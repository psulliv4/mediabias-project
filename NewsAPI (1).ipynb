# %% [markdown]
# # Conservative Sources

# %%
import pandas as pd
import requests

url_fox1 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=fox-news&'
       'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_fox1 = requests.get(url_fox1)

#print(response_fox1.content)

url_fox2 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=fox-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_fox2 = requests.get(url_fox2)

#response_fox2.content

# %%
url_nreview1 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_nreview1 = requests.get(url_nreview1)

#print(response_nreview1.content)

url_nreview2 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_nreview2 = requests.get(url_nreview2)

#print(response_nreview2.content)

url_nreview3 = ('http://newsapi.org/v2/everything?'
       'q=what&'
       'sources=national-review&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_nreview3 = requests.get(url_nreview3)

#response_nreview3.content

# %%
url_bart1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_bart1 = requests.get(url_bart1)

#print(response_bart1.content)

url_bart2 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=breitbart-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_bart2 = requests.get(url_bart2)

#response_bart2.content

# %% [markdown]
# # Liberal Sources

# %%
url_vice1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_vice1 = requests.get(url_vice1)

#print(response_vice1.content)

url_vice2 = ('http://newsapi.org/v2/everything?'
       'q=what&'
       'sources=vice-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_vice2 = requests.get(url_vice2)

#print(response_vice2.content)

# %%
url_msnbc1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_msnbc1 = requests.get(url_msnbc1)

#print(response_msnbc1.content)

url_msnbc2 = ('http://newsapi.org/v2/everything?'
       'q=what&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_msnbc2 = requests.get(url_msnbc2)

#print(response_msnbc2.content)

url_msnbc3 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=msnbc&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_msnbc3 = requests.get(url_msnbc3)

#print(response_msnbc3.content)

# %%
url_buzz1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_buzz1 = requests.get(url_buzz1)

#print(response_buzz1.content)

url_buzz2 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_buzz2 = requests.get(url_buzz2)

#print(response_buzz2.content)

url_buzz3 = ('http://newsapi.org/v2/everything?'
       'q=news&'
       'sources=buzzfeed&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_buzz3 = requests.get(url_buzz3)

#print(response_buzz3.content)

# %% [markdown]
# # Neutral Sources

# %%
url_cbs1 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=cbs-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_cbs1 = requests.get(url_cbs1)

#print(response_cbs1.content)

url_cbs2 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=cbs-news&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_cbs2 = requests.get(url_cbs2)

#print(response_cbs2.content)

# %%
url_hill1 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=the-hill&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_hill1 = requests.get(url_hill1)

#print(response_hill1.content)

url_hill2 = ('http://newsapi.org/v2/everything?'
       'q=virus&'
       'sources=the-hill&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_hill2 = requests.get(url_hill2)

#print(response_hill2.content)

# %%
url_reuters1 = ('http://newsapi.org/v2/everything?'
       'q=primary&'
       'sources=reuters&'
        'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-02-24&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_reuters1 = requests.get(url_reuters1)

#print(response_reuters1.content)

url_reuters2 = ('http://newsapi.org/v2/everything?'
       'q=trump&'
       'sources=reuters&'
       'pageSize=100&'
       'sortBy=popularity&'
       'from=2020-03-15&'
       'to=2020-03-24&'
       'apiKey=dfb5e6075cc043b687b45876d6be0561')

response_reuters2 = requests.get(url_reuters2)

#print(response_reuters2.content)
# response_reuters2.json()

# %% [markdown]
# # Decoding and Converting to JSON

# %%
# response_fox1
# response_fox2
# response_bart1
# response_bart2
# response_nreview1
# response_nreview2
# response_nreview3

print('Conservative sources, 1 partisan right, 2 skew right')
response_fox1_d = response_fox1.content.decode("utf-8")
print(response_fox1_d)
response_fox2_d = response_fox2.content.decode("utf-8")
print(response_fox2_d)

response_bart1_d = response_bart1.content.decode("utf-8")
#print(response_bart1_d)
response_bart2_d = response_bart2.content.decode("utf-8")
#print(response_bart2_d)

response_nreview1_d = response_nreview1.content.decode("utf-8")
#print(response_nreview1_d)
response_nreview2_d = response_nreview2.content.decode("utf-8")
#print(response_nreview2_d)
response_nreview3_d = response_nreview3.content.decode("utf-8")
#print(response_nreview3_d)




# response_vice1
# response_vice2
# response_msnbc1
# response_msnbc2
# response_msnbc3
# response_buzz1
# response_buzz2
# response_buzz3

print('Liberal sources, 1 partisan left, 2 skew left')
response_vice1_d = response_vice1.content.decode("utf-8")
#print(response_vice1_d)
response_vice2_d = response_vice2.content.decode("utf-8")
#print(response_vice2_d)

response_msnbc1_d = response_msnbc1.content.decode("utf-8")
#print(response_msnbc1_d)
response_msnbc2_d = response_msnbc2.content.decode("utf-8")
#print(response_msnbc2_d)
response_msnbc3_d = response_msnbc3.content.decode("utf-8")
#print(response_msnbc3_d)

response_buzz1_d = response_buzz1.content.decode("utf-8")
#print(response_buzz1_d)
response_buzz2_d = response_buzz2.content.decode("utf-8")
#print(response_buzz2_d)
response_buzz3_d = response_buzz3.content.decode("utf-8")
#print(response_buzz3_d)



# response_hill1
# response_hill2
# response_reuters1
# response_reuters2
# response_cbs1
# response_cbs2

print('Neutral sources')
response_hill1_d = response_hill1.content.decode("utf-8")
#print(response_hill1_d)
response_hill2_d = response_hill2.content.decode("utf-8")
#print(response_hill2_d)

response_reuters1_d = response_reuters1.content.decode("utf-8")
#print(response_reuters1_d)
response_reuters2_d = response_reuters2.content.decode("utf-8")
#print(response_reuters2_d)

response_cbs1_d = response_cbs1.content.decode("utf-8")
#print(response_cbs1_d)
response_cbs2_d = response_cbs2.content.decode("utf-8")
#print(response_cbs2_d)





print(type(response_cbs2))
type(response_cbs2_d)

# %%
import json
# response_1x = json.loads(response_1)
# print(type(response_1x))
# # print(response_1x)
# response_1x['articles']



#conservative
response_fox1_j = json.loads(response_fox1_d)
# response_fox1_j['articles']
# response_fox1_j
response_fox2_j = json.loads(response_fox2_d)


response_bart1_j = json.loads(response_bart1_d)
response_bart2_j = json.loads(response_bart2_d)

response_nreview1_j = json.loads(response_nreview1_d)
response_nreview2_j = json.loads(response_nreview2_d)
response_nreview3_j = json.loads(response_nreview3_d)

#liberal
response_vice1_j = json.loads(response_vice1_d)
response_vice2_j = json.loads(response_vice2_d)

response_msnbc1_j = json.loads(response_msnbc1_d)
response_msnbc2_j = json.loads(response_msnbc2_d)
response_msnbc3_j = json.loads(response_msnbc3_d)

response_buzz1_j = json.loads(response_buzz1_d)
response_buzz2_j = json.loads(response_buzz2_d)
response_buzz3_j = json.loads(response_buzz3_d)


#neutral
response_hill1_j = json.loads(response_hill1_d)
response_hill2_j = json.loads(response_hill2_d)

response_reuters1_j = json.loads(response_reuters1_d)
response_reuters2_j = json.loads(response_reuters2_d)

response_cbs1_j = json.loads(response_cbs1_d)
response_cbs2_j = json.loads(response_cbs2_d)

# %% [markdown]
# # Converting JSON to pandas Dataframe

# %%
# df = pd.DataFrame(response_1x['articles'])
# df

#conservative df's
df_fox1 = pd.DataFrame(response_fox1_j['articles'])
df_fox1
df_fox2 = pd.DataFrame(response_fox2_j['articles'])
df_fox2


df_bart1 = pd.DataFrame(response_bart1_j['articles'])
df_bart1
df_bart2 = pd.DataFrame(response_bart2_j['articles'])
df_bart2
 

df_nreview1 = pd.DataFrame(response_nreview1_j['articles'])
df_nreview1
df_nreview2 = pd.DataFrame(response_nreview2_j['articles'])
df_nreview2
df_nreview3 = pd.DataFrame(response_nreview3_j['articles'])
df_nreview3


# #liberal

df_vice1 = pd.DataFrame(response_vice1_j['articles'])
df_vice1
df_vice2 = pd.DataFrame(response_vice2_j['articles'])
df_vice2

df_msnbc1 = pd.DataFrame(response_msnbc1_j['articles'])
df_msnbc1
df_msnbc2 = pd.DataFrame(response_msnbc2_j['articles'])
df_msnbc2
df_msnbc3 = pd.DataFrame(response_msnbc3_j['articles'])
df_msnbc3

df_buzz1 = pd.DataFrame(response_buzz1_j['articles'])
df_buzz1
df_buzz2 = pd.DataFrame(response_buzz2_j['articles'])
df_buzz2
df_buzz3 = pd.DataFrame(response_buzz3_j['articles'])
df_buzz3


# #neutral
df_hill1 = pd.DataFrame(response_hill1_j['articles'])
df_hill1
df_hill2 = pd.DataFrame(response_hill2_j['articles'])
df_hill2

df_reuters1 = pd.DataFrame(response_reuters1_j['articles'])
df_reuters1
df_reuters2 = pd.DataFrame(response_reuters2_j['articles'])
df_reuters2

df_cbs1 = pd.DataFrame(response_cbs1_j['articles'])
df_cbs1
df_cbs2 = pd.DataFrame(response_cbs1_j['articles'])
df_cbs2

# %% [markdown]
# # Merging Dataframes

# %%
df_allsources = pd.concat([df_fox1, df_fox2, df_bart1, df_bart2, df_nreview1, df_nreview2, df_nreview3,
                           df_msnbc1, df_msnbc2, df_msnbc3, df_buzz1, df_buzz2, df_buzz3, df_vice1, df_vice2,
                           df_hill1, df_hill2, df_reuters1, df_reuters2, df_cbs1, df_cbs2])
df_allsources

# %%
df_allsources.to_csv('newsapi_scrape1.csv', index=False)

# %% [markdown]
# # Cleaning the Data

# %%
MarchNews = pd.read_csv('newsapi_scrape1.csv')
#print(MarchNews)

Nan = MarchNews['content'].isnull().sum()
print(f'There are {Nan} news articles that do not have content')


#Replacing Null values with 'None'
MarchNews['content'].fillna("None", inplace = True)
MarchNews['title'].fillna('None', inplace = True)
MarchNews['description'].fillna('None', inplace = True)
# Out:
# There are 453 news articles that do not have content

# %%
import re
import nltk
from nltk.corpus import stopwords
stopwords = nltk.corpus.stopwords.words('english')


Content = []
Description = []
Title = []

for i in range(len(MarchNews['content'])):
    Content.append(re.findall(r'\w+', MarchNews['content'][i])[:-2])
    Description.append(re.findall(r'\w+', MarchNews['description'][i]))
    Title.append(re.findall(r'\w+', MarchNews['title'][i]))

# %%
Title
# Out:
# [['South',
#   'Carolina',
#   'primary',
#   'is',
#   'do',
#   'or',
#   'die',
#   'for',
#   'Biden',
#   'campaign'],
#  ['Sanders',
#   'supporters',
#   'react',
#   'to',
#   'DNC',
#   'reportedly',
#   'attempting',
#   'to',
#   'subvert',
#   'primary',
#   'result'],
#  ['Contentious',
#   'Race',
#   'Democratic',
#   'Race',
#   'Heads',
#   'to',
#   'South',
#   'Carolina'],
#  ['Federalist',
#   'Editor',
#   'Mollie',
#   'Hemingway',
#   'On',
#   'Biden',
#   's',
#   'SC',
#   'Win',
#   'He',
#   'Blew',
#   'Away',
#   'People',
#   's',
#   'Expectations'],
#  ['Will', 'Biden', 'Get', 'a', 'Bounce', 'on', 'Super', 'Tuesday'],
#  ['Josh',
#   'Kraushaar',
#   'Politics',
#   'Editor',
#   'For',
#   'National',
#   'Journal',
#   'On',
#   '2020',
#   'Dem',
#   'Race',
#   'If',
#   'Biden',
#   'Doesn',
#   't',
#   'Win',
#   'South',
#   'Carolina',
#   'Primary',
#   'Bernie',
#   'Sanders',
#   'Is',
#   'The',
#   'Democratic',
#   'Nominee'],
#  ['Bernie',
#   'Fights',
#   'for',
#   'Survival',
#   'as',
#   'Polls',
#   'Show',
#   'Biden',
#   'Blowout',
#   'in',
#   'Michigan'],
#  ['Sen',
#   'Rick',
#   'Scott',
#   'I',
#   'Do',
#   'Not',
#   'Believe',
#   'In',
#   'Bailouts',
#   'For',
#   'Companies',
#   'Period'],
#  ['Former',
#   'Ohio',
#   'Senate',
#   'Minority',
#   'Leader',
#   'Capri',
#   'Cafaro',
#   'On',
#   'Bernie',
#   'Sander',
#   's',
#   '2020',
#   'Primary',
#   'Performance',
#   'He',
#   'Has',
#   'Consistently',
#   'Underperformed',
#   'From',
#   'His',
#   'Numbers',
#   'In',
#   '2016'],
#  ['Biden',
#   'Boost',
#   'Can',
#   'the',
#   'Establishment',
#   'Make',
#   'Him',
#   'the',
#   'Comeback',
#   'Kid'],
#  ['Fox',
#   'News',
#   'Contributor',
#   'Kim',
#   'Strassel',
#   'Takes',
#   'On',
#   'Socialism',
#   'Bernie',
#   'Sanders',
#   'Has',
#   'A',
#   'Fundamentally',
#   'Different',
#   'Concept',
#   'Of',
#   'America'],
#  ['2020', 'and', 'the', 'Fight', 'to', 'Control', 'Congress'],
#  ['Sanders',
#   'Speeds',
#   'out',
#   'of',
#   'Nevada',
#   'with',
#   'Momentum',
#   'as',
#   'Moderate',
#   'Democrats',
#   'Panic'],
#  ['March',
#   'Madness',
#   'Stocks',
#   'Plummet',
#   'Amid',
#   'Oil',
#   'Plunge',
#   'and',
#   'Coronavirus',
#   'Fears'],
#  ['Fox',
#   'News',
#   'Rundown',
#   'Extra',
#   'Karl',
#   'Rove',
#   'on',
#   'The',
#   'Democrats',
#   'Biggest',
#   '2020',
#   'Challenges'],
#  ['Make', 'Your', 'Bernie', 'Bets'],
#  ['Rep',
#   'Elise',
#   'Stefanik',
#   'NY',
#   '21',
#   'On',
#   'Slow',
#   'Pace',
#   'Of',
#   'Coronavirus',
#   'Testing',
#   'There',
#   'Is',
#   'No',
#   'Explanation',
#   'For',
#   'Lack',
#   'Of',
#   'Testing'],
#  ['Senator',
#   'Joni',
#   'Ernst',
#   'R',
#   'IA',
#   'On',
#   'Democrats',
#   'Infanticide',
#   'Filibuster',
#   'Heartbroken',
#   'With',
#   'Where',
#   'The',
#   'Dems',
#   'Are',
#   'On',
#   'The',
#   'Issue',
#   'Of',
#   'Life'],
#  ['Candidates',
#   'make',
#   'final',
#   'pitches',
#   'ahead',
#   'of',
#   'South',
#   'Carolina',
#   'primary'],
#  ['Sanders', 'taking', 'Nevada', 'momentum', 'to', 'South', 'Carolina'],
#  ['Fox',
#   'Poll',
#   'Sanders',
#   'leads',
#   'with',
#   'Democrats',
#   'who',
#   'want',
#   'change'],
#  ['Biden',
#   'Sanders',
#   'battle',
#   'for',
#   'working',
#   'class',
#   'voters',
#   'ahead',
#   'of',
#   'Michigan',
#   'primary'],
#  ['Past', 'South', 'Carolina', 'presidential', 'primary', 'winners'],
#  ['Sanders',
#   'downplays',
#   'shortcomings',
#   'with',
#   'black',
#   'voters',
#   'following',
#   'South',
#   'Carolina',
#   'loss'],
#  ['Louisiana', 'postpones', 'primary', 'amid', 'coronavirus', 'pandemic'],
#  ['Geraldo',
#   'Rivera',
#   'Biden',
#   'will',
#   'win',
#   'South',
#   'Carolina',
#   'and',
#   'carry',
#   'momentum',
#   'into',
#   'Super',
#   'Tuesday'],
#  ['Clyburn',
#   'endorses',
#   'Joe',
#   'Biden',
#   'ahead',
#   'of',
#   'South',
#   'Carolina',
#   'primary'],
#  ['Tom',
#   'Steyer',
#   'ends',
#   'campaign',
#   'after',
#   'Biden',
#   'wins',
#   'South',
#   'Carolina',
#   'primary'],
#  ['Michigan',
#   's',
#   'primary',
#   'winners',
#   'in',
#   'past',
#   'presidential',
#   'contests'],
#  ['Tucker',
#   'Carlson',
#   'Everyone',
#   'in',
#   'the',
#   '2020',
#   'Democratic',
#   'field',
#   'has',
#   'been',
#   'diminished',
#   'Their',
#   'ideas',
#   'are',
#   'absurd'],
#  ['Democracy',
#   '2020',
#   'Digest',
#   'GOP',
#   'voters',
#   'a',
#   'potential',
#   'factor',
#   'in',
#   'Dems',
#   'South',
#   'Carolina',
#   'primary'],
#  ['Coronavirus',
#   'live',
#   'blog',
#   'Primary',
#   'care',
#   'physician',
#   'Dr',
#   'Nate',
#   'Favini',
#   'answers',
#   'your',
#   'questions'],
#  ['Sanders',
#   'supporters',
#   'accused',
#   'of',
#   'late',
#   'night',
#   'bullhorn',
#   'protests',
#   'of',
#   'Dem',
#   'officials'],
#  ['Sanders', 'knocks', 'Biden', 'out', 'of', 'first'],
#  ['Rob',
#   'Kardashian',
#   's',
#   'emergency',
#   'request',
#   'for',
#   'primary',
#   'custody',
#   'of',
#   'daughter',
#   'Dream',
#   'is',
#   'denied',
#   'reports'],
#  ['Biden',
#   'touts',
#   'landslide',
#   'victory',
#   'in',
#   'South',
#   'Carolina',
#   'swipes',
#   'at',
#   'Sanders',
#   'revolution'],
#  ['Bernie',
#   'Sanders',
#   'to',
#   'deliver',
#   'statement',
#   'after',
#   'primary',
#   'losses',
#   'to',
#   'Biden'],
#  ['Biden',
#   'wins',
#   'Maine',
#   'primary',
#   'giving',
#   'him',
#   '10',
#   'Super',
#   'Tuesday',
#   'victories'],
#  ['Democracy',
#   '2020',
#   'Digest',
#   'Coronavirus',
#   'scare',
#   'dampens',
#   'primary',
#   'turnout'],
#  ['Trump',
#   'secures',
#   'GOP',
#   'presidential',
#   'nomination',
#   'with',
#   'Tuesday',
#   's',
#   'primary',
#   'victories'],
#  ['AOC',
#   's',
#   'pick',
#   'in',
#   'Democrat',
#   'primary',
#   'for',
#   'House',
#   'seat',
#   'beats',
#   'incumbent'],
#  ['A',
#   'look',
#   'at',
#   'Ohio',
#   's',
#   'primary',
#   'winners',
#   'in',
#   'past',
#   'presidential',
#   'contests'],
#  ['Trump',
#   'snubs',
#   'Sessions',
#   'endorses',
#   'Tuberville',
#   'in',
#   'Alabama',
#   'Senate',
#   'primary',
#   'runoff'],
#  ['Maryland',
#   'will',
#   'postpone',
#   'primary',
#   'election',
#   'because',
#   'of',
#   'coronavirus',
#   'governor',
#   'says'],
#  ['Biden',
#   'declared',
#   'winner',
#   'of',
#   'Washington',
#   'state',
#   'primary',
#   'days',
#   'after',
#   'vote'],
#  ['Bill',
#   'Weld',
#   'suspends',
#   'long',
#   'shot',
#   'primary',
#   'challenge',
#   'against',
#   'Trump'],
#  ['Trump',
#   'taunts',
#   'Sanders',
#   'after',
#   'primary',
#   'drubbing',
#   'Bernie',
#   'has',
#   'given',
#   'up'],
#  ['Biden',
#   'lands',
#   'big',
#   'endorsement',
#   'in',
#   'crucial',
#   'primary',
#   'state',
#   'of',
#   'Michigan'],
#  ['Cory', 'Booker', 'endorses', 'former', 'primary', 'rival', 'Joe', 'Biden'],
#  ['A',
#   'look',
#   'at',
#   'Florida',
#   's',
#   'primary',
#   'winners',
#   'in',
#   'past',
#   'presidential',
#   'contests'],
#  ['Super',
#   'Tuesday',
#   'results',
#   'Where',
#   'the',
#   '2020',
#   'Democratic',
#   'candidates',
#   'stand'],
#  ['March',
#   '17',
#   'primaries',
#   'Here',
#   'are',
#   'the',
#   'states',
#   'voting',
#   'and',
#   'the',
#   'delegates',
#   'at',
#   'stake'],
#  ['States',
#   'that',
#   'have',
#   'postponed',
#   'primaries',
#   'due',
#   'to',
#   'coronavirus',
#   'outbreak'],
#  ['Mike',
#   'Bloomberg',
#   'spent',
#   'nearly',
#   '1B',
#   'of',
#   'his',
#   'own',
#   'money',
#   'on',
#   'failed',
#   'presidential',
#   'bid'],
#  ['Bernie',
#   'Sanders',
#   'surrogate',
#   'claims',
#   'media',
#   'are',
#   'lying',
#   'about',
#   'support',
#   'for',
#   'socialism',
#   'Our',
#   'ideas',
#   'are',
#   'popular'],
#  ['Laura',
#   'Ingraham',
#   'Joe',
#   'Biden',
#   's',
#   'lagging',
#   'campaign',
#   'lacks',
#   'the',
#   'Obama',
#   'magic',
#   'and',
#   'money'],
#  ['Trump',
#   'says',
#   'Biden',
#   's',
#   'South',
#   'Carolina',
#   'win',
#   'should',
#   'end',
#   'Mini',
#   'Mike',
#   'Bloomberg',
#   's',
#   'joke',
#   'of',
#   'a',
#   'campaign'],
#  ['Joe',
#   'Biden',
#   's',
#   'campaign',
#   'still',
#   'on',
#   'life',
#   'support',
#   'despite',
#   'South',
#   'Carolina',
#   'win',
#   'Corey',
#   'Lewandowski',
#   'says'],
#  ['Biden',
#   'accidentally',
#   'tells',
#   'South',
#   'Carolina',
#   'crowd',
#   'he',
#   's',
#   'a',
#   'Dem',
#   'candidate',
#   'for',
#   'the',
#   'United',
#   'States',
#   'Senate'],
#  ['Colin',
#   'Reed',
#   'Is',
#   'Bernie',
#   'Sanders',
#   'newfound',
#   'front',
#   'runner',
#   'status',
#   'pushing',
#   'establishment',
#   'Dems',
#   'to',
#   'the',
#   'edge'],
#  ['Lawrence',
#   'Jones',
#   'grills',
#   'South',
#   'Carolina',
#   'Democrats',
#   'about',
#   'Bernie',
#   'Sanders',
#   'Castro',
#   'praise',
#   'inconceivable'],
#  ['Tom',
#   'Steyer',
#   'dances',
#   'to',
#   'Back',
#   'that',
#   'Azz',
#   'up',
#   'in',
#   'excruciating',
#   'video'],
#  ['Andrew',
#   'Yang',
#   'launches',
#   'nonprofit',
#   'after',
#   'dropping',
#   'out',
#   'of',
#   '2020',
#   'race'],
#  ['Gutfeld', 'on', 'Bernie', 'vs', 'Joe'],
#  ['Jessica',
#   'Tarlov',
#   'The',
#   'key',
#   'thing',
#   'Democratic',
#   'primary',
#   'voters',
#   'need',
#   'to',
#   'remember',
#   'when',
#   'they',
#   'cast',
#   'their',
#   'ballots'],
#  ['Democracy',
#   '2020',
#   'Digest',
#   'Sanders',
#   'heavy',
#   'on',
#   'electability',
#   'light',
#   'on',
#   'revolution',
#   'on',
#   'eve',
#   'of',
#   'SC',
#   'primary'],
#  ['Sanders',
#   'congratulates',
#   'Biden',
#   'on',
#   'primary',
#   'win',
#   'eyes',
#   'Super',
#   'Tuesday',
#   'You',
#   'cannot',
#   'win',
#   'them',
#   'all'],
#  ['Polls',
#   'to',
#   'close',
#   'in',
#   'South',
#   'Carolina',
#   'primary',
#   'as',
#   'Biden',
#   'seeks',
#   'crucial',
#   'first',
#   'win'],
#  ['South',
#   'Carolina',
#   'paper',
#   'warns',
#   'of',
#   'political',
#   'dirty',
#   'tricks',
#   'ahead',
#   'of',
#   'state',
#   'primary'],
#  ['Trump',
#   'holds',
#   'rally',
#   'in',
#   'North',
#   'Charleston',
#   'on',
#   'eve',
#   'of',
#   'Dems',
#   'South',
#   'Carolina',
#   'primary'],
#  ['When',
#   'Bill',
#   'Clinton',
#   'was',
#   'accused',
#   'of',
#   'racism',
#   'during',
#   'South',
#   'Carolina',
#   'primary'],
#  ['Sanders',
#   'claims',
#   'he',
#   'backed',
#   'Obama',
#   'in',
#   'both',
#   'of',
#   'his',
#   'campaigns',
#   'despite',
#   'report',
#   'of',
#   'mulling',
#   'primary',
#   'bid'],
#  ['Leslie',
#   'Marshall',
#   'Biden',
#   's',
#   'big',
#   'victory',
#   'in',
#   'SC',
#   'primary',
#   'strengthens',
#   'his',
#   'challenge',
#   'to',
#   'Sanders'],
#  ['South',
#   'Carolina',
#   'Democrats',
#   'say',
#   'presidential',
#   'primary',
#   'turnout',
#   'may',
#   'approach',
#   'record',
#   'high'],
#  ['Chris',
#   'Matthews',
#   'absent',
#   'from',
#   'MSNBC',
#   's',
#   'primary',
#   'coverage',
#   'after',
#   'sexism',
#   'allegations',
#   'on',
#   'air',
#   'slip',
#   'ups'],
#  ['Biden',
#   's',
#   'South',
#   'Carolina',
#   'win',
#   'may',
#   'aid',
#   'primary',
#   'reset',
#   'but',
#   'Super',
#   'Tuesday',
#   'will',
#   'decide'],
#  ['Biden',
#   'calls',
#   'SC',
#   'primary',
#   'real',
#   'comeback',
#   'as',
#   'he',
#   'sets',
#   'sights',
#   'on',
#   'Super',
#   'Tuesday'],
#  ['Primaries',
#   'go',
#   'forward',
#   'in',
#   'three',
#   'big',
#   'states',
#   'despite',
#   'coronavirus',
#   'as',
#   'Biden',
#   'looks',
#   'to',
#   'shut',
#   'out',
#   'Sanders'],
#  ['Newt',
#   'Gingrich',
#   '50',
#   'hours',
#   'that',
#   'changed',
#   'the',
#   '2020',
#   'Democratic',
#   'presidential',
#   'race'],
#  ['Sanders',
#   'clashes',
#   'with',
#   'Biden',
#   'at',
#   'debate',
#   'over',
#   'claims',
#   'he',
#   'sought',
#   'Social',
#   'Security',
#   'cuts'],
#  ['No',
#   'live',
#   'audience',
#   'at',
#   'next',
#   'Democratic',
#   'debate',
#   'due',
#   'to',
#   'coronavirus',
#   'precautions'],
#  ['Biden',
#   'up',
#   '20',
#   'points',
#   'over',
#   'Sanders',
#   'in',
#   'Arizona',
#   'on',
#   'eve',
#   'of',
#   'presidential',
#   'primary',
#   'poll'],
#  ['Florida',
#   'dealing',
#   'with',
#   'dearth',
#   'of',
#   'poll',
#   'workers',
#   'as',
#   'primary',
#   'held',
#   'amid',
#   'coronavirus',
#   'pandemic'],
#  ['Clyburn',
#   'calls',
#   'for',
#   'shutting',
#   'Dem',
#   'primary',
#   'down',
#   'canceling',
#   'debates',
#   'after',
#   'Biden',
#   'surge'],
#  ['Michigan',
#   'officials',
#   'say',
#   'complete',
#   'primary',
#   'results',
#   'won',
#   't',
#   'be',
#   'released',
#   'until',
#   'Wednesday',
#   'afternoon'],
#  ['Biden',
#   'projected',
#   'to',
#   'win',
#   'Mississippi',
#   'and',
#   'Missouri',
#   'primaries',
#   'with',
#   'polls',
#   'in',
#   'pivotal',
#   'Michigan',
#   'closing',
#   'soon'],
#  ['CNN',
#   'mocked',
#   'for',
#   'airing',
#   'graphic',
#   'declaring',
#   'Sanders',
#   'the',
#   'winner',
#   'in',
#   'Mississippi'],
#  ['Progressives',
#   'slam',
#   'irresponsible',
#   'Tom',
#   'Perez',
#   'Dems',
#   'for',
#   'allowing',
#   'primaries',
#   'amid',
#   'virus',
#   'outbreak',
#   'This',
#   'is',
#   'going',
#   'to',
#   'get',
#   'people',
#   'killed'],
#  ['Confusion',
#   'over',
#   'how',
#   'and',
#   'when',
#   'Ohio',
#   's',
#   'primary',
#   'will',
#   'take',
#   'place',
#   'after',
#   'coronavirus',
#   'postponement'],
#  ['Biden', 'backs', 'off', 'calling', 'South', 'Carolina', 'his', 'firewall'],
#  ['NYT',
#   's',
#   'Friedman',
#   'calls',
#   'for',
#   'a',
#   'gathering',
#   'of',
#   'Dem',
#   'Party',
#   'elders',
#   'to',
#   'counter',
#   'Bernie',
#   'Sanders',
#   'surge'],
#  ['Biden',
#   'campaign',
#   'vows',
#   'victory',
#   'in',
#   'South',
#   'Carolina',
#   'says',
#   'race',
#   'just',
#   'getting',
#   'started'],
#  ['Mary',
#   'Anne',
#   'Marsh',
#   'In',
#   'Democratic',
#   'debate',
#   '3',
#   'winners',
#   'and',
#   '4',
#   'losers',
#   'in',
#   'a',
#   'two',
#   'hour',
#   'street',
#   'fight'],
#  ['South',
#   'Carolina',
#   'Gov',
#   'McMaster',
#   'on',
#   'Trump',
#   's',
#   'connection',
#   'with',
#   'voters',
#   'Never',
#   'seen',
#   'anything',
#   'like',
#   'it'],
#  ['Sanders',
#   'once',
#   'complained',
#   'about',
#   'early',
#   'southern',
#   'primaries',
#   'said',
#   'calendar',
#   'distorts',
#   'reality'],
#  ['Sen',
#   'Tim',
#   'Scott',
#   'Sanders',
#   'rivals',
#   'face',
#   'a',
#   'make',
#   'or',
#   'break',
#   'moment',
#   'in',
#   'South',
#   'Carolina',
#   'debate'],
#  ['Bernie',
#   'Sanders',
#   'revisited',
#   'Candidate',
#   'backs',
#   'letting',
#   'violent',
#   'felons',
#   'vote',
#   'from',
#   'prison'],
#  ['Charles',
#   'Hurt',
#   'Mike',
#   'Bloomberg',
#   'dangerous',
#   'ahead',
#   'of',
#   'Super',
#   'Tuesday'],
#  ['Karl',
#   'Rove',
#   'on',
#   'Biden',
#   's',
#   'South',
#   'Carolina',
#   'win',
#   'If',
#   'he',
#   'didn',
#   't',
#   'win',
#   'tonight',
#   'he',
#   'was',
#   'out'],
#  ['In',
#   'South',
#   'Carolina',
#   'pumped',
#   'up',
#   'Steyer',
#   'says',
#   'he',
#   's',
#   'ready',
#   'to',
#   'run',
#   'through',
#   'the',
#   'tape'],
#  ['New',
#   'York',
#   'State',
#   'fights',
#   'coronavirus',
#   'with',
#   'blood',
#   'plasma',
#   'from',
#   'recovered',
#   'patients'],
#  ['Africa', 's', 'mountain', 'gorillas', 'face', 'coronavirus', 'risk'],
#  ['Scientists',
#   'map',
#   'how',
#   'immune',
#   'system',
#   'fights',
#   'back',
#   'against',
#   'COVID',
#   '19'],
#  ['Coronavirus',
#   'travel',
#   'ban',
#   'American',
#   'United',
#   'and',
#   'Delta',
#   'airlines',
#   'cap',
#   'flight',
#   'fares',
#   'from',
#   'Europe',
#   'to',
#   'U',
#   'S',
#   'Fox',
#   'News'],
#  ['Jimmy',
#   'Kimmel',
#   'mocks',
#   'Pence',
#   's',
#   'ability',
#   'to',
#   'tackle',
#   'coronavirus',
#   'What',
#   's',
#   'his',
#   'plan',
#   'abstinence',
#   'Fox',
#   'News'],
#  ['Trump',
#   'to',
#   'pitch',
#   'Congress',
#   'on',
#   'payroll',
#   'tax',
#   'cut',
#   'relief',
#   'for',
#   'small',
#   'business',
#   'amid',
#   'coronavirus',
#   'crisis',
#   'Fox',
#   'News'],
#  ['5',
#   'ways',
#   'tech',
#   'can',
#   'help',
#   'you',
#   'stay',
#   'sane',
#   'while',
#   'you',
#   'stay',
#   'home',
#   'Fox',
#   'News'],
#  ['Lose',
#   'of',
#   'taste',
#   'smell',
#   'could',
#   'be',
#   'telltale',
#   'sign',
#   'of',
#   'coronavirus',
#   'Fox',
#   'News'],
#  ['Brazil',
#   's',
#   'President',
#   'Bolsonaro',
#   's',
#   'son',
#   'claims',
#   'father',
#   'tested',
#   'negative',
#   'for',
#   'coronavirus',
#   'despite',
#   'earlier',
#   'reports',
#   'Fox',
#   'News'],
#  ['Trump',
#   'tweets',
#   'out',
#   'series',
#   'of',
#   'tips',
#   'on',
#   'how',
#   'to',
#   'avoid',
#   'coronavirus',
#   'Fox',
#   'News'],
#  ['Washington',
#   'state',
#   'confirms',
#   '10th',
#   'coronavirus',
#   'death',
#   'Fox',
#   'News'],
#  ['Tom', 'Hanks', 'confirms', 'positive', 'test', 'for', 'coronoavirus'],
#  ['Sen',
#   'Lindsey',
#   'Graham',
#   'says',
#   'US',
#   'will',
#   'counterattack',
#   'the',
#   'coronavirus',
#   'while',
#   'stabilizing',
#   'the',
#   'economy'],
#  ['Is', 'America', 'Ready', 'to', 'Fight', 'the', 'Coronavirus'],
#  ['Trump', 'Blames', 'Media', 'Hatred', 'for', 'Tough', 'Virus', 'Coverage'],
#  ['Biden',
#   'Sweeps',
#   '3',
#   'States',
#   'Media',
#   'Barely',
#   'Budge',
#   'from',
#   'Virus',
#   'Coverage'],
#  ['Trump',
#   'Others',
#   'Eye',
#   'Softening',
#   'Restrictions',
#   'Despite',
#   'Pandemic'],
#  ['Sen',
#   'John',
#   'Cornyn',
#   'Congress',
#   'And',
#   'The',
#   'Nation',
#   'Need',
#   'To',
#   'Be',
#   'On',
#   'A',
#   'War',
#   'Footing',
#   'To',
#   'Beat',
#   'This',
#   'Virus'],
#  ['State',
#   'Department',
#   'Spox',
#   'Morgan',
#   'Ortagus',
#   'On',
#   'Coronavirus',
#   'China',
#   's',
#   'Holding',
#   'the',
#   'Match',
#   'They',
#   'Lit',
#   'The',
#   'World',
#   'On',
#   'Fire',
#   'With',
#   'This',
#   'Virus'],
#  ['Dr',
#   'Ronny',
#   'Jackson',
#   'Disgusted',
#   'By',
#   'The',
#   'Press',
#   'Trying',
#   'To',
#   'Make',
#   'President',
#   'Trump',
#   'A',
#   'Xenophobe'],
#  ['U',
#   'S',
#   'Surgeon',
#   'General',
#   'on',
#   'CoronaVirus',
#   'Take',
#   'Precautions',
#   'Don',
#   't',
#   'Hoard',
#   'Our',
#   'Anticipation',
#   'Is',
#   'That',
#   'This',
#   'Will',
#   'Be',
#   'Equivalent',
#   'To',
#   'A',
#   'Bad',
#   'Flu',
#   'Season'],
#  ['POTUS', 'v', 'SCOTUS'],
#  ['Momming',
#   'Through',
#   'Coronavirus',
#   'What',
#   'To',
#   'Tell',
#   'Your',
#   'Kids',
#   'and',
#   'Yourself'],
#  ['Is', 'Your', 'Wedding', 'Dress', 'In', 'Coronavirus', 'Jeopardy'],
#  ['Rep',
#   'Josh',
#   'Gottheimer',
#   'Time',
#   'For',
#   'Aggressive',
#   'Measures',
#   'To',
#   'Take',
#   'Care',
#   'Of',
#   'Local',
#   'Businesses'],
#  ['Dr',
#   'Janette',
#   'Nesheiwat',
#   'Social',
#   'Distancing',
#   'Is',
#   'There',
#   'To',
#   'Save',
#   'Lives'],
#  ['A', 'National', 'Emergency', 'For', 'A', 'Global', 'Pandemic'],
#  ['March',
#   'Madness',
#   'Stocks',
#   'Plummet',
#   'Amid',
#   'Oil',
#   'Plunge',
#   'and',
#   'Coronavirus',
#   'Fears'],
#  ['Government', 's', 'Response', 'To', 'Our', 'Invisible', 'Enemy'],
#  ['Fox',
#   'News',
#   'Rundown',
#   'Extra',
#   'A',
#   'Former',
#   'FEMA',
#   'Chief',
#   'On',
#   'Coronavirus',
#   'And',
#   'The',
#   'Failure',
#   'of',
#   'Personal',
#   'Responsibility'],
#  ['Dr',
#   'Marc',
#   'Siegel',
#   'We',
#   'Need',
#   'Coronavirus',
#   'Testing',
#   'To',
#   'Ramp',
#   'Up',
#   'Not',
#   'Paranoia'],
#  ['Pastor',
#   'Max',
#   'Lucado',
#   'Feeding',
#   'Your',
#   'Faith',
#   'to',
#   'Starve',
#   'Your',
#   'Fears'],
#  ['Senator',
#   'Bill',
#   'Cassidy',
#   'R',
#   'LA',
#   'On',
#   'Federal',
#   'Response',
#   'To',
#   'Coronavirus'],
#  ['Billions', 'Approved', 'to', 'Fight', 'Coronavirus'],
#  ['Rep',
#   'Matt',
#   'Gaetz',
#   'I',
#   'Wore',
#   'A',
#   'Gas',
#   'Mask',
#   'To',
#   'Show',
#   'How',
#   'Congress',
#   'Will',
#   'Feel',
#   'The',
#   'Impact',
#   'Of',
#   'Coronavirus'],
#  ['Rep',
#   'Elise',
#   'Stefanik',
#   'NY',
#   '21',
#   'On',
#   'Slow',
#   'Pace',
#   'Of',
#   'Coronavirus',
#   'Testing',
#   'There',
#   'Is',
#   'No',
#   'Explanation',
#   'For',
#   'Lack',
#   'Of',
#   'Testing'],
#  ['Stock',
#   'market',
#   'woes',
#   'Virus',
#   'fears',
#   'lead',
#   'to',
#   'worst',
#   'week',
#   'since',
#   'financial',
#   'crisis'],
#  ['Dr',
#   'Peter',
#   'Hotez',
#   'As',
#   'coronavirus',
#   'spreads',
#   'the',
#   'U',
#   'S',
#   'is',
#   'not',
#   'fully',
#   'prepared',
#   'but',
#   'here',
#   'is',
#   'how',
#   'we',
#   'can',
#   'be'],
#  ['Are', 'pregnant', 'women', 'at', 'risk', 'for', 'coronavirus'],
#  ['Dr',
#   'William',
#   'Haseltine',
#   '4',
#   'coronavirus',
#   'prevention',
#   'steps',
#   'we',
#   'can',
#   'all',
#   'take'],
#  ['Tokyo',
#   'organizers',
#   'government',
#   'take',
#   'offensive',
#   'on',
#   'virus',
#   'threat'],
#  ['Italian',
#   'soccer',
#   'could',
#   'be',
#   'played',
#   'without',
#   'fans',
#   'because',
#   'of',
#   'virus'],
#  ['Asian',
#   'baseball',
#   'soccer',
#   'rugby',
#   'affected',
#   'by',
#   'new',
#   'China',
#   'virus'],
#  ['Virus',
#   'cases',
#   'in',
#   'South',
#   'Korea',
#   'delays',
#   'table',
#   'tennis',
#   'team',
#   'world',
#   'champs'],
#  ['Dog',
#   'tests',
#   'weak',
#   'positive',
#   'for',
#   'coronavirus',
#   'in',
#   'Hong',
#   'Kong',
#   'first',
#   'possible',
#   'infection',
#   'in',
#   'pet'],
#  ['Brazil',
#   'confirms',
#   'first',
#   'coronavirus',
#   'case',
#   'in',
#   'Latin',
#   'America'],
#  ['Hawaiian',
#   'Airlines',
#   'temporarily',
#   'suspends',
#   'all',
#   'service',
#   'to',
#   'South',
#   'Korea',
#   'due',
#   'to',
#   'a',
#   'spike',
#   'in',
#   'coronavirus',
#   'cases'],
#  ['Some',
#   'discharged',
#   'coronavirus',
#   'patients',
#   'in',
#   'China',
#   'test',
#   'positive',
#   'for',
#   'second',
#   'time',
#   'report'],
#  ['Coronavirus',
#   'fears',
#   'send',
#   'face',
#   'mask',
#   'prices',
#   'skyrocketing',
#   'prompt',
#   'warnings',
#   'about',
#   'price',
#   'gouging'],
#  ['Coronavirus',
#   'epidemic',
#   'fears',
#   'shuts',
#   'down',
#   'France',
#   's',
#   'Louvre',
#   'Museum'],
#  ['Coronavirus',
#   'lockdown',
#   'in',
#   'China',
#   'prevents',
#   'young',
#   'boy',
#   'from',
#   'leaving',
#   'home',
#   'where',
#   'grandfather',
#   'died',
#   'report'],
#  ['WHO',
#   'says',
#   'coronavirus',
#   'absolutely',
#   'has',
#   'potential',
#   'for',
#   'pandemic',
#   'status',
#   'as',
#   'Italy',
#   'Iran',
#   'brace',
#   'for',
#   'surge'],
#  ['Sean',
#   'Hannity',
#   'accuses',
#   'Dems',
#   'of',
#   'weaponizing',
#   'coronavirus',
#   'to',
#   'score',
#   'cheap',
#   'repulsive',
#   'political',
#   'points'],
#  ['IOC',
#   'senior',
#   'member',
#   '3',
#   'months',
#   'to',
#   'decide',
#   'fate',
#   'of',
#   'Tokyo',
#   'Olympics'],
#  ['Sen',
#   'John',
#   'Kennedy',
#   'walks',
#   'back',
#   'earlier',
#   'criticism',
#   'of',
#   'Trump',
#   'admin',
#   's',
#   'handling',
#   'of',
#   'coronavirus',
#   'I',
#   'm',
#   'very',
#   'pleased'],
#  ['Dr',
#   'Marc',
#   'Siegel',
#   'warns',
#   'of',
#   'coronavirus',
#   'community',
#   'spread',
#   'but',
#   'says',
#   'patients',
#   'responding',
#   'to',
#   'treatments'],
#  ['Cuccinelli',
#   'won',
#   't',
#   'rule',
#   'out',
#   'startling',
#   'theory',
#   'on',
#   'coronavirus',
#   'origins',
#   'We',
#   'are',
#   'not',
#   'entirely',
#   'sure',
#   'yet'],
#  ['Social',
#   'media',
#   'revives',
#   'speculation',
#   'that',
#   'Dean',
#   'Koontz',
#   'novel',
#   'predicted',
#   'disease',
#   'similar',
#   'to',
#   'coronavirus'],
#  ['More', 'sporting', 'events', 'affected', 'by', 'spreading', 'virus'],
#  ['Former', 'Denmark', 'soccer', 'player', 'quarantined', 'with', 'virus'],
#  ['Ingraham', 'Contain', 'the', 'virus', 'protect', 'our', 'freedom'],
#  ['Virus',
#   'cancellations',
#   'send',
#   'Olympic',
#   'beach',
#   'hopefuls',
#   'scrambling'],
#  ['Iran',
#   's',
#   'coronavirus',
#   'task',
#   'force',
#   'head',
#   'contracts',
#   'illness',
#   'as',
#   'country',
#   's',
#   'death',
#   'toll',
#   'reaches',
#   '15'],
#  ['Betsy',
#   'McCaughey',
#   'Coronavirus',
#   'lies',
#   'endanger',
#   'us',
#   'all',
#   '3',
#   'practical',
#   'steps',
#   'the',
#   'government',
#   'should',
#   'take',
#   'now'],
#  ['Nebraska',
#   'nurse',
#   'overseeing',
#   'quarantine',
#   'of',
#   'US',
#   'coronavirus',
#   'patients',
#   'says',
#   'they',
#   'are',
#   'doing',
#   'very',
#   'well'],
#  ['Washington',
#   'high',
#   'school',
#   'closed',
#   'over',
#   'coronavirus',
#   'concerns',
#   'after',
#   'staff',
#   'member',
#   's',
#   'relative',
#   'is',
#   'tested',
#   'for',
#   'virus'],
#  ['Coronavirus',
#   'disruption',
#   'to',
#   'everyday',
#   'life',
#   'in',
#   'US',
#   'might',
#   'be',
#   'severe',
#   'CDC',
#   'official',
#   'says'],
#  ['Iran',
#   's',
#   'vice',
#   'president',
#   'contracts',
#   'coronavirus',
#   'as',
#   'country',
#   's',
#   'tally',
#   'spikes',
#   'again'],
#  ['NBC',
#   'News',
#   'Richard',
#   'Engel',
#   'takes',
#   'heat',
#   'for',
#   'saying',
#   'coronavirus',
#   'is',
#   'a',
#   'bat',
#   'virus',
#   'not',
#   'a',
#   'China',
#   'virus'],
#  ['CDC',
#   'director',
#   'says',
#   'coronavirus',
#   'threat',
#   'in',
#   'US',
#   'remains',
#   'low',
#   'but',
#   'warns',
#   'there',
#   'will',
#   'be',
#   'new',
#   'cases'],
#  ['Trump',
#   'administration',
#   'expected',
#   'to',
#   'ask',
#   'Congress',
#   'for',
#   '1B',
#   'to',
#   'combat',
#   'coronavirus'],
#  ['Denmark',
#   'sees',
#   'first',
#   'coronavirus',
#   'case',
#   'in',
#   'man',
#   'returning',
#   'from',
#   'Italy',
#   'vacation'],
#  ['Varney',
#   'Dems',
#   'drumming',
#   'up',
#   'panic',
#   'about',
#   'coronavirus',
#   'driving',
#   'down',
#   'markets'],
#  ['Tucker',
#   'Carlson',
#   'says',
#   'coronavirus',
#   'response',
#   'shows',
#   'how',
#   'identity',
#   'politics',
#   'trumped',
#   'public',
#   'health'],
#  ['US',
#   'intelligence',
#   'agencies',
#   'monitoring',
#   'worldwide',
#   'spread',
#   'of',
#   'coronavirus',
#   'concerns',
#   'in',
#   'India',
#   'Iran',
#   'report'],
#  ['Trump',
#   'addresses',
#   'coronavirus',
#   'in',
#   'primetime',
#   'news',
#   'conference',
#   'as',
#   'fears',
#   'of',
#   'US',
#   'outbreak',
#   'spread'],
#  ['1st',
#   'coronavirus',
#   'case',
#   'of',
#   'unknown',
#   'origin',
#   'in',
#   'US',
#   'was',
#   'hospitalized',
#   'for',
#   'days',
#   'before',
#   'being',
#   'tested',
#   'officials'],
#  ['Dr',
#   'Anthony',
#   'Fauci',
#   'tells',
#   'public',
#   'to',
#   'be',
#   'prepared',
#   'for',
#   'coronavirus',
#   'but',
#   'still',
#   'do',
#   'the',
#   'things',
#   'you',
#   'always',
#   'do'],
#  ['Trump',
#   'holds',
#   'rally',
#   'in',
#   'North',
#   'Charleston',
#   'on',
#   'eve',
#   'of',
#   'Dems',
#   'South',
#   'Carolina',
#   'primary'],
#  ['CDC',
#   'issues',
#   'coronavirus',
#   'warning',
#   'against',
#   'nonessential',
#   'South',
#   'Korea',
#   'travel'],
#  ['Dr',
#   'Manny',
#   'Alvarez',
#   'Coronavirus',
#   'How',
#   'to',
#   'prepare',
#   'and',
#   'protect',
#   'yourself',
#   'as',
#   'US',
#   'gears',
#   'up',
#   'to',
#   'fight',
#   'it'],
#  ['Dr',
#   'Siegel',
#   'reports',
#   'from',
#   'Nebraska',
#   'biocontainment',
#   'facility',
#   'Coronavirus',
#   'may',
#   'be',
#   'more',
#   'contagious',
#   'than',
#   'the',
#   'flu'],
#  ['Tucker',
#   'Carlson',
#   'sounds',
#   'the',
#   'alarm',
#   'America',
#   'is',
#   'not',
#   'ready',
#   'for',
#   'the',
#   'coronavirus'],
#  ['Some',
#   'human',
#   'coronaviruses',
#   'can',
#   'live',
#   'on',
#   'surfaces',
#   'for',
#   '9',
#   'days',
#   'study',
#   'finds'],
#  ['Oregon',
#   'coronavirus',
#   'patient',
#   'is',
#   'grade',
#   'school',
#   'employee',
#   'school',
#   'closed',
#   'for',
#   'deep',
#   'cleaning',
#   'officials',
#   'say'],
#  ['Pelosi',
#   'tours',
#   'San',
#   'Francisco',
#   's',
#   'Chinatown',
#   'in',
#   'attempt',
#   'to',
#   'ease',
#   'fears',
#   'of',
#   'coronavirus'],
#  ['Could',
#   'coronavirus',
#   'become',
#   'a',
#   'pandemic',
#   'What',
#   'to',
#   'know',
#   'about',
#   'the',
#   'classification'],
#  ['Gutfeld', 'on', 'Bernie', 's', 'non', 'plan', 'for', 'the', 'virus'],
#  ['Journalists',
#   'fear',
#   'contracting',
#   'virus',
#   'as',
#   'coverage',
#   'increasingly',
#   'criticized'],
#  ['Dream',
#   'denied',
#   'Virus',
#   'dashes',
#   'Dayton',
#   's',
#   'magical',
#   'hoops',
#   'season'],
#  ['Pistons', 'Christian', 'Wood', 'tests', 'positive', 'for', 'virus', 'AP'],
#  ['Wife',
#   'of',
#   'Spain',
#   's',
#   'prime',
#   'minister',
#   'tests',
#   'positive',
#   'for',
#   'virus'],
#  ['Tokyo',
#   'calls',
#   'off',
#   'test',
#   'event',
#   'growing',
#   'virus',
#   'threatens',
#   'Olympics'],
#  ['Vail',
#   'Alterra',
#   'close',
#   '49',
#   'ski',
#   'resorts',
#   'amid',
#   'virus',
#   'outbreak'],
#  ['With',
#   'season',
#   'in',
#   'doubt',
#   'Japan',
#   's',
#   'baseball',
#   'taps',
#   'virus',
#   'experts'],
#  ['With',
#   'virus',
#   'in',
#   'mind',
#   'Korea',
#   's',
#   'Sungjae',
#   'Im',
#   'wins',
#   'Honda',
#   'Classic'],
#  ['World',
#   'Cup',
#   'skiing',
#   'finals',
#   'in',
#   'Cortina',
#   'canceled',
#   'because',
#   'of',
#   'virus'],
#  ['Member',
#   'of',
#   'Iranian',
#   'clerical',
#   'assembly',
#   'dies',
#   'from',
#   'virus',
#   'Reports'],
#  ['Across',
#   'faiths',
#   'religious',
#   'rules',
#   'bent',
#   'as',
#   'virus',
#   'alters',
#   'worship'],
#  ['Virus',
#   'at',
#   'Iran',
#   's',
#   'gates',
#   'How',
#   'Tehran',
#   'failed',
#   'to',
#   'stop',
#   'outbreak'],
#  ['CRAMER', 'SUSPEND', 'TAX', 'COLLECTION'],
#  ['Shoot',
#   'Stray',
#   'Dogs',
#   'Win',
#   'Cash',
#   'Prizes',
#   'How',
#   'Chinese',
#   'Officials',
#   'Slaughtered',
#   'Canines'],
#  ['Scientist',
#   'Coronavirus',
#   'Not',
#   'Airborne',
#   'but',
#   'Extremely',
#   'Contagious'],
#  ['Italy',
#   's',
#   'Patient',
#   'One',
#   'Forced',
#   'to',
#   'Wait',
#   '36',
#   'Hours',
#   'Before',
#   'Being',
#   'Tested',
#   'for',
#   'Coronavirus'],
#  ['Coronavirus',
#   'Wuhan',
#   'Football',
#   'Team',
#   'Stuck',
#   'In',
#   'Spain',
#   'for',
#   'Months'],
#  ['UK',
#   'Schools',
#   'Close',
#   'as',
#   'Two',
#   'More',
#   'Coronavirus',
#   'Cases',
#   'Confirmed'],
#  ['Nigeria',
#   'Africa',
#   's',
#   'Most',
#   'Populous',
#   'Country',
#   'Confirms',
#   'First',
#   'Case',
#   'of',
#   'Coronavirus'],
#  ['Unwieldy',
#   'Anti',
#   'Stigma',
#   'Coronavirus',
#   'Names',
#   'Confuse',
#   'Indonesian',
#   'Official'],
#  ['NBC',
#   's',
#   'Engel',
#   'Coronavirus',
#   'Is',
#   'a',
#   'Bat',
#   'Virus',
#   'Not',
#   'a',
#   'China',
#   'Virus'],
#  ['Iran',
#   'Lawmaker',
#   'Regime',
#   'Lying',
#   'About',
#   'Uncontrolled',
#   'China',
#   'Virus',
#   'Spread',
#   '50',
#   'Dead'],
#  ['Study',
#   'China',
#   'Lied',
#   'Wuhan',
#   'Virus',
#   'Did',
#   'Not',
#   'Originate',
#   'in',
#   'Meat',
#   'Market'],
#  ['Xi',
#   'Jinping',
#   'Berates',
#   '170',
#   '000',
#   'Communists',
#   'for',
#   'Obvious',
#   'Shortcomings',
#   'Against',
#   'Coronavirus'],
#  ['Mike',
#   'Pence',
#   'on',
#   'Coronavirus',
#   'The',
#   'Average',
#   'American',
#   'Does',
#   'Not',
#   'Need',
#   'to',
#   'Go',
#   'Out',
#   'and',
#   'Buy',
#   'a',
#   'Mask'],
#  ['Mullah',
#   's',
#   'Virus',
#   'Iranian',
#   'Protesters',
#   'Condemn',
#   'Regime',
#   'for',
#   'Coronavirus',
#   'Response',
#   'Failure'],
#  ['Hillary',
#   'Clinton',
#   'Saying',
#   'Chinese',
#   'Virus',
#   'Is',
#   'Racist',
#   'Rhetoric'],
#  ['83',
#   'New',
#   'Yorkers',
#   'in',
#   'Voluntary',
#   'Isolation',
#   'for',
#   'Coronavirus',
#   'Testing'],
#  ['Coronavirus',
#   'Study',
#   'One',
#   'Traveler',
#   'from',
#   'China',
#   'Infected',
#   '39',
#   'People',
#   'in',
#   'Washington',
#   'State'],
#  ['Expert',
#   'Chinese',
#   'Scientists',
#   'Sell',
#   'Lab',
#   'Animals',
#   'as',
#   'Meat',
#   'on',
#   'the',
#   'Black',
#   'Market'],
#  ['Watch',
#   'Donald',
#   'Trump',
#   'Calling',
#   'Coronavirus',
#   'Chinese',
#   'Virus',
#   'or',
#   'Kung',
#   'Flu',
#   'Is',
#   'Not',
#   'Racist',
#   'at',
#   'All'],
#  ['Italian',
#   'Man',
#   'with',
#   'Coronavirus',
#   'Who',
#   'Hid',
#   'Symptoms',
#   'Faces',
#   '12',
#   'Years',
#   'in',
#   'Prison'],
#  ['Rudy',
#   'Gobert',
#   'Apologizes',
#   'for',
#   'Being',
#   'Careless',
#   'About',
#   'Coronavirus'],
#  ['Florida',
#   'Man',
#   'with',
#   'Coronavirus',
#   'Credits',
#   'Drug',
#   'Touted',
#   'by',
#   'Trump',
#   'for',
#   'Saving',
#   'His',
#   'Life'],
#  ['France',
#   'and',
#   'Germany',
#   'Close',
#   'Schools',
#   'in',
#   'Coronavirus',
#   'Cluster',
#   'Zones'],
#  ['Donald',
#   'Trump',
#   'U',
#   'S',
#   'Economy',
#   'May',
#   'Be',
#   'Headed',
#   'for',
#   'a',
#   'Recession'],
#  ['Boris',
#   'Reveals',
#   'Coronavirus',
#   'Battle',
#   'Plan',
#   'More',
#   'Outbreaks',
#   'Highly',
#   'Likely',
#   'But',
#   'for',
#   'Now',
#   'It',
#   's',
#   'Business',
#   'as',
#   'Usual',
#   'for',
#   'Britain'],
#  ['Nolte',
#   'A',
#   'Mere',
#   '8',
#   'Days',
#   'Ago',
#   'Joe',
#   'Biden',
#   'Was',
#   'Still',
#   'Attacking',
#   'Trump',
#   's',
#   'Travel',
#   'Bans'],
#  ['U',
#   'of',
#   'Washington',
#   'Professor',
#   'Dies',
#   'of',
#   'Chinese',
#   'Coronavirus'],
#  ['Oprah', 'Launches', 'Apple', 'TV', 'Series', 'About', 'Coronavirus'],
#  ['Donald',
#   'Trump',
#   'Plans',
#   'Address',
#   'to',
#   'the',
#   'Nation',
#   'in',
#   'Response',
#   'to',
#   'Coronavirus'],
#  ['France',
#   'Goes',
#   'Ahead',
#   'with',
#   'Local',
#   'and',
#   'Mayoral',
#   'Elections',
#   'Despite',
#   'Pandemic'],
#  ['Actor',
#   'Josh',
#   'Gad',
#   'Defends',
#   'NBC',
#   's',
#   'Peter',
#   'Alexander',
#   'Our',
#   'President',
#   'Is',
#   'a',
#   'Pig',
#   'Rolling',
#   'in',
#   'S',
#   't'],
#  ['NBA',
#   'Says',
#   'Virus',
#   'Hiatus',
#   'Will',
#   'Likely',
#   'Last',
#   'At',
#   'Least',
#   'a',
#   'Month'],
#  ['Tucker',
#   'Carlson',
#   'Colleges',
#   'Will',
#   'Be',
#   'Forced',
#   'to',
#   'Reform',
#   'After',
#   'Chinese',
#   'Virus',
#   'Shutdowns'],
#  ['LA',
#   'Times',
#   'Smacks',
#   'Elon',
#   'Musk',
#   'for',
#   'Trying',
#   'to',
#   'Build',
#   'Luxury',
#   'Cars',
#   'During',
#   'Chinese',
#   'Virus',
#   'Lockdown'],
#  ['Coronavirus',
#   'Italy',
#   'Total',
#   'Death',
#   'Toll',
#   'Rises',
#   '11',
#   'Percent',
#   'in',
#   '24',
#   'Hours',
#   'Exceeds',
#   '6',
#   '000'],
#  ['5',
#   'Reasons',
#   'to',
#   'Doubt',
#   'China',
#   's',
#   'Claim',
#   'It',
#   'Has',
#   'Stopped',
#   'Seeing',
#   'Coronavirus',
#   'Cases'],
#  ['Europe',
#   'in',
#   'Crisis',
#   'Nations',
#   'Across',
#   'the',
#   'Continent',
#   'Grapple',
#   'with',
#   'Growing',
#   'Coronavirus',
#   'Pandemic'],
#  ['Twitter',
#   'Lets',
#   'Elon',
#   'Musk',
#   'Post',
#   'Coronavirus',
#   'Misinformation',
#   'Despite',
#   'Strict',
#   'Policy',
#   'Against',
#   'It'],
#  ['Donald',
#   'Trump',
#   'Coronavirus',
#   'Very',
#   'Much',
#   'Under',
#   'Control',
#   'in',
#   'United',
#   'States'],
#  ['Pathogens',
#   'Expert',
#   'Praises',
#   'CDC',
#   'for',
#   'Expanding',
#   'Coronavirus',
#   'Testing',
#   'in',
#   'U',
#   'S'],
#  ['1',
#   '000',
#   'Tourists',
#   'Quarantined',
#   'in',
#   'Canary',
#   'Islands',
#   'Hotel',
#   'After',
#   'Coronavirus',
#   'Confirmed'],
#  ['Limbaugh',
#   'Coronavirus',
#   'Being',
#   'Weaponized',
#   'to',
#   'Bring',
#   'Down',
#   'Trump'],
#  ['Ohio',
#   'Health',
#   'Director',
#   'Walks',
#   'Back',
#   'Wild',
#   'Estimate',
#   'of',
#   '100',
#   '000',
#   'Coronavirus',
#   'Infections',
#   'in',
#   'State'],
#  ['China', 'Threatens', 'EMP', 'Attack', 'in', 'South', 'China', 'Sea'],
#  ['15',
#   'Times',
#   'Establishment',
#   'Media',
#   'Used',
#   'Bigoted',
#   'Phrases',
#   'to',
#   'Refer',
#   'to',
#   'the',
#   'Coronavirus'],
#  ['Susan',
#   'Rice',
#   'China',
#   'Not',
#   'Behaving',
#   'Well',
#   'in',
#   'Blaming',
#   'U',
#   'S',
#   'for',
#   'Coronavirus',
#   'U',
#   'S',
#   'Isn',
#   't',
#   'Behaving',
#   'Well',
#   'When',
#   'Trump',
#   'Uses',
#   'Racist',
#   'Descriptions'],
#  ['Four',
#   'Olympic',
#   'Athletes',
#   'Quarantined',
#   'After',
#   'Coronavirus',
#   'Exposure'],
#  ['White',
#   'House',
#   'Donald',
#   'Trump',
#   'Has',
#   'Not',
#   'Been',
#   'Tested',
#   'for',
#   'Coronavirus'],
#  ['Scarborough',
#   'Trump',
#   'Admin',
#   'Coronavirus',
#   'Stupidity',
#   'Will',
#   'Get',
#   'Americans',
#   'Killed'],
#  ['Sweden', 'Tests', 'Ebola', 'Medication', 'on', 'Coronavirus', 'Patients'],
#  ['State',
#   'of',
#   'Emergency',
#   'Declared',
#   'in',
#   'Washington',
#   'State',
#   'Over',
#   'Coronavirus'],
#  ['Tom',
#   'Steyer',
#   'Coronavirus',
#   'Proves',
#   'Trump',
#   'Incompetent',
#   'on',
#   'Economy'],
#  ['Donald',
#   'Trump',
#   'Promises',
#   'Victory',
#   'Over',
#   'Coronavirus',
#   'America',
#   'Will',
#   'Get',
#   'It',
#   'Done'],
#  ['Watch',
#   'Ayanna',
#   'Pressley',
#   'The',
#   'Term',
#   'Chinese',
#   'Coronavirus',
#   'Is',
#   'Painful',
#   'for',
#   'Immigrants'],
#  ['Donald',
#   'Trump',
#   'Declares',
#   'National',
#   'Emergency',
#   'over',
#   'Coronavirus'],
#  ['Study',
#   '86',
#   'Percent',
#   'Infected',
#   'with',
#   'Coronavirus',
#   'in',
#   'Public',
#   'Are',
#   'Undetected'],
#  ['Watch',
#   'Live',
#   'President',
#   'Trump',
#   's',
#   'Coronavirus',
#   'Task',
#   'Force',
#   'Speaks',
#   'to',
#   'the',
#   'Press'],
#  ['Ann', 'Coulter', 'Cheap', 'TVs', 'Expensive', 'Flu'],
#  ['Donald',
#   'Trump',
#   'Unfortunate',
#   'China',
#   'Was',
#   'Very',
#   'Very',
#   'Secretive',
#   'About',
#   'Coronavirus'],
#  ['Federally',
#   'Funded',
#   'Studies',
#   'Show',
#   'Coronavirus',
#   'Survives',
#   'Hours',
#   'Airborne'],
#  ['Video',
#   'of',
#   'Italian',
#   'Obituaries',
#   'Puts',
#   'Coronavirus',
#   'Death',
#   'Toll',
#   'into',
#   'Perspective'],
#  ['Star',
#   'Forward',
#   'Kevin',
#   'Durant',
#   'Among',
#   'Four',
#   'Brooklyn',
#   'Nets',
#   'Players',
#   'to',
#   'Test',
#   'Positive',
#   'for',
#   'Coronavirus'],
#  ['Donald',
#   'Trump',
#   'Coronavirus',
#   'Could',
#   'Last',
#   'Until',
#   'July',
#   'or',
#   'August'],
#  ['Venezuela',
#   'Maduro',
#   'Imports',
#   'Cuban',
#   'Doctors',
#   'Imposes',
#   'Chinese',
#   'Coronavirus',
#   'Quarantine'],
#  ['Actress',
#   'Evangeline',
#   'Lilly',
#   'Dismisses',
#   'Social',
#   'Distance',
#   'Warnings',
#   'While',
#   'Living',
#   'with',
#   'Her',
#   'Cancer',
#   'Stricken',
#   'Father'],
#  ['Taliban',
#   'Coronavirus',
#   'a',
#   'Decree',
#   'of',
#   'Allah',
#   'Because',
#   'of',
#   'the',
#   'Sins',
#   'of',
#   'Mankind'],
#  ['Report',
#   'Nebraska',
#   'Coach',
#   'Hospitalized',
#   'After',
#   'Appearing',
#   'Extremely',
#   'Ill',
#   'Team',
#   'Quarantined'],
#  ['Donald',
#   'Trump',
#   'Americans',
#   'Should',
#   'Keep',
#   'Gatherings',
#   'Under',
#   'Ten',
#   'People',
#   'to',
#   'Defeat',
#   'Coronavirus'],
#  ['Donald',
#   'Trump',
#   'Shakes',
#   'Hands',
#   'with',
#   'Supporters',
#   'Despite',
#   'Coronavirus',
#   'Fears'],
#  ['Rapper',
#   'Drake',
#   'Self',
#   'Quarantining',
#   'After',
#   'Partying',
#   'with',
#   'Coronavirus',
#   'Positive',
#   'NBA',
#   'Star',
#   'Kevin',
#   'Durant'],
#  ['Ohio',
#   'Hit',
#   'with',
#   '3',
#   'Coronavirus',
#   'Cases',
#   'Governor',
#   'DeWine',
#   'Declares',
#   'State',
#   'of',
#   'Emergency'],
#  ['Elderly',
#   'Cleric',
#   'Becomes',
#   'First',
#   'Coronavirus',
#   'Death',
#   'in',
#   'Iraq'],
#  ['WATCH',
#   'Brazil',
#   's',
#   'Christ',
#   'the',
#   'Redeemer',
#   'Statue',
#   'Lit',
#   'Up',
#   'with',
#   'Flags',
#   'of',
#   'Countries',
#   'Affected',
#   'by',
#   'Coronavirus'],
#  ['Video',
#   'Italian',
#   'Actor',
#   'Pleads',
#   'for',
#   'Help',
#   'After',
#   'Sister',
#   'Dies',
#   'from',
#   'Coronavirus',
#   'Italy',
#   'Has',
#   'Abandoned',
#   'Us'],
#  ['Joe',
#   'Biden',
#   'Demands',
#   'Trump',
#   'Invoke',
#   'Defense',
#   'Production',
#   'Act',
#   'Minutes',
#   'After',
#   'President',
#   'Does'],
#  ['Hawaii',
#   'Orders',
#   'Mandatory',
#   '14',
#   'Day',
#   'Quarantine',
#   'for',
#   'Visitors',
#   'Returning',
#   'Residents'],
#  ['UK',
#   'Wartime',
#   'style',
#   'Four',
#   'Month',
#   'Elderly',
#   'Quarantine',
#   'Planned'],
#  ['Coronavirus',
#   'Dr',
#   'Fauci',
#   'Applauds',
#   'Flight',
#   'Cancellations',
#   'That',
#   'World',
#   'Health',
#   'Organization',
#   'Discouraged'],
#  ['Exclusive',
#   'Newt',
#   'Gingrich',
#   'on',
#   'Coronavirus',
#   'Crisis',
#   'Live',
#   'from',
#   'Rome',
#   'Turmoil',
#   'Forcing',
#   'Rethinking',
#   'Lots',
#   'of',
#   'Things'],
#  ['Donald',
#   'Trump',
#   'Delights',
#   'CPAC',
#   'Crowd',
#   'with',
#   'Election',
#   'Year',
#   'Performance',
#   'See',
#   'You',
#   'Next',
#   'Year'],
#  ['Watch',
#   'Live',
#   'The',
#   'White',
#   'House',
#   'Coronavirus',
#   'Task',
#   'Force',
#   'Holds',
#   'a',
#   'Press',
#   'Briefing'],
#  ['Conway',
#   'CDC',
#   'Guidelines',
#   'Will',
#   'Mitigate',
#   'this',
#   'Health',
#   'Crisis',
#   'Literally',
#   'Save',
#   'Lives'],
#  ['Whoopi',
#   'Goldberg',
#   'on',
#   'Coronavirus',
#   'Mother',
#   'Nature',
#   'Did',
#   'This',
#   'to',
#   'Us',
#   'Not',
#   'China'],
#  ['Police',
#   'Man',
#   'Arrested',
#   'for',
#   'Lying',
#   'About',
#   'Having',
#   'Coronavirus',
#   'to',
#   'Get',
#   'Paid',
#   'Vacation'],
#  ['Morning',
#   'Joe',
#   'on',
#   'Coronavirus',
#   'Sociopathic',
#   'Trump',
#   'Actively',
#   'Working',
#   'to',
#   'Tank',
#   'the',
#   'Stock',
#   'Market'],
#  ['Model',
#   'Kaia',
#   'Gerber',
#   'Is',
#   'Social',
#   'Distancing',
#   'Outside',
#   'Surrounded',
#   'by',
#   'Celebrity',
#   'Friends'],
#  ['Coronavirus',
#   'Federal',
#   'Judge',
#   'Rules',
#   'Migrants',
#   'Must',
#   'Stay',
#   'in',
#   'Detention',
#   'Center'],
#  ['FDA',
#   'Urged',
#   'to',
#   'Approve',
#   'Chloroquine',
#   'to',
#   'Treat',
#   'COVID',
#   '19'],
#  ['The',
#   'Road',
#   'to',
#   'Lockdown',
#   'How',
#   'Britain',
#   'Went',
#   'From',
#   'Coronavirus',
#   'Light',
#   'Touch',
#   'to',
#   'National',
#   'House',
#   'Arrest'],
#  ['China',
#   'Pushes',
#   'Propaganda',
#   'that',
#   'U',
#   'S',
#   'Created',
#   'the',
#   'Coronavirus'],
#  ['China',
#   's',
#   'Attempt',
#   'to',
#   'Return',
#   'Coronavirus',
#   'Origin',
#   'Province',
#   'to',
#   'Normalcy',
#   'Fails'],
#  ['Bolsonaro',
#   'Brazil',
#   'Winning',
#   'Soccer',
#   'Match',
#   'Against',
#   'Coronavirus',
#   'Thanks',
#   'to',
#   'Coach',
#   'Bolsonaro'],
#  ['CDC',
#   'Recommends',
#   'Canceling',
#   'Postponing',
#   'Gatherings',
#   'of',
#   'over',
#   '50',
#   'People'],
#  ['Ohio',
#   'and',
#   'Illinois',
#   'Announce',
#   'Closure',
#   'of',
#   'Restaurants',
#   'and',
#   'Bars',
#   'amid',
#   'Coronavirus',
#   'Pandemic'],
#  ['Celtics',
#   'Marcus',
#   'Smart',
#   'Two',
#   'Lakers',
#   'Test',
#   'Positive',
#   'for',
#   'Coronavirus'],
#  ['UCLA',
#   'Duke',
#   'Join',
#   'Growing',
#   'List',
#   'of',
#   'Coronavirus',
#   'Campus',
#   'Closures'],
#  ['Lindsey',
#   'Graham',
#   'Absolutely',
#   'No',
#   'EB',
#   '5',
#   'Green',
#   'Card',
#   'Expansion',
#   'in',
#   'Coronavirus',
#   'Bill'],
#  ['Biden',
#   's',
#   'Coronavirus',
#   'Proposal',
#   'Cribs',
#   'Heavily',
#   'from',
#   'Trump',
#   'Administration'],
#  ['Iranian',
#   'President',
#   'Contradicts',
#   'Ayatollah',
#   'Urges',
#   'Serious',
#   'Concern',
#   'over',
#   'Chinese',
#   'Coronavirus'],
#  ['Watch',
#   'Live',
#   'President',
#   'Donald',
#   'Trump',
#   'Gives',
#   'Oval',
#   'Office',
#   'Address',
#   'to',
#   'Nation',
#   'on',
#   'Coronavirus'],
#  ['Bernie', 'Sanders', 'Predicts', 'Win', 'in', 'Michigan', 'Primary'],
#  ['Joe', 'Biden', 'Projected', 'Winner', 'of', 'Maine', 'Primary'],
#  ['Plouffe',
#   'Either',
#   'Bernie',
#   'Sanders',
#   'or',
#   'Joe',
#   'Biden',
#   'Will',
#   'Be',
#   'the',
#   'Nominee'],
#  ['Carville',
#   'Shut',
#   'This',
#   'Puppy',
#   'Down',
#   'Biden',
#   'Won',
#   'Sanders',
#   'Has',
#   'to',
#   'Respect',
#   'The',
#   'Voters'],
#  ['Carville',
#   'Klobuchar',
#   'and',
#   'Buttigieg',
#   'Will',
#   'Probably',
#   'Be',
#   'Out',
#   'by',
#   'Wednesday'],
#  ['Best',
#   'Presidential',
#   'Candidate',
#   'in',
#   '40',
#   'Years',
#   'Michael',
#   'Douglas',
#   'Hits',
#   'the',
#   'Campaign',
#   'Trail',
#   'for',
#   'Bloomberg'],
#  ['Jussie',
#   'Smollett',
#   'Prosecutor',
#   'Kim',
#   'Foxx',
#   'Fends',
#   'Off',
#   'Primary',
#   'Challengers'],
#  ['Joe',
#   'Biden',
#   'Declared',
#   'Winner',
#   'of',
#   'Missouri',
#   's',
#   'Democrat',
#   'Primary',
#   'Race'],
#  ['Democrats',
#   'Condemn',
#   'Bernie',
#   'Sanders',
#   'Praise',
#   'of',
#   'Fidel',
#   'Castro',
#   'Absolutely',
#   'Unacceptable'],
#  ['Poll',
#   'Bernie',
#   'Sanders',
#   'Takes',
#   'National',
#   'Lead',
#   'Among',
#   'Black',
#   'Voters'],
#  ['McCaskill',
#   'Biden',
#   's',
#   'Confrontation',
#   'with',
#   'Voter',
#   'Will',
#   'Help',
#   'Him',
#   'with',
#   'White',
#   'Non',
#   'College',
#   'Voters'],
#  ['Biden',
#   'Deputy',
#   'Manager',
#   'Bedingfield',
#   'on',
#   'Voter',
#   'Confrontation',
#   'Voters',
#   'Are',
#   'Looking',
#   'for',
#   'Someone',
#   'Who',
#   'Won',
#   't',
#   'Allow',
#   'Distortions'],
#  ['Poll',
#   'Joe',
#   'Biden',
#   's',
#   'National',
#   'Lead',
#   'Shrinks',
#   'to',
#   'Single',
#   'Digits'],
#  ['James',
#   'Comey',
#   'Endorses',
#   'and',
#   'Votes',
#   'for',
#   'Joe',
#   'Biden',
#   'in',
#   'Virginia'],
#  ['UK',
#   'Schools',
#   'Close',
#   'as',
#   'Two',
#   'More',
#   'Coronavirus',
#   'Cases',
#   'Confirmed'],
#  ['Trump',
#   'Mike',
#   'Bloomberg',
#   's',
#   'Failed',
#   'Campaign',
#   'Worst',
#   'and',
#   'Most',
#   'Embarrassing',
#   'Experience',
#   'of',
#   'His',
#   'Life'],
#  ['Harvard',
#   'Counsels',
#   'Students',
#   'to',
#   'Combat',
#   'Coronavirus',
#   'Anxiety',
#   'with',
#   'Yoga'],
#  ['CNN',
#   'Guest',
#   'I',
#   'Think',
#   'There',
#   'Is',
#   'Nobody',
#   'Here',
#   'That',
#   'Does',
#   'Not',
#   'Want',
#   'Donald',
#   'Trump',
#   'to',
#   'Be',
#   'Defeated'],
#  ['Bill',
#   'de',
#   'Blasio',
#   'Warns',
#   'Joe',
#   'Biden',
#   'Hasn',
#   't',
#   'Been',
#   'Vetted'],
#  ['Bernie',
#   'Sanders',
#   'Vows',
#   'to',
#   'Debate',
#   'Biden',
#   '1',
#   'on',
#   '1',
#   'Won',
#   't',
#   'Drop',
#   'Out',
#   'After',
#   'Michigan',
#   'Defeat'],
#  ['Video',
#   'Tom',
#   'Steyer',
#   'Dances',
#   'to',
#   'Back',
#   'That',
#   'Azz',
#   'Up',
#   'With',
#   'Rapper',
#   'Juvenile'],
#  ['Carville',
#   'There',
#   'Will',
#   'Be',
#   'Calls',
#   'for',
#   'Sanders',
#   'to',
#   'Exit',
#   'Clyburn',
#   'Saved',
#   'the',
#   'Democratic',
#   'Party'],
#  ['Rigged',
#   'Jim',
#   'Clyburn',
#   'Suggests',
#   'DNC',
#   'Cancel',
#   'Debates',
#   'and',
#   'Primaries',
#   'Anoint',
#   'Biden'],
#  ['Poll',
#   'Bernie',
#   'Sanders',
#   'and',
#   'Joe',
#   'Biden',
#   'Neck',
#   'and',
#   'Neck',
#   'in',
#   'Texas'],
#  ['DNC',
#   'to',
#   'Change',
#   'Debate',
#   'Rules',
#   'as',
#   'Tulsi',
#   'Gabbard',
#   'Reaches',
#   'Delegate',
#   'Requirement'],
#  ['DNC',
#   'Changes',
#   'Debate',
#   'Rules',
#   'After',
#   'Tulsi',
#   'Gabbard',
#   'Reaches',
#   'Previous',
#   'Requirement'],
#  ['Politico',
#   'Democrat',
#   'Establishment',
#   'in',
#   'Panic',
#   'Mode',
#   'over',
#   'Bernie',
#   'Sanders'],
#  ['Super',
#   'Tuesday',
#   'Race',
#   'Tightens',
#   'in',
#   'Amy',
#   'Klobuchar',
#   's',
#   'Minnesota'],
#  ['Live', 'Updates', 'Democrats', 'Debate', 'in', 'South', 'Carolina'],
#  ['Jumanji',
#   'Star',
#   'Jack',
#   'Black',
#   'I',
#   'm',
#   'All',
#   'In',
#   'For',
#   'Elizabeth',
#   'Warren'],
#  ['Live', 'Updates', 'Super', 'Tuesday', 'Election', 'Results'],
#  ['Cory',
#   'Booker',
#   'Endorses',
#   'Joe',
#   'Biden',
#   'He',
#   'll',
#   'Restore',
#   'Honor',
#   'to',
#   'the',
#   'Oval',
#   'Office'],
#  ['Nolte',
#   'Poll',
#   'Shows',
#   'Trump',
#   'Earns',
#   'More',
#   'than',
#   'Twice',
#   'as',
#   'Much',
#   'Trust',
#   'as',
#   'Media'],
#  ['Donald',
#   'Trump',
#   'Delights',
#   'CPAC',
#   'Crowd',
#   'with',
#   'Election',
#   'Year',
#   'Performance',
#   'See',
#   'You',
#   'Next',
#   'Year'],
#  ['Sanders',
#   'Establishment',
#   'Forced',
#   'Klobuchar',
#   'Buttigieg',
#   'Out',
#   'to',
#   'Try',
#   'and',
#   'Defeat',
#   'Me'],
#  ['Coronavirus',
#   'Arizona',
#   'Democrats',
#   'Push',
#   'for',
#   'All',
#   'Mail',
#   'Voting',
#   'in',
#   '2020',
#   'Election'],
#  ['Marianne',
#   'Williamson',
#   'Backs',
#   'Bernie',
#   'Sanders',
#   'The',
#   'Energy',
#   'Is',
#   'Unquestionably',
#   'with',
#   'Him'],
#  ['MSNBC',
#   's',
#   'Chris',
#   'Matthews',
#   'Facing',
#   'Calls',
#   'to',
#   'Resign',
#   'for',
#   'Comparing',
#   'Sanders',
#   'Win',
#   'to',
#   'Nazi',
#   'Invasion'],
#  ['Clyburn',
#   'Rushes',
#   'to',
#   'Save',
#   'Biden',
#   's',
#   'South',
#   'Carolina',
#   'Firewall',
#   'as',
#   'Sanders',
#   'Threat',
#   'Looms'],
#  ['Marianne',
#   'Williamson',
#   'Slams',
#   'Joe',
#   'Biden',
#   's',
#   'Rise',
#   'This',
#   'Was',
#   'Not',
#   'a',
#   'Resurrection',
#   'It',
#   'Was',
#   'a',
#   'Coup'],
#  ['President',
#   'Trump',
#   'Offers',
#   'Hope',
#   'on',
#   'Coronavirus',
#   'One',
#   'Day',
#   'We',
#   'll',
#   'Say',
#   'We',
#   'Won'],
#  ['Report',
#   'Joe',
#   'Biden',
#   'Already',
#   'Choosing',
#   'Cabinet',
#   'Picks',
#   'Kerry',
#   'Rice',
#   'Return'],
#  ['VIDEO',
#   'Joe',
#   'Biden',
#   'Senior',
#   'Adviser',
#   'Symone',
#   'Sanders',
#   'Knocked',
#   'to',
#   'Ground',
#   'During',
#   'Rally',
#   'Scrum'],
#  ['Maxine',
#   'Waters',
#   'I',
#   'Don',
#   't',
#   'Know',
#   'if',
#   'Biden',
#   'Can',
#   'Beat',
#   'Trump'],
#  ['Team',
#   'Warren',
#   'Endorses',
#   'Bernie',
#   'Sanders',
#   'Elizabeth',
#   'Warren',
#   'Remains',
#   'Silent'],
#  ['Trevor',
#   'Noah',
#   'Mocks',
#   'Kamala',
#   'Harris',
#   'Hostage',
#   'Style',
#   'Video',
#   'Endorsement',
#   'of',
#   'Biden'],
#  ['Nolte',
#   'Trump',
#   'Russia',
#   'Hoax',
#   '2',
#   '0',
#   'Has',
#   'Already',
#   'Crashed',
#   'and',
#   'Burned'],
#  ['Nolte',
#   'Polls',
#   'Show',
#   'Elizabeth',
#   'Warren',
#   'Losing',
#   'Her',
#   'Home',
#   'State',
#   'Tuesday'],
#  ['Exclusive',
#   'As',
#   'Coronavirus',
#   'Crisis',
#   'Rages',
#   'Tom',
#   'Cotton',
#   'Launches',
#   'Television',
#   'Ads',
#   'Exposing',
#   'Joe',
#   'Biden',
#   's',
#   'Chinese',
#   'Corruption'],
#  ['Report',
#   'Sen',
#   'Ron',
#   'Johnson',
#   'Planning',
#   'to',
#   'Release',
#   'Interim',
#   'Findings',
#   'in',
#   'Burisma',
#   'Biden',
#   'Probe'],
#  ['Report',
#   'NBA',
#   'Bracing',
#   'for',
#   'Mid',
#   'to',
#   'Late',
#   'June',
#   'Return',
#   'at',
#   'the',
#   'Earliest'],
#  ['Ryan',
#   'Helfenbein',
#   'Biden',
#   'Sanders',
#   'Two',
#   'Sides',
#   'of',
#   'the',
#   'Same',
#   'Democratic',
#   'Coin'],
#  ['Sanders',
#   'Trump',
#   'Is',
#   'the',
#   'Greatest',
#   'Threat',
#   'to',
#   'This',
#   'Country',
#   'in',
#   'Modern',
#   'History'],
#  ['Pollak',
#   'Bernie',
#   'Sanders',
#   'Supporters',
#   'Get',
#   'a',
#   'Taste',
#   'of',
#   'How',
#   'Media',
#   'Abuse',
#   'Trump'],
#  ['Live', 'Updates', 'South', 'Carolina', 'Primary', 'Results'],
#  ['Maryland', 'Postpones', 'Presidential', 'Primary', 'Election'],
#  ['Rahm',
#   'Emanuel',
#   'Democrats',
#   'Low',
#   'Primary',
#   'Turnout',
#   'a',
#   'Flashing',
#   'Yellow',
#   'Light'],
#  ['Joe', 'Biden', 'Projected', 'Winner', 'of', 'South', 'Carolina', 'Primary'],
#  ['Joe', 'Biden', 'Wins', 'Mississippi', 'Democratic', 'Primary'],
#  ['Joe', 'Biden', 'Projected', 'Winner', 'of', 'Michigan', 'Primary'],
#  ['Axelrod',
#   'Buttigieg',
#   'Needs',
#   'to',
#   'Consider',
#   'if',
#   'He',
#   'Wants',
#   'to',
#   'Stay',
#   'In'],
#  ['Joe',
#   'Biden',
#   'Mistakenly',
#   'Endorses',
#   'Jaime',
#   'Harrison',
#   'for',
#   'President',
#   'in',
#   'South',
#   'Carolina',
#   'Victory',
#   'Speech'],
#  ['Democrats',
#   'Make',
#   'Their',
#   'Pitch',
#   'at',
#   'Al',
#   'Sharpton',
#   'Breakfast',
#   'in',
#   'South',
#   'Carolina'],
#  ['Joe',
#   'Biden',
#   'Slips',
#   'into',
#   'Southern',
#   'Accent',
#   'After',
#   'Declaring',
#   'South',
#   'Carolina',
#   'Victory'],
#  ['California',
#   'Primary',
#   'Darrell',
#   'Issa',
#   'Could',
#   'Return',
#   'to',
#   'Congress'],
#  ['Charles',
#   'Hurt',
#   'Democrats',
#   'Goofball',
#   'Primary',
#   'Continues',
#   'Amid',
#   'Global',
#   'Pandemic'],
#  ['Joe',
#   'Biden',
#   'Routs',
#   'Bernie',
#   'Sanders',
#   'in',
#   'Florida',
#   's',
# ...
#   'New',
#   'Facial',
#   'Recognition',
#   'Tool'],
#  ['There',
#   's',
#   'A',
#   'Nationwide',
#   'Shortage',
#   'Of',
#   'The',
#   'Pneumonia',
#   'Vaccine',
#   'Putting',
#   'Vulnerable',
#   'Patients',
#   'At',
#   'Risk'],
#  ['Boris',
#   'Johnson',
#   'Has',
#   'Summoned',
#   'Major',
#   'Tech',
#   'Companies',
#   'To',
#   'Downing',
#   'Street',
#   'To',
#   'Help',
#   'In',
#   'The',
#   'Fight',
#   'Against',
#   'Coronavirus'],
#  ['Around',
#   '40',
#   '000',
#   'Disabled',
#   'Kids',
#   'Are',
#   'Extremely',
#   'Vulnerable',
#   'To',
#   'Coronavirus',
#   'Teachers',
#   'Say',
#   'The',
#   'Government',
#   'Hasn',
#   't',
#   'Got',
#   'A',
#   'Plan',
#   'To',
#   'Protect',
#   'Them'],
#  ['A',
#   '24',
#   'Year',
#   'Old',
#   'Refugee',
#   'Died',
#   'Mysteriously',
#   'In',
#   'Nauru',
#   'Australia',
#   'Says',
#   'That',
#   's',
#   'Nauru',
#   's',
#   'Problem'],
#  ['Private',
#   'Citizens',
#   'Are',
#   'Running',
#   'Websites',
#   'And',
#   'Twitter',
#   'Accounts',
#   'Tracking',
#   'The',
#   'Spread',
#   'Of',
#   'COVID',
#   '19'],
#  ['Travellers',
#   'At',
#   'UK',
#   'Airports',
#   'Say',
#   'No',
#   'One',
#   'Is',
#   'Telling',
#   'Them',
#   'What',
#   'To',
#   'Do',
#   'Or',
#   'Whether',
#   'To',
#   'Self',
#   'Isolate'],
#  ['Teachers',
#   'Say',
#   'Their',
#   'Schools',
#   'Will',
#   'Become',
#   'Breeding',
#   'Grounds',
#   'For',
#   'Coronavirus',
#   'Without',
#   'Government',
#   'Support'],
#  ['Travellers',
#   'Stranded',
#   'Abroad',
#   'Because',
#   'Of',
#   'Coronavirus',
#   'Say',
#   'Nobody',
#   'Is',
#   'Helping',
#   'Them',
#   'To',
#   'Get',
#   'Home'],
#  ['The',
#   'Number',
#   'Of',
#   'Italian',
#   'Health',
#   'Workers',
#   'Infected',
#   'By',
#   'The',
#   'Coronavirus',
#   'Shows',
#   'The',
#   'Urgent',
#   'Need',
#   'For',
#   'Protective',
#   'Equipment'],
#  ['Being',
#   'The',
#   'Mother',
#   'Of',
#   'An',
#   'Immunosuppressed',
#   'Four',
#   'Year',
#   'Old',
#   'In',
#   'The',
#   'Coronavirus',
#   'Outbreak',
#   'Is',
#   'Not',
#   'Easy'],
#  ['This',
#   'Major',
#   'Wine',
#   'Retailer',
#   'Is',
#   'Calling',
#   'Itself',
#   'Essential',
#   'During',
#   'The',
#   'Coronavirus',
#   'Lockdown',
#   'And',
#   'Not',
#   'Everyone',
#   'Is',
#   'Happy'],
#  ['An',
#   'Art',
#   'Gallery',
#   'Director',
#   'Told',
#   'A',
#   'Vietnamese',
#   'Artist',
#   'Their',
#   'Presence',
#   'At',
#   'A',
#   'London',
#   'Art',
#   'Fair',
#   'Could',
#   'Create',
#   'Hesitation',
#   'Because',
#   'Of',
#   'Coronavirus'],
#  ['Could',
#   'It',
#   'Get',
#   'Easier',
#   'For',
#   'People',
#   'To',
#   'Say',
#   'Yuck',
#   'Stuff',
#   'About',
#   'Women',
#   'In',
#   'The',
#   'Workplace',
#   'Attorney',
#   'General',
#   'No',
#   'Lawyers',
#   'Yes'],
#  ['Here',
#   's',
#   'What',
#   'You',
#   'Should',
#   'And',
#   'Shouldn',
#   't',
#   'Include',
#   'In',
#   'A',
#   'Coronavirus',
#   'Preparedness',
#   'Kit'],
#  ['These',
#   'Doctors',
#   'Were',
#   'Meant',
#   'To',
#   'Travel',
#   'Interstate',
#   'To',
#   'Provide',
#   'Abortions',
#   'They',
#   'Don',
#   't',
#   'Know',
#   'If',
#   'They',
#   'Can',
#   'Anymore'],
#  ['An',
#   'Anti',
#   'Vaxxer',
#   'Group',
#   'Has',
#   'Been',
#   'Warned',
#   'For',
#   'Using',
#   'The',
#   'World',
#   'Health',
#   'Organisation',
#   'Logo',
#   'On',
#   'A',
#   'Press',
#   'Release'],
#  ['This',
#   'TikToker',
#   'Takes',
#   'You',
#   'Inside',
#   'Wuhan',
#   's',
#   'Coronavirus',
#   'Quarantine'],
#  ['The',
#   'Food',
#   'Industry',
#   'Wants',
#   'The',
#   'Government',
#   'To',
#   'Second',
#   'Hospitality',
#   'Workers',
#   'To',
#   'Production',
#   'Lines'],
#  ['Survivors',
#   'Of',
#   'The',
#   'AIDS',
#   'Crisis',
#   'Speak',
#   'Out',
#   'About',
#   'The',
#   'Coronavirus',
#   'We',
#   'Will',
#   'Get',
#   'Through',
#   'This'],
#  ['17',
#   'People',
#   'Shared',
#   'The',
#   'Worst',
#   'Date',
#   'They',
#   've',
#   'Been',
#   'On',
#   'In',
#   'New',
#   'York',
#   'And',
#   'Boy',
#   'Oh',
#   'Boy',
#   'They',
#   're',
#   'A',
#   'Doozy'],
#  ['New',
#   'Jury',
#   'Trials',
#   'Are',
#   'Cancelled',
#   'And',
#   'Bail',
#   'Applications',
#   'Will',
#   'Likely',
#   'Rise',
#   'As',
#   'The',
#   'Coronavirus',
#   'Spreads'],
#  ['Tinder',
#   'Users',
#   'Are',
#   'Setting',
#   'Their',
#   'Locations',
#   'To',
#   'Wuhan',
#   'To',
#   'Get',
#   'Coronavirus',
#   'News',
#   'And',
#   'Pick',
#   'Up'],
#  ['Racist',
#   'Hoaxes',
#   'About',
#   'Chinese',
#   'People',
#   'Stockpiling',
#   'In',
#   'The',
#   'Coronavirus',
#   'Pandemic',
#   'Keep',
#   'Going',
#   'Viral'],
#  ['NHK中国語版が', '日本新型コロナウイルス', 'と報じた', '誤り', '国会議員らが指摘したが'],
#  ['残念な裁判だった', '相模原事件で死刑判決', '被害者の父親の思いとは'],
#  ['コロナだけが感染症じゃない', 'マスク盗難が相次ぐ病院', '看護師の嘆き'],
#  ['BTS',
#   'Smashes',
#   'YouTube',
#   'Records',
#   'With',
#   'Their',
#   'New',
#   'Music',
#   'Video',
#   'And',
#   '7',
#   'Of',
#   'This',
#   'Week',
#   's',
#   'Best',
#   'K',
#   'Pop',
#   'Stories'],
#  ['Aussie',
#   'Women',
#   'Are',
#   'Spending',
#   'Serious',
#   'Money',
#   'On',
#   'Sex',
#   'Toys',
#   'During',
#   'The',
#   'Coronavirus',
#   'Outbreak',
#   'And',
#   'Same',
#   'TBH'],
#  ['The',
#   'Mayor',
#   'Of',
#   'Italy',
#   's',
#   'Worst',
#   'Hit',
#   'City',
#   'For',
#   'Coronavirus',
#   'Is',
#   'Bringing',
#   'His',
#   'Daughters',
#   'Home',
#   'From',
#   'The',
#   'UK'],
#  ['Hospital',
#   'Doctors',
#   'Battling',
#   'Coronavirus',
#   'Think',
#   'The',
#   'Government',
#   'Has',
#   'Been',
#   'Too',
#   'Slow',
#   'To',
#   'Act',
#   'And',
#   'Some',
#   'Tory',
#   'MPs',
#   'Agree'],
#  ['Most',
#   'People',
#   'Under',
#   '70',
#   'Were',
#   'Told',
#   'They',
#   'd',
#   'Easily',
#   'Beat',
#   'Coronavirus',
#   'But',
#   'Data',
#   'Suggests',
#   'It',
#   's',
#   'Way',
#   'More',
#   'Than',
#   'Just',
#   'A',
#   'Mild',
#   'Illness',
#   'For',
#   'Some'],
#  ['How',
#   'The',
#   'Coronavirus',
#   'Is',
#   'Impacting',
#   'The',
#   'Production',
#   'Of',
#   'Your',
#   'Favorite',
#   'TV',
#   'Shows'],
#  ['YouTube',
#   'Is',
#   'Letting',
#   'Millions',
#   'Of',
#   'People',
#   'Watch',
#   'Videos',
#   'Promoting',
#   'Misinformation',
#   'About',
#   'Coronavirus'],
#  ['Her',
#   'Son',
#   'Died',
#   'Of',
#   'Mysterious',
#   'Causes',
#   'At',
#   '24',
#   'Her',
#   'Dying',
#   'Wish',
#   'Is',
#   'To',
#   'Find',
#   'Out',
#   'What',
#   'Killed',
#   'Him'],
#  ['All',
#   'Schools',
#   'In',
#   'The',
#   'UK',
#   'Will',
#   'Close',
#   'From',
#   'Friday',
#   'As',
#   'The',
#   'Coronavirus',
#   'Spreads'],
#  ['Pubs',
#   'Cafés',
#   'And',
#   'Theatres',
#   'Are',
#   'Worried',
#   'About',
#   'Insurance',
#   'After',
#   'Boris',
#   'Johnson',
#   's',
#   'Coronavirus',
#   'Speech'],
#  ['A',
#   'Men',
#   's',
#   'Rights',
#   'Activist',
#   'Won',
#   'A',
#   'Prestigious',
#   'Honour',
#   'And',
#   'Now',
#   'A',
#   'Senior',
#   'Politician',
#   'Has',
#   'Asked',
#   'For',
#   'A',
#   'Review'],
#  ['These',
#   'Small',
#   'Business',
#   'Owners',
#   'Were',
#   'Told',
#   'Their',
#   'Diverse',
#   'Skin',
#   'Tone',
#   'Plasters',
#   'Was',
#   'Too',
#   'Niche',
#   'Now',
#   'Big',
#   'Retailers',
#   'Are',
#   'Doing',
#   'It',
#   'Without',
#   'Them'],
#  ['The',
#   'Big',
#   'Brother',
#   'Australia',
#   'Contestants',
#   'DO',
#   'Know',
#   'About',
#   'The',
#   'Coronavirus'],
#  ['Gumtree',
#   'A',
#   'Big',
#   'Australian',
#   'Classifieds',
#   'Site',
#   'Is',
#   'Letting',
#   'People',
#   'Price',
#   'Gouge',
#   'On',
#   'Coronavirus',
#   'Supplies'],
#  ['Cabinet',
#   'Ministers',
#   'And',
#   'Senior',
#   'Aides',
#   'Are',
#   'Threatening',
#   'Full',
#   'Scale',
#   'Mutiny',
#   'If',
#   'Boris',
#   'Johnson',
#   'Doesn',
#   't',
#   'Enforce',
#   'A',
#   'Lockdown'],
#  ['Australia',
#   's',
#   'Unlikely',
#   'Coronavirus',
#   'Celebrity',
#   'Is',
#   'A',
#   'Boomer',
#   'Health',
#   'Journalist'],
#  ['The', 'Refugee', 'Death', 'Australia', 'Forgot'],
#  ['Facebook',
#   'Is',
#   'Being',
#   'Sued',
#   'In',
#   'Australia',
#   'Over',
#   'The',
#   'Cambridge',
#   'Analytica',
#   'Scandal'],
#  ['Doomsday',
#   'Is',
#   'Here',
#   'And',
#   'The',
#   'Facebook',
#   'Portal',
#   'Is',
#   'Good',
#   'Now'],
#  ['Driving',
#   'A',
#   'City',
#   'Bus',
#   'In',
#   'A',
#   'Global',
#   'Pandemic',
#   'Is',
#   'Extremely',
#   'Stressful'],
#  ['18',
#   'Tips',
#   'For',
#   'Working',
#   'From',
#   'Home',
#   'Without',
#   'Losing',
#   'Your',
#   'Mind'],
#  ['Here',
#   's',
#   'What',
#   'You',
#   'Need',
#   'To',
#   'Know',
#   'About',
#   'Coronavirus',
#   'In',
#   'The',
#   'UK'],
#  ['Here',
#   's',
#   'What',
#   'You',
#   'Need',
#   'To',
#   'Know',
#   'Now',
#   'Coronavirus',
#   'Is',
#   'Being',
#   'Transmitted',
#   'Between',
#   'People',
#   'In',
#   'The',
#   'UK'],
#  ['Iceland',
#   's',
#   'Entire',
#   'Population',
#   'Can',
#   'Get',
#   'Tested',
#   'For',
#   'The',
#   'Coronavirus',
#   'Here',
#   's',
#   'How',
#   'That',
#   'Could',
#   'Help',
#   'All',
#   'Of',
#   'Us'],
#  ['The',
#   'Tokyo',
#   'Olympics',
#   'Could',
#   'Possibly',
#   'Be',
#   'Canceled',
#   'Because',
#   'Of',
#   'Coronavirus',
#   'But',
#   'All',
#   'Everyone',
#   'Can',
#   'Talk',
#   'About',
#   'Is',
#   'Dick',
#   'Pound'],
#  ['Australia', 's', 'Major', 'News', 'Wire', 'Is', 'Shutting', 'Down'],
#  ['22', 'Times', 'Tumblr', 'Completely', 'Roasted', 'Twilight'],
#  ['Hilary',
#   'Duff',
#   'Dragged',
#   'A',
#   'Tabloid',
#   'That',
#   'Said',
#   'Her',
#   'Marriage',
#   'Is',
#   'On',
#   'The',
#   'Rocks',
#   'After',
#   'Three',
#   'Months'],
#  ['European',
#   'Diplomats',
#   'Are',
#   'Very',
#   'Puzzled',
#   'By',
#   'Donald',
#   'Trump',
#   's',
#   'Coronavirus',
#   'Travel',
#   'Ban'],
#  ['Thousands',
#   'Of',
#   'Europeans',
#   'Have',
#   'Left',
#   'Britain',
#   'This',
#   'Week',
#   'Because',
#   'Of',
#   'The',
#   'Coronavirus'],
#  ['Looks',
#   'Like',
#   'A',
#   'Love',
#   'Is',
#   'Blind',
#   'Couple',
#   'That',
#   'Split',
#   'Up',
#   'Got',
#   'Back',
#   'Together',
#   'And',
#   'I',
#   'm',
#   'Freaking',
#   'Out',
#   'Over',
#   'The',
#   'News'],
#  ['Boris',
#   's',
#   'Lackey',
#   'Or',
#   'The',
#   'Civil',
#   'Service',
#   's',
#   'Moral',
#   'Compass',
#   'Mark',
#   'Sedwill',
#   'Finds',
#   'Himself',
#   'Where',
#   'No',
#   'Cabinet',
#   'Secretary',
#   'Wants',
#   'To',
#   'Be'],
#  ['Boris',
#   'Johnson',
#   's',
#   'Government',
#   'Has',
#   'Lost',
#   'Another',
#   'Top',
#   'Civil',
#   'Servant'],
#  ['Emily',
#   'Alyn',
#   'Lind',
#   'Is',
#   'The',
#   'First',
#   'Lead',
#   'Actor',
#   'Announced',
#   'For',
#   'Gossip',
#   'Girl',
#   'Reboot'],
#  ['The',
#   'Conspiracy',
#   'Theory',
#   'About',
#   'Bullied',
#   '9',
#   'Year',
#   'Old',
#   'Quaden',
#   'Bayles',
#   'Explained'],
#  ['The',
#   'UK',
#   'Government',
#   'Has',
#   'Reacted',
#   'With',
#   'Incredulity',
#   'And',
#   'Genuine',
#   'Disbelief',
#   'At',
#   'Trump',
#   's',
#   'Handling',
#   'Of',
#   'Coronavirus'],
#  ['18',
#   'Funny',
#   'Tweets',
#   'From',
#   'This',
#   'Month',
#   'That',
#   'll',
#   'Hopefully',
#   'Give',
#   'You',
#   'A',
#   'Break',
#   'From',
#   'All',
#   'The',
#   'Chaos'],
#  ['Really',
#   'Brought',
#   'Their',
#   'A',
#   'Game',
#   'The',
#   'Emails',
#   'Behind',
#   'That',
#   'Bizarre',
#   'Horoscopes',
#   'Poster',
#   'Designed',
#   'To',
#   'Scare',
#   'Refugees'],
#  ['A',
#   'Bunch',
#   'Of',
#   'Media',
#   'Outlets',
#   'Have',
#   'Deleted',
#   'Or',
#   'Withdrawn',
#   'Comments',
#   'From',
#   'A',
#   'Men',
#   's',
#   'Rights',
#   'Activist',
#   'Attacking',
#   'A',
#   'Journalist'],
#  ['A',
#   'Guard',
#   'Who',
#   'Worked',
#   'In',
#   'A',
#   'Brisbane',
#   'Detention',
#   'Centre',
#   'Has',
#   'Tested',
#   'Positive',
#   'For',
#   'COVID',
#   '19'],
#  ['Australia',
#   'Won',
#   't',
#   'Let',
#   'People',
#   'Visit',
#   'Immigration',
#   'Detainees',
#   'Because',
#   'Of',
#   'The',
#   'Coronavirus',
#   'Fears'],
#  ['Men',
#   'In',
#   'Detention',
#   'Are',
#   'Washing',
#   'Their',
#   'Hands',
#   'With',
#   '2',
#   'In',
#   '1',
#   'Shampoo',
#   'And',
#   'Conditioner',
#   'As',
#   'The',
#   'Coronavirus',
#   'Spreads'],
#  ['This',
#   'Is',
#   'What',
#   'Happened',
#   'To',
#   'Egg',
#   'Boy',
#   'And',
#   'The',
#   'Racist',
#   'Politician',
#   'In',
#   'The',
#   'Year',
#   'Since',
#   'The',
#   'Christchurch',
#   'Attack'],
#  ['Coronavirus',
#   'Won',
#   't',
#   'Shut',
#   'Down',
#   'Parliament',
#   'But',
#   'Staff',
#   'Say',
#   'They',
#   'Are',
#   'Afraid',
#   'For',
#   'Their',
#   'Health'],
#  ['A',
#   'Fake',
#   'Facebook',
#   'Account',
#   'Pretending',
#   'To',
#   'Be',
#   'A',
#   'Chinese',
#   'Woman',
#   'Hoarding',
#   'Toilet',
#   'Paper',
#   'Is',
#   'Being',
#   'Shared',
#   'By',
#   'Right',
#   'Wing',
#   'Pages'],
#  ['The',
#   'Tube',
#   'Is',
#   'Still',
#   'Packed',
#   'Despite',
#   'The',
#   'Coronavirus',
#   'Lockdown',
#   'As',
#   'London',
#   's',
#   'Mayor',
#   'And',
#   'The',
#   'Government',
#   'Give',
#   'Different',
#   'Advice',
#   'Over',
#   'Construction',
#   'Workers'],
#  ['Italian',
#   'Tourists',
#   'Fear',
#   'Being',
#   'Stranded',
#   'In',
#   'The',
#   'UK',
#   'By',
#   'Their',
#   'Country',
#   's',
#   'Coronavirus',
#   'Lockdown'],
#  ['A',
#   'Young',
#   'Man',
#   'With',
#   'Severe',
#   'Mental',
#   'Health',
#   'Issues',
#   'Was',
#   'Told',
#   'He',
#   'd',
#   'Be',
#   'In',
#   'Detention',
#   'For',
#   'A',
#   'Week',
#   'It',
#   's',
#   'Been',
#   '15',
#   'Months'],
#  ['Schools',
#   'And',
#   'Nurseries',
#   'Are',
#   'Very',
#   'Confused',
#   'About',
#   'The',
#   'New',
#   'Key',
#   'Worker',
#   'Policy'],
#  ['You',
#   'Probably',
#   'Saw',
#   'This',
#   'Hoax',
#   'About',
#   'Australia',
#   'Enforcing',
#   'A',
#   'Mandatory',
#   'Lockdown',
#   'Here',
#   's',
#   'The',
#   'Story',
#   'Behind',
#   'It'],
#  ['Rebecca',
#   'Long',
#   'Bailey',
#   'Worked',
#   'On',
#   'A',
#   'Legal',
#   'Team',
#   'That',
#   'Advised',
#   'On',
#   'A',
#   'PFI',
#   'Deal',
#   'For',
#   'A',
#   'Hospital',
#   'That',
#   's',
#   'Costing',
#   'Liverpool',
#   'Millions'],
#  ['Here',
#   's',
#   'A',
#   'Few',
#   'Of',
#   'Those',
#   'Hilarious',
#   'Coronavirus',
#   'Voice',
#   'Notes',
#   'That',
#   'Have',
#   'Been',
#   'Going',
#   'Viral',
#   'On',
#   'WhatsApp'],
#  ['An',
#   'Immunosuppressed',
#   'Scientist',
#   'Is',
#   'Using',
#   'His',
#   'Self',
#   'Isolation',
#   'Time',
#   'To',
#   'Map',
#   'The',
#   'Coronavirus'],
#  ['Pickles',
#   'And',
#   'Online',
#   'Bridge',
#   'How',
#   'At',
#   'Risk',
#   'People',
#   'Are',
#   'Making',
#   'It',
#   'Through',
#   'The',
#   'Coronavirus',
#   'Pandemic'],
#  ['Here',
#   's',
#   'How',
#   'Coronavirus',
#   'Is',
#   'Affecting',
#   'Real',
#   'People',
#   's',
#   'Lives',
#   'Around',
#   'The',
#   'World'],
#  ['Você',
#   'consegue',
#   'acertar',
#   'se',
#   'essas',
#   '10',
#   'notícias',
#   'sobre',
#   'o',
#   'coronavírus',
#   'são',
#   'verdadeiras',
#   'ou',
#   'fake',
#   'news'],
#  ['Boulos',
#   'lança',
#   'candidatura',
#   'a',
#   'prefeito',
#   'de',
#   'SP',
#   'mas',
#   'terá',
#   'de',
#   'enfrentar',
#   'prévias',
#   'no',
#   'PSOL'],
#  ['Bolsonaro',
#   'diz',
#   'que',
#   'exames',
#   'deram',
#   'negativo',
#   'para',
#   'coronavírus'],
#  ['Ela',
#   'foi',
#   'a',
#   'uma',
#   'festa',
#   'sem',
#   'esperar',
#   'resultado',
#   'do',
#   'exame',
#   'do',
#   'namorado',
#   'Deu',
#   'positivo',
#   'e',
#   'boate',
#   'fechou'],
#  ['Mulher',
#   'xinga',
#   'negra',
#   'de',
#   'macaca',
#   'sem',
#   'educação',
#   'em',
#   'shopping',
#   'no',
#   'Rio',
#   'e',
#   'é',
#   'presa',
#   'em',
#   'flagrante'],
#  ['The',
#   'DOJ',
#   'Won',
#   't',
#   'Let',
#   'Immigration',
#   'Judges',
#   'Hang',
#   'Up',
#   'Posters',
#   'About',
#   'Coronavirus',
#   'for',
#   'Some',
#   'Reason'],
#  ['We',
#   'Regret',
#   'to',
#   'Inform',
#   'You',
#   'That',
#   'These',
#   'Coronavirus',
#   'Songs',
#   'Slap'],
#  ['The',
#   'Coronavirus',
#   'Is',
#   'Starting',
#   'to',
#   'Hit',
#   'The',
#   'U',
#   'S',
#   'Military'],
#  ['Hotels',
#   'and',
#   'Convention',
#   'Centers',
#   'Emptied',
#   'by',
#   'Coronavirus',
#   'Are',
#   'now',
#   'Sheltering',
#   'the',
#   'Homeless'],
#  ['The', 'Coronavirus', 'Threat', 'Just', 'Got', 'Real', 'in', 'Europe'],
#  ['Coronavirus', 'Merch', 'Is', 'Here', 'But', 'Who', 's', 'Buying', 'It'],
#  ['Iran',
#   'Says',
#   'It',
#   'Has',
#   'Just',
#   '500',
#   'Dead',
#   'From',
#   'Coronavirus',
#   'So',
#   'Why',
#   'Can',
#   'You',
#   'See',
#   'the',
#   'Mass',
#   'Graves',
#   'From',
#   'Space'],
#  ['Here',
#   's',
#   'What',
#   'You',
#   'Personally',
#   'Should',
#   'Do',
#   'About',
#   'Coronavirus'],
#  ['Is',
#   'Your',
#   'Soul',
#   'Patch',
#   'Putting',
#   'You',
#   'At',
#   'Risk',
#   'During',
#   'the',
#   'Coronavirus',
#   'Outbreak'],
#  ['Canadian',
#   'Researchers',
#   'Have',
#   'Isolated',
#   'the',
#   'Novel',
#   'Coronavirus'],
#  ['Surprise',
#   'People',
#   'Are',
#   'Making',
#   'Terrible',
#   'TikToks',
#   'About',
#   'Coronavirus'],
#  ['Don',
#   't',
#   'Believe',
#   'These',
#   '4',
#   'Wild',
#   'Coronavirus',
#   'Conspiracy',
#   'Theories'],
#  ['Iranian', 'Officials', 'Keep', 'Dying', 'From', 'Coronavirus'],
#  ['We',
#   'Talk',
#   'to',
#   'a',
#   'Doctor',
#   'at',
#   'the',
#   'Center',
#   'of',
#   'South',
#   'Korea',
#   's',
#   'Coronavirus',
#   'Explosion'],
#  ['Worried',
#   'College',
#   'Students',
#   'Are',
#   'Asking',
#   'Their',
#   'Schools',
#   'to',
#   'Cancel',
#   'Class'],
#  ['As',
#   'Coronavirus',
#   'Spreads',
#   'Artists',
#   'Are',
#   'Coping',
#   'With',
#   'Waifus',
#   'and',
#   'Fursona',
#   'Art'],
#  ...]

# %%
# Getting rid of Stopwords

for i in range(len(Content)):
    # Taking out the Stopwords
    Content[i] = [words.lower() for words in Content[i] if words.lower() not in stopwords]
    Title[i] = [words.lower() for words in Title[i] if words.lower() not in stopwords]
    Description[i] = [words.lower() for words in Description[i] if words.lower() not in stopwords]
    
    # Taking out the non-string values
    Content[i] = [words for words in Content[i] if words.isalpha() == True]
    Title[i] = [words for words in Title[i] if words.isalpha() == True]
    Description[i] = [words for words in Description[i] if words.isalpha() == True]
    
#print(Title)

# %%
Title
# Out:
# [['south', 'carolina', 'primary', 'die', 'biden', 'campaign'],
#  ['sanders',
#   'supporters',
#   'react',
#   'dnc',
#   'reportedly',
#   'attempting',
#   'subvert',
#   'primary',
#   'result'],
#  ['contentious', 'race', 'democratic', 'race', 'heads', 'south', 'carolina'],
#  ['federalist',
#   'editor',
#   'mollie',
#   'hemingway',
#   'biden',
#   'sc',
#   'win',
#   'blew',
#   'away',
#   'people',
#   'expectations'],
#  ['biden', 'get', 'bounce', 'super', 'tuesday'],
#  ['josh',
#   'kraushaar',
#   'politics',
#   'editor',
#   'national',
#   'journal',
#   'dem',
#   'race',
#   'biden',
#   'win',
#   'south',
#   'carolina',
#   'primary',
#   'bernie',
#   'sanders',
#   'democratic',
#   'nominee'],
#  ['bernie',
#   'fights',
#   'survival',
#   'polls',
#   'show',
#   'biden',
#   'blowout',
#   'michigan'],
#  ['sen', 'rick', 'scott', 'believe', 'bailouts', 'companies', 'period'],
#  ['former',
#   'ohio',
#   'senate',
#   'minority',
#   'leader',
#   'capri',
#   'cafaro',
#   'bernie',
#   'sander',
#   'primary',
#   'performance',
#   'consistently',
#   'underperformed',
#   'numbers'],
#  ['biden', 'boost', 'establishment', 'make', 'comeback', 'kid'],
#  ['fox',
#   'news',
#   'contributor',
#   'kim',
#   'strassel',
#   'takes',
#   'socialism',
#   'bernie',
#   'sanders',
#   'fundamentally',
#   'different',
#   'concept',
#   'america'],
#  ['fight', 'control', 'congress'],
#  ['sanders', 'speeds', 'nevada', 'momentum', 'moderate', 'democrats', 'panic'],
#  ['march',
#   'madness',
#   'stocks',
#   'plummet',
#   'amid',
#   'oil',
#   'plunge',
#   'coronavirus',
#   'fears'],
#  ['fox',
#   'news',
#   'rundown',
#   'extra',
#   'karl',
#   'rove',
#   'democrats',
#   'biggest',
#   'challenges'],
#  ['make', 'bernie', 'bets'],
#  ['rep',
#   'elise',
#   'stefanik',
#   'ny',
#   'slow',
#   'pace',
#   'coronavirus',
#   'testing',
#   'explanation',
#   'lack',
#   'testing'],
#  ['senator',
#   'joni',
#   'ernst',
#   'r',
#   'ia',
#   'democrats',
#   'infanticide',
#   'filibuster',
#   'heartbroken',
#   'dems',
#   'issue',
#   'life'],
#  ['candidates',
#   'make',
#   'final',
#   'pitches',
#   'ahead',
#   'south',
#   'carolina',
#   'primary'],
#  ['sanders', 'taking', 'nevada', 'momentum', 'south', 'carolina'],
#  ['fox', 'poll', 'sanders', 'leads', 'democrats', 'want', 'change'],
#  ['biden',
#   'sanders',
#   'battle',
#   'working',
#   'class',
#   'voters',
#   'ahead',
#   'michigan',
#   'primary'],
#  ['past', 'south', 'carolina', 'presidential', 'primary', 'winners'],
#  ['sanders',
#   'downplays',
#   'shortcomings',
#   'black',
#   'voters',
#   'following',
#   'south',
#   'carolina',
#   'loss'],
#  ['louisiana', 'postpones', 'primary', 'amid', 'coronavirus', 'pandemic'],
#  ['geraldo',
#   'rivera',
#   'biden',
#   'win',
#   'south',
#   'carolina',
#   'carry',
#   'momentum',
#   'super',
#   'tuesday'],
#  ['clyburn',
#   'endorses',
#   'joe',
#   'biden',
#   'ahead',
#   'south',
#   'carolina',
#   'primary'],
#  ['tom',
#   'steyer',
#   'ends',
#   'campaign',
#   'biden',
#   'wins',
#   'south',
#   'carolina',
#   'primary'],
#  ['michigan', 'primary', 'winners', 'past', 'presidential', 'contests'],
#  ['tucker',
#   'carlson',
#   'everyone',
#   'democratic',
#   'field',
#   'diminished',
#   'ideas',
#   'absurd'],
#  ['democracy',
#   'digest',
#   'gop',
#   'voters',
#   'potential',
#   'factor',
#   'dems',
#   'south',
#   'carolina',
#   'primary'],
#  ['coronavirus',
#   'live',
#   'blog',
#   'primary',
#   'care',
#   'physician',
#   'dr',
#   'nate',
#   'favini',
#   'answers',
#   'questions'],
#  ['sanders',
#   'supporters',
#   'accused',
#   'late',
#   'night',
#   'bullhorn',
#   'protests',
#   'dem',
#   'officials'],
#  ['sanders', 'knocks', 'biden', 'first'],
#  ['rob',
#   'kardashian',
#   'emergency',
#   'request',
#   'primary',
#   'custody',
#   'daughter',
#   'dream',
#   'denied',
#   'reports'],
#  ['biden',
#   'touts',
#   'landslide',
#   'victory',
#   'south',
#   'carolina',
#   'swipes',
#   'sanders',
#   'revolution'],
#  ['bernie', 'sanders', 'deliver', 'statement', 'primary', 'losses', 'biden'],
#  ['biden',
#   'wins',
#   'maine',
#   'primary',
#   'giving',
#   'super',
#   'tuesday',
#   'victories'],
#  ['democracy',
#   'digest',
#   'coronavirus',
#   'scare',
#   'dampens',
#   'primary',
#   'turnout'],
#  ['trump',
#   'secures',
#   'gop',
#   'presidential',
#   'nomination',
#   'tuesday',
#   'primary',
#   'victories'],
#  ['aoc', 'pick', 'democrat', 'primary', 'house', 'seat', 'beats', 'incumbent'],
#  ['look', 'ohio', 'primary', 'winners', 'past', 'presidential', 'contests'],
#  ['trump',
#   'snubs',
#   'sessions',
#   'endorses',
#   'tuberville',
#   'alabama',
#   'senate',
#   'primary',
#   'runoff'],
#  ['maryland',
#   'postpone',
#   'primary',
#   'election',
#   'coronavirus',
#   'governor',
#   'says'],
#  ['biden',
#   'declared',
#   'winner',
#   'washington',
#   'state',
#   'primary',
#   'days',
#   'vote'],
#  ['bill', 'weld', 'suspends', 'long', 'shot', 'primary', 'challenge', 'trump'],
#  ['trump', 'taunts', 'sanders', 'primary', 'drubbing', 'bernie', 'given'],
#  ['biden',
#   'lands',
#   'big',
#   'endorsement',
#   'crucial',
#   'primary',
#   'state',
#   'michigan'],
#  ['cory', 'booker', 'endorses', 'former', 'primary', 'rival', 'joe', 'biden'],
#  ['look', 'florida', 'primary', 'winners', 'past', 'presidential', 'contests'],
#  ['super', 'tuesday', 'results', 'democratic', 'candidates', 'stand'],
#  ['march', 'primaries', 'states', 'voting', 'delegates', 'stake'],
#  ['states', 'postponed', 'primaries', 'due', 'coronavirus', 'outbreak'],
#  ['mike',
#   'bloomberg',
#   'spent',
#   'nearly',
#   'money',
#   'failed',
#   'presidential',
#   'bid'],
#  ['bernie',
#   'sanders',
#   'surrogate',
#   'claims',
#   'media',
#   'lying',
#   'support',
#   'socialism',
#   'ideas',
#   'popular'],
#  ['laura',
#   'ingraham',
#   'joe',
#   'biden',
#   'lagging',
#   'campaign',
#   'lacks',
#   'obama',
#   'magic',
#   'money'],
#  ['trump',
#   'says',
#   'biden',
#   'south',
#   'carolina',
#   'win',
#   'end',
#   'mini',
#   'mike',
#   'bloomberg',
#   'joke',
#   'campaign'],
#  ['joe',
#   'biden',
#   'campaign',
#   'still',
#   'life',
#   'support',
#   'despite',
#   'south',
#   'carolina',
#   'win',
#   'corey',
#   'lewandowski',
#   'says'],
#  ['biden',
#   'accidentally',
#   'tells',
#   'south',
#   'carolina',
#   'crowd',
#   'dem',
#   'candidate',
#   'united',
#   'states',
#   'senate'],
#  ['colin',
#   'reed',
#   'bernie',
#   'sanders',
#   'newfound',
#   'front',
#   'runner',
#   'status',
#   'pushing',
#   'establishment',
#   'dems',
#   'edge'],
#  ['lawrence',
#   'jones',
#   'grills',
#   'south',
#   'carolina',
#   'democrats',
#   'bernie',
#   'sanders',
#   'castro',
#   'praise',
#   'inconceivable'],
#  ['tom', 'steyer', 'dances', 'back', 'azz', 'excruciating', 'video'],
#  ['andrew', 'yang', 'launches', 'nonprofit', 'dropping', 'race'],
#  ['gutfeld', 'bernie', 'vs', 'joe'],
#  ['jessica',
#   'tarlov',
#   'key',
#   'thing',
#   'democratic',
#   'primary',
#   'voters',
#   'need',
#   'remember',
#   'cast',
#   'ballots'],
#  ['democracy',
#   'digest',
#   'sanders',
#   'heavy',
#   'electability',
#   'light',
#   'revolution',
#   'eve',
#   'sc',
#   'primary'],
#  ['sanders',
#   'congratulates',
#   'biden',
#   'primary',
#   'win',
#   'eyes',
#   'super',
#   'tuesday',
#   'cannot',
#   'win'],
#  ['polls',
#   'close',
#   'south',
#   'carolina',
#   'primary',
#   'biden',
#   'seeks',
#   'crucial',
#   'first',
#   'win'],
#  ['south',
#   'carolina',
#   'paper',
#   'warns',
#   'political',
#   'dirty',
#   'tricks',
#   'ahead',
#   'state',
#   'primary'],
#  ['trump',
#   'holds',
#   'rally',
#   'north',
#   'charleston',
#   'eve',
#   'dems',
#   'south',
#   'carolina',
#   'primary'],
#  ['bill', 'clinton', 'accused', 'racism', 'south', 'carolina', 'primary'],
#  ['sanders',
#   'claims',
#   'backed',
#   'obama',
#   'campaigns',
#   'despite',
#   'report',
#   'mulling',
#   'primary',
#   'bid'],
#  ['leslie',
#   'marshall',
#   'biden',
#   'big',
#   'victory',
#   'sc',
#   'primary',
#   'strengthens',
#   'challenge',
#   'sanders'],
#  ['south',
#   'carolina',
#   'democrats',
#   'say',
#   'presidential',
#   'primary',
#   'turnout',
#   'may',
#   'approach',
#   'record',
#   'high'],
#  ['chris',
#   'matthews',
#   'absent',
#   'msnbc',
#   'primary',
#   'coverage',
#   'sexism',
#   'allegations',
#   'air',
#   'slip',
#   'ups'],
#  ['biden',
#   'south',
#   'carolina',
#   'win',
#   'may',
#   'aid',
#   'primary',
#   'reset',
#   'super',
#   'tuesday',
#   'decide'],
#  ['biden',
#   'calls',
#   'sc',
#   'primary',
#   'real',
#   'comeback',
#   'sets',
#   'sights',
#   'super',
#   'tuesday'],
#  ['primaries',
#   'go',
#   'forward',
#   'three',
#   'big',
#   'states',
#   'despite',
#   'coronavirus',
#   'biden',
#   'looks',
#   'shut',
#   'sanders'],
#  ['newt',
#   'gingrich',
#   'hours',
#   'changed',
#   'democratic',
#   'presidential',
#   'race'],
#  ['sanders',
#   'clashes',
#   'biden',
#   'debate',
#   'claims',
#   'sought',
#   'social',
#   'security',
#   'cuts'],
#  ['live',
#   'audience',
#   'next',
#   'democratic',
#   'debate',
#   'due',
#   'coronavirus',
#   'precautions'],
#  ['biden',
#   'points',
#   'sanders',
#   'arizona',
#   'eve',
#   'presidential',
#   'primary',
#   'poll'],
#  ['florida',
#   'dealing',
#   'dearth',
#   'poll',
#   'workers',
#   'primary',
#   'held',
#   'amid',
#   'coronavirus',
#   'pandemic'],
#  ['clyburn',
#   'calls',
#   'shutting',
#   'dem',
#   'primary',
#   'canceling',
#   'debates',
#   'biden',
#   'surge'],
#  ['michigan',
#   'officials',
#   'say',
#   'complete',
#   'primary',
#   'results',
#   'released',
#   'wednesday',
#   'afternoon'],
#  ['biden',
#   'projected',
#   'win',
#   'mississippi',
#   'missouri',
#   'primaries',
#   'polls',
#   'pivotal',
#   'michigan',
#   'closing',
#   'soon'],
#  ['cnn',
#   'mocked',
#   'airing',
#   'graphic',
#   'declaring',
#   'sanders',
#   'winner',
#   'mississippi'],
#  ['progressives',
#   'slam',
#   'irresponsible',
#   'tom',
#   'perez',
#   'dems',
#   'allowing',
#   'primaries',
#   'amid',
#   'virus',
#   'outbreak',
#   'going',
#   'get',
#   'people',
#   'killed'],
#  ['confusion',
#   'ohio',
#   'primary',
#   'take',
#   'place',
#   'coronavirus',
#   'postponement'],
#  ['biden', 'backs', 'calling', 'south', 'carolina', 'firewall'],
#  ['nyt',
#   'friedman',
#   'calls',
#   'gathering',
#   'dem',
#   'party',
#   'elders',
#   'counter',
#   'bernie',
#   'sanders',
#   'surge'],
#  ['biden',
#   'campaign',
#   'vows',
#   'victory',
#   'south',
#   'carolina',
#   'says',
#   'race',
#   'getting',
#   'started'],
#  ['mary',
#   'anne',
#   'marsh',
#   'democratic',
#   'debate',
#   'winners',
#   'losers',
#   'two',
#   'hour',
#   'street',
#   'fight'],
#  ['south',
#   'carolina',
#   'gov',
#   'mcmaster',
#   'trump',
#   'connection',
#   'voters',
#   'never',
#   'seen',
#   'anything',
#   'like'],
#  ['sanders',
#   'complained',
#   'early',
#   'southern',
#   'primaries',
#   'said',
#   'calendar',
#   'distorts',
#   'reality'],
#  ['sen',
#   'tim',
#   'scott',
#   'sanders',
#   'rivals',
#   'face',
#   'make',
#   'break',
#   'moment',
#   'south',
#   'carolina',
#   'debate'],
#  ['bernie',
#   'sanders',
#   'revisited',
#   'candidate',
#   'backs',
#   'letting',
#   'violent',
#   'felons',
#   'vote',
#   'prison'],
#  ['charles',
#   'hurt',
#   'mike',
#   'bloomberg',
#   'dangerous',
#   'ahead',
#   'super',
#   'tuesday'],
#  ['karl', 'rove', 'biden', 'south', 'carolina', 'win', 'win', 'tonight'],
#  ['south', 'carolina', 'pumped', 'steyer', 'says', 'ready', 'run', 'tape'],
#  ['new',
#   'york',
#   'state',
#   'fights',
#   'coronavirus',
#   'blood',
#   'plasma',
#   'recovered',
#   'patients'],
#  ['africa', 'mountain', 'gorillas', 'face', 'coronavirus', 'risk'],
#  ['scientists', 'map', 'immune', 'system', 'fights', 'back', 'covid'],
#  ['coronavirus',
#   'travel',
#   'ban',
#   'american',
#   'united',
#   'delta',
#   'airlines',
#   'cap',
#   'flight',
#   'fares',
#   'europe',
#   'u',
#   'fox',
#   'news'],
#  ['jimmy',
#   'kimmel',
#   'mocks',
#   'pence',
#   'ability',
#   'tackle',
#   'coronavirus',
#   'plan',
#   'abstinence',
#   'fox',
#   'news'],
#  ['trump',
#   'pitch',
#   'congress',
#   'payroll',
#   'tax',
#   'cut',
#   'relief',
#   'small',
#   'business',
#   'amid',
#   'coronavirus',
#   'crisis',
#   'fox',
#   'news'],
#  ['ways', 'tech', 'help', 'stay', 'sane', 'stay', 'home', 'fox', 'news'],
#  ['lose',
#   'taste',
#   'smell',
#   'could',
#   'telltale',
#   'sign',
#   'coronavirus',
#   'fox',
#   'news'],
#  ['brazil',
#   'president',
#   'bolsonaro',
#   'son',
#   'claims',
#   'father',
#   'tested',
#   'negative',
#   'coronavirus',
#   'despite',
#   'earlier',
#   'reports',
#   'fox',
#   'news'],
#  ['trump', 'tweets', 'series', 'tips', 'avoid', 'coronavirus', 'fox', 'news'],
#  ['washington', 'state', 'confirms', 'coronavirus', 'death', 'fox', 'news'],
#  ['tom', 'hanks', 'confirms', 'positive', 'test', 'coronoavirus'],
#  ['sen',
#   'lindsey',
#   'graham',
#   'says',
#   'us',
#   'counterattack',
#   'coronavirus',
#   'stabilizing',
#   'economy'],
#  ['america', 'ready', 'fight', 'coronavirus'],
#  ['trump', 'blames', 'media', 'hatred', 'tough', 'virus', 'coverage'],
#  ['biden',
#   'sweeps',
#   'states',
#   'media',
#   'barely',
#   'budge',
#   'virus',
#   'coverage'],
#  ['trump',
#   'others',
#   'eye',
#   'softening',
#   'restrictions',
#   'despite',
#   'pandemic'],
#  ['sen',
#   'john',
#   'cornyn',
#   'congress',
#   'nation',
#   'need',
#   'war',
#   'footing',
#   'beat',
#   'virus'],
#  ['state',
#   'department',
#   'spox',
#   'morgan',
#   'ortagus',
#   'coronavirus',
#   'china',
#   'holding',
#   'match',
#   'lit',
#   'world',
#   'fire',
#   'virus'],
#  ['dr',
#   'ronny',
#   'jackson',
#   'disgusted',
#   'press',
#   'trying',
#   'make',
#   'president',
#   'trump',
#   'xenophobe'],
#  ['u',
#   'surgeon',
#   'general',
#   'coronavirus',
#   'take',
#   'precautions',
#   'hoard',
#   'anticipation',
#   'equivalent',
#   'bad',
#   'flu',
#   'season'],
#  ['potus', 'v', 'scotus'],
#  ['momming', 'coronavirus', 'tell', 'kids'],
#  ['wedding', 'dress', 'coronavirus', 'jeopardy'],
#  ['rep',
#   'josh',
#   'gottheimer',
#   'time',
#   'aggressive',
#   'measures',
#   'take',
#   'care',
#   'local',
#   'businesses'],
#  ['dr', 'janette', 'nesheiwat', 'social', 'distancing', 'save', 'lives'],
#  ['national', 'emergency', 'global', 'pandemic'],
#  ['march',
#   'madness',
#   'stocks',
#   'plummet',
#   'amid',
#   'oil',
#   'plunge',
#   'coronavirus',
#   'fears'],
#  ['government', 'response', 'invisible', 'enemy'],
#  ['fox',
#   'news',
#   'rundown',
#   'extra',
#   'former',
#   'fema',
#   'chief',
#   'coronavirus',
#   'failure',
#   'personal',
#   'responsibility'],
#  ['dr',
#   'marc',
#   'siegel',
#   'need',
#   'coronavirus',
#   'testing',
#   'ramp',
#   'paranoia'],
#  ['pastor', 'max', 'lucado', 'feeding', 'faith', 'starve', 'fears'],
#  ['senator',
#   'bill',
#   'cassidy',
#   'r',
#   'la',
#   'federal',
#   'response',
#   'coronavirus'],
#  ['billions', 'approved', 'fight', 'coronavirus'],
#  ['rep',
#   'matt',
#   'gaetz',
#   'wore',
#   'gas',
#   'mask',
#   'show',
#   'congress',
#   'feel',
#   'impact',
#   'coronavirus'],
#  ['rep',
#   'elise',
#   'stefanik',
#   'ny',
#   'slow',
#   'pace',
#   'coronavirus',
#   'testing',
#   'explanation',
#   'lack',
#   'testing'],
#  ['stock',
#   'market',
#   'woes',
#   'virus',
#   'fears',
#   'lead',
#   'worst',
#   'week',
#   'since',
#   'financial',
#   'crisis'],
#  ['dr', 'peter', 'hotez', 'coronavirus', 'spreads', 'u', 'fully', 'prepared'],
#  ['pregnant', 'women', 'risk', 'coronavirus'],
#  ['dr', 'william', 'haseltine', 'coronavirus', 'prevention', 'steps', 'take'],
#  ['tokyo', 'organizers', 'government', 'take', 'offensive', 'virus', 'threat'],
#  ['italian', 'soccer', 'could', 'played', 'without', 'fans', 'virus'],
#  ['asian', 'baseball', 'soccer', 'rugby', 'affected', 'new', 'china', 'virus'],
#  ['virus',
#   'cases',
#   'south',
#   'korea',
#   'delays',
#   'table',
#   'tennis',
#   'team',
#   'world',
#   'champs'],
#  ['dog',
#   'tests',
#   'weak',
#   'positive',
#   'coronavirus',
#   'hong',
#   'kong',
#   'first',
#   'possible',
#   'infection',
#   'pet'],
#  ['brazil', 'confirms', 'first', 'coronavirus', 'case', 'latin', 'america'],
#  ['hawaiian',
#   'airlines',
#   'temporarily',
#   'suspends',
#   'service',
#   'south',
#   'korea',
#   'due',
#   'spike',
#   'coronavirus',
#   'cases'],
#  ['discharged',
#   'coronavirus',
#   'patients',
#   'china',
#   'test',
#   'positive',
#   'second',
#   'time',
#   'report'],
#  ['coronavirus',
#   'fears',
#   'send',
#   'face',
#   'mask',
#   'prices',
#   'skyrocketing',
#   'prompt',
#   'warnings',
#   'price',
#   'gouging'],
#  ['coronavirus', 'epidemic', 'fears', 'shuts', 'france', 'louvre', 'museum'],
#  ['coronavirus',
#   'lockdown',
#   'china',
#   'prevents',
#   'young',
#   'boy',
#   'leaving',
#   'home',
#   'grandfather',
#   'died',
#   'report'],
#  ['says',
#   'coronavirus',
#   'absolutely',
#   'potential',
#   'pandemic',
#   'status',
#   'italy',
#   'iran',
#   'brace',
#   'surge'],
#  ['sean',
#   'hannity',
#   'accuses',
#   'dems',
#   'weaponizing',
#   'coronavirus',
#   'score',
#   'cheap',
#   'repulsive',
#   'political',
#   'points'],
#  ['ioc', 'senior', 'member', 'months', 'decide', 'fate', 'tokyo', 'olympics'],
#  ['sen',
#   'john',
#   'kennedy',
#   'walks',
#   'back',
#   'earlier',
#   'criticism',
#   'trump',
#   'admin',
#   'handling',
#   'coronavirus',
#   'pleased'],
#  ['dr',
#   'marc',
#   'siegel',
#   'warns',
#   'coronavirus',
#   'community',
#   'spread',
#   'says',
#   'patients',
#   'responding',
#   'treatments'],
#  ['cuccinelli',
#   'rule',
#   'startling',
#   'theory',
#   'coronavirus',
#   'origins',
#   'entirely',
#   'sure',
#   'yet'],
#  ['social',
#   'media',
#   'revives',
#   'speculation',
#   'dean',
#   'koontz',
#   'novel',
#   'predicted',
#   'disease',
#   'similar',
#   'coronavirus'],
#  ['sporting', 'events', 'affected', 'spreading', 'virus'],
#  ['former', 'denmark', 'soccer', 'player', 'quarantined', 'virus'],
#  ['ingraham', 'contain', 'virus', 'protect', 'freedom'],
#  ['virus',
#   'cancellations',
#   'send',
#   'olympic',
#   'beach',
#   'hopefuls',
#   'scrambling'],
#  ['iran',
#   'coronavirus',
#   'task',
#   'force',
#   'head',
#   'contracts',
#   'illness',
#   'country',
#   'death',
#   'toll',
#   'reaches'],
#  ['betsy',
#   'mccaughey',
#   'coronavirus',
#   'lies',
#   'endanger',
#   'us',
#   'practical',
#   'steps',
#   'government',
#   'take'],
#  ['nebraska',
#   'nurse',
#   'overseeing',
#   'quarantine',
#   'us',
#   'coronavirus',
#   'patients',
#   'says',
#   'well'],
#  ['washington',
#   'high',
#   'school',
#   'closed',
#   'coronavirus',
#   'concerns',
#   'staff',
#   'member',
#   'relative',
#   'tested',
#   'virus'],
#  ['coronavirus',
#   'disruption',
#   'everyday',
#   'life',
#   'us',
#   'might',
#   'severe',
#   'cdc',
#   'official',
#   'says'],
#  ['iran',
#   'vice',
#   'president',
#   'contracts',
#   'coronavirus',
#   'country',
#   'tally',
#   'spikes'],
#  ['nbc',
#   'news',
#   'richard',
#   'engel',
#   'takes',
#   'heat',
#   'saying',
#   'coronavirus',
#   'bat',
#   'virus',
#   'china',
#   'virus'],
#  ['cdc',
#   'director',
#   'says',
#   'coronavirus',
#   'threat',
#   'us',
#   'remains',
#   'low',
#   'warns',
#   'new',
#   'cases'],
#  ['trump',
#   'administration',
#   'expected',
#   'ask',
#   'congress',
#   'combat',
#   'coronavirus'],
#  ['denmark',
#   'sees',
#   'first',
#   'coronavirus',
#   'case',
#   'man',
#   'returning',
#   'italy',
#   'vacation'],
#  ['varney', 'dems', 'drumming', 'panic', 'coronavirus', 'driving', 'markets'],
#  ['tucker',
#   'carlson',
#   'says',
#   'coronavirus',
#   'response',
#   'shows',
#   'identity',
#   'politics',
#   'trumped',
#   'public',
#   'health'],
#  ['us',
#   'intelligence',
#   'agencies',
#   'monitoring',
#   'worldwide',
#   'spread',
#   'coronavirus',
#   'concerns',
#   'india',
#   'iran',
#   'report'],
#  ['trump',
#   'addresses',
#   'coronavirus',
#   'primetime',
#   'news',
#   'conference',
#   'fears',
#   'us',
#   'outbreak',
#   'spread'],
#  ['coronavirus',
#   'case',
#   'unknown',
#   'origin',
#   'us',
#   'hospitalized',
#   'days',
#   'tested',
#   'officials'],
#  ['dr',
#   'anthony',
#   'fauci',
#   'tells',
#   'public',
#   'prepared',
#   'coronavirus',
#   'still',
#   'things',
#   'always'],
#  ['trump',
#   'holds',
#   'rally',
#   'north',
#   'charleston',
#   'eve',
#   'dems',
#   'south',
#   'carolina',
#   'primary'],
#  ['cdc',
#   'issues',
#   'coronavirus',
#   'warning',
#   'nonessential',
#   'south',
#   'korea',
#   'travel'],
#  ['dr',
#   'manny',
#   'alvarez',
#   'coronavirus',
#   'prepare',
#   'protect',
#   'us',
#   'gears',
#   'fight'],
#  ['dr',
#   'siegel',
#   'reports',
#   'nebraska',
#   'biocontainment',
#   'facility',
#   'coronavirus',
#   'may',
#   'contagious',
#   'flu'],
#  ['tucker', 'carlson', 'sounds', 'alarm', 'america', 'ready', 'coronavirus'],
#  ['human', 'coronaviruses', 'live', 'surfaces', 'days', 'study', 'finds'],
#  ['oregon',
#   'coronavirus',
#   'patient',
#   'grade',
#   'school',
#   'employee',
#   'school',
#   'closed',
#   'deep',
#   'cleaning',
#   'officials',
#   'say'],
#  ['pelosi',
#   'tours',
#   'san',
#   'francisco',
#   'chinatown',
#   'attempt',
#   'ease',
#   'fears',
#   'coronavirus'],
#  ['could', 'coronavirus', 'become', 'pandemic', 'know', 'classification'],
#  ['gutfeld', 'bernie', 'non', 'plan', 'virus'],
#  ['journalists',
#   'fear',
#   'contracting',
#   'virus',
#   'coverage',
#   'increasingly',
#   'criticized'],
#  ['dream',
#   'denied',
#   'virus',
#   'dashes',
#   'dayton',
#   'magical',
#   'hoops',
#   'season'],
#  ['pistons', 'christian', 'wood', 'tests', 'positive', 'virus', 'ap'],
#  ['wife', 'spain', 'prime', 'minister', 'tests', 'positive', 'virus'],
#  ['tokyo',
#   'calls',
#   'test',
#   'event',
#   'growing',
#   'virus',
#   'threatens',
#   'olympics'],
#  ['vail', 'alterra', 'close', 'ski', 'resorts', 'amid', 'virus', 'outbreak'],
#  ['season', 'doubt', 'japan', 'baseball', 'taps', 'virus', 'experts'],
#  ['virus', 'mind', 'korea', 'sungjae', 'im', 'wins', 'honda', 'classic'],
#  ['world', 'cup', 'skiing', 'finals', 'cortina', 'canceled', 'virus'],
#  ['member', 'iranian', 'clerical', 'assembly', 'dies', 'virus', 'reports'],
#  ['across',
#   'faiths',
#   'religious',
#   'rules',
#   'bent',
#   'virus',
#   'alters',
#   'worship'],
#  ['virus', 'iran', 'gates', 'tehran', 'failed', 'stop', 'outbreak'],
#  ['cramer', 'suspend', 'tax', 'collection'],
#  ['shoot',
#   'stray',
#   'dogs',
#   'win',
#   'cash',
#   'prizes',
#   'chinese',
#   'officials',
#   'slaughtered',
#   'canines'],
#  ['scientist', 'coronavirus', 'airborne', 'extremely', 'contagious'],
#  ['italy',
#   'patient',
#   'one',
#   'forced',
#   'wait',
#   'hours',
#   'tested',
#   'coronavirus'],
#  ['coronavirus', 'wuhan', 'football', 'team', 'stuck', 'spain', 'months'],
#  ['uk', 'schools', 'close', 'two', 'coronavirus', 'cases', 'confirmed'],
#  ['nigeria',
#   'africa',
#   'populous',
#   'country',
#   'confirms',
#   'first',
#   'case',
#   'coronavirus'],
#  ['unwieldy',
#   'anti',
#   'stigma',
#   'coronavirus',
#   'names',
#   'confuse',
#   'indonesian',
#   'official'],
#  ['nbc', 'engel', 'coronavirus', 'bat', 'virus', 'china', 'virus'],
#  ['iran',
#   'lawmaker',
#   'regime',
#   'lying',
#   'uncontrolled',
#   'china',
#   'virus',
#   'spread',
#   'dead'],
#  ['study', 'china', 'lied', 'wuhan', 'virus', 'originate', 'meat', 'market'],
#  ['xi',
#   'jinping',
#   'berates',
#   'communists',
#   'obvious',
#   'shortcomings',
#   'coronavirus'],
#  ['mike',
#   'pence',
#   'coronavirus',
#   'average',
#   'american',
#   'need',
#   'go',
#   'buy',
#   'mask'],
#  ['mullah',
#   'virus',
#   'iranian',
#   'protesters',
#   'condemn',
#   'regime',
#   'coronavirus',
#   'response',
#   'failure'],
#  ['hillary', 'clinton', 'saying', 'chinese', 'virus', 'racist', 'rhetoric'],
#  ['new', 'yorkers', 'voluntary', 'isolation', 'coronavirus', 'testing'],
#  ['coronavirus',
#   'study',
#   'one',
#   'traveler',
#   'china',
#   'infected',
#   'people',
#   'washington',
#   'state'],
#  ['expert',
#   'chinese',
#   'scientists',
#   'sell',
#   'lab',
#   'animals',
#   'meat',
#   'black',
#   'market'],
#  ['watch',
#   'donald',
#   'trump',
#   'calling',
#   'coronavirus',
#   'chinese',
#   'virus',
#   'kung',
#   'flu',
#   'racist'],
#  ['italian',
#   'man',
#   'coronavirus',
#   'hid',
#   'symptoms',
#   'faces',
#   'years',
#   'prison'],
#  ['rudy', 'gobert', 'apologizes', 'careless', 'coronavirus'],
#  ['florida',
#   'man',
#   'coronavirus',
#   'credits',
#   'drug',
#   'touted',
#   'trump',
#   'saving',
#   'life'],
#  ['france', 'germany', 'close', 'schools', 'coronavirus', 'cluster', 'zones'],
#  ['donald', 'trump', 'u', 'economy', 'may', 'headed', 'recession'],
#  ['boris',
#   'reveals',
#   'coronavirus',
#   'battle',
#   'plan',
#   'outbreaks',
#   'highly',
#   'likely',
#   'business',
#   'usual',
#   'britain'],
#  ['nolte',
#   'mere',
#   'days',
#   'ago',
#   'joe',
#   'biden',
#   'still',
#   'attacking',
#   'trump',
#   'travel',
#   'bans'],
#  ['u', 'washington', 'professor', 'dies', 'chinese', 'coronavirus'],
#  ['oprah', 'launches', 'apple', 'tv', 'series', 'coronavirus'],
#  ['donald', 'trump', 'plans', 'address', 'nation', 'response', 'coronavirus'],
#  ['france',
#   'goes',
#   'ahead',
#   'local',
#   'mayoral',
#   'elections',
#   'despite',
#   'pandemic'],
#  ['actor',
#   'josh',
#   'gad',
#   'defends',
#   'nbc',
#   'peter',
#   'alexander',
#   'president',
#   'pig',
#   'rolling'],
#  ['nba', 'says', 'virus', 'hiatus', 'likely', 'last', 'least', 'month'],
#  ['tucker',
#   'carlson',
#   'colleges',
#   'forced',
#   'reform',
#   'chinese',
#   'virus',
#   'shutdowns'],
#  ['la',
#   'times',
#   'smacks',
#   'elon',
#   'musk',
#   'trying',
#   'build',
#   'luxury',
#   'cars',
#   'chinese',
#   'virus',
#   'lockdown'],
#  ['coronavirus',
#   'italy',
#   'total',
#   'death',
#   'toll',
#   'rises',
#   'percent',
#   'hours',
#   'exceeds'],
#  ['reasons',
#   'doubt',
#   'china',
#   'claim',
#   'stopped',
#   'seeing',
#   'coronavirus',
#   'cases'],
#  ['europe',
#   'crisis',
#   'nations',
#   'across',
#   'continent',
#   'grapple',
#   'growing',
#   'coronavirus',
#   'pandemic'],
#  ['twitter',
#   'lets',
#   'elon',
#   'musk',
#   'post',
#   'coronavirus',
#   'misinformation',
#   'despite',
#   'strict',
#   'policy'],
#  ['donald', 'trump', 'coronavirus', 'much', 'control', 'united', 'states'],
#  ['pathogens',
#   'expert',
#   'praises',
#   'cdc',
#   'expanding',
#   'coronavirus',
#   'testing',
#   'u'],
#  ['tourists',
#   'quarantined',
#   'canary',
#   'islands',
#   'hotel',
#   'coronavirus',
#   'confirmed'],
#  ['limbaugh', 'coronavirus', 'weaponized', 'bring', 'trump'],
#  ['ohio',
#   'health',
#   'director',
#   'walks',
#   'back',
#   'wild',
#   'estimate',
#   'coronavirus',
#   'infections',
#   'state'],
#  ['china', 'threatens', 'emp', 'attack', 'south', 'china', 'sea'],
#  ['times',
#   'establishment',
#   'media',
#   'used',
#   'bigoted',
#   'phrases',
#   'refer',
#   'coronavirus'],
#  ['susan',
#   'rice',
#   'china',
#   'behaving',
#   'well',
#   'blaming',
#   'u',
#   'coronavirus',
#   'u',
#   'behaving',
#   'well',
#   'trump',
#   'uses',
#   'racist',
#   'descriptions'],
#  ['four', 'olympic', 'athletes', 'quarantined', 'coronavirus', 'exposure'],
#  ['white', 'house', 'donald', 'trump', 'tested', 'coronavirus'],
#  ['scarborough',
#   'trump',
#   'admin',
#   'coronavirus',
#   'stupidity',
#   'get',
#   'americans',
#   'killed'],
#  ['sweden', 'tests', 'ebola', 'medication', 'coronavirus', 'patients'],
#  ['state', 'emergency', 'declared', 'washington', 'state', 'coronavirus'],
#  ['tom', 'steyer', 'coronavirus', 'proves', 'trump', 'incompetent', 'economy'],
#  ['donald',
#   'trump',
#   'promises',
#   'victory',
#   'coronavirus',
#   'america',
#   'get',
#   'done'],
#  ['watch',
#   'ayanna',
#   'pressley',
#   'term',
#   'chinese',
#   'coronavirus',
#   'painful',
#   'immigrants'],
#  ['donald', 'trump', 'declares', 'national', 'emergency', 'coronavirus'],
#  ['study', 'percent', 'infected', 'coronavirus', 'public', 'undetected'],
#  ['watch',
#   'live',
#   'president',
#   'trump',
#   'coronavirus',
#   'task',
#   'force',
#   'speaks',
#   'press'],
#  ['ann', 'coulter', 'cheap', 'tvs', 'expensive', 'flu'],
#  ['donald', 'trump', 'unfortunate', 'china', 'secretive', 'coronavirus'],
#  ['federally',
#   'funded',
#   'studies',
#   'show',
#   'coronavirus',
#   'survives',
#   'hours',
#   'airborne'],
#  ['video',
#   'italian',
#   'obituaries',
#   'puts',
#   'coronavirus',
#   'death',
#   'toll',
#   'perspective'],
#  ['star',
#   'forward',
#   'kevin',
#   'durant',
#   'among',
#   'four',
#   'brooklyn',
#   'nets',
#   'players',
#   'test',
#   'positive',
#   'coronavirus'],
#  ['donald', 'trump', 'coronavirus', 'could', 'last', 'july', 'august'],
#  ['venezuela',
#   'maduro',
#   'imports',
#   'cuban',
#   'doctors',
#   'imposes',
#   'chinese',
#   'coronavirus',
#   'quarantine'],
#  ['actress',
#   'evangeline',
#   'lilly',
#   'dismisses',
#   'social',
#   'distance',
#   'warnings',
#   'living',
#   'cancer',
#   'stricken',
#   'father'],
#  ['taliban', 'coronavirus', 'decree', 'allah', 'sins', 'mankind'],
#  ['report',
#   'nebraska',
#   'coach',
#   'hospitalized',
#   'appearing',
#   'extremely',
#   'ill',
#   'team',
#   'quarantined'],
#  ['donald',
#   'trump',
#   'americans',
#   'keep',
#   'gatherings',
#   'ten',
#   'people',
#   'defeat',
#   'coronavirus'],
#  ['donald',
#   'trump',
#   'shakes',
#   'hands',
#   'supporters',
#   'despite',
#   'coronavirus',
#   'fears'],
#  ['rapper',
#   'drake',
#   'self',
#   'quarantining',
#   'partying',
#   'coronavirus',
#   'positive',
#   'nba',
#   'star',
#   'kevin',
#   'durant'],
#  ['ohio',
#   'hit',
#   'coronavirus',
#   'cases',
#   'governor',
#   'dewine',
#   'declares',
#   'state',
#   'emergency'],
#  ['elderly', 'cleric', 'becomes', 'first', 'coronavirus', 'death', 'iraq'],
#  ['watch',
#   'brazil',
#   'christ',
#   'redeemer',
#   'statue',
#   'lit',
#   'flags',
#   'countries',
#   'affected',
#   'coronavirus'],
#  ['video',
#   'italian',
#   'actor',
#   'pleads',
#   'help',
#   'sister',
#   'dies',
#   'coronavirus',
#   'italy',
#   'abandoned',
#   'us'],
#  ['joe',
#   'biden',
#   'demands',
#   'trump',
#   'invoke',
#   'defense',
#   'production',
#   'act',
#   'minutes',
#   'president'],
#  ['hawaii',
#   'orders',
#   'mandatory',
#   'day',
#   'quarantine',
#   'visitors',
#   'returning',
#   'residents'],
#  ['uk',
#   'wartime',
#   'style',
#   'four',
#   'month',
#   'elderly',
#   'quarantine',
#   'planned'],
#  ['coronavirus',
#   'dr',
#   'fauci',
#   'applauds',
#   'flight',
#   'cancellations',
#   'world',
#   'health',
#   'organization',
#   'discouraged'],
#  ['exclusive',
#   'newt',
#   'gingrich',
#   'coronavirus',
#   'crisis',
#   'live',
#   'rome',
#   'turmoil',
#   'forcing',
#   'rethinking',
#   'lots',
#   'things'],
#  ['donald',
#   'trump',
#   'delights',
#   'cpac',
#   'crowd',
#   'election',
#   'year',
#   'performance',
#   'see',
#   'next',
#   'year'],
#  ['watch',
#   'live',
#   'white',
#   'house',
#   'coronavirus',
#   'task',
#   'force',
#   'holds',
#   'press',
#   'briefing'],
#  ['conway',
#   'cdc',
#   'guidelines',
#   'mitigate',
#   'health',
#   'crisis',
#   'literally',
#   'save',
#   'lives'],
#  ['whoopi', 'goldberg', 'coronavirus', 'mother', 'nature', 'us', 'china'],
#  ['police',
#   'man',
#   'arrested',
#   'lying',
#   'coronavirus',
#   'get',
#   'paid',
#   'vacation'],
#  ['morning',
#   'joe',
#   'coronavirus',
#   'sociopathic',
#   'trump',
#   'actively',
#   'working',
#   'tank',
#   'stock',
#   'market'],
#  ['model',
#   'kaia',
#   'gerber',
#   'social',
#   'distancing',
#   'outside',
#   'surrounded',
#   'celebrity',
#   'friends'],
#  ['coronavirus',
#   'federal',
#   'judge',
#   'rules',
#   'migrants',
#   'must',
#   'stay',
#   'detention',
#   'center'],
#  ['fda', 'urged', 'approve', 'chloroquine', 'treat', 'covid'],
#  ['road',
#   'lockdown',
#   'britain',
#   'went',
#   'coronavirus',
#   'light',
#   'touch',
#   'national',
#   'house',
#   'arrest'],
#  ['china', 'pushes', 'propaganda', 'u', 'created', 'coronavirus'],
#  ['china',
#   'attempt',
#   'return',
#   'coronavirus',
#   'origin',
#   'province',
#   'normalcy',
#   'fails'],
#  ['bolsonaro',
#   'brazil',
#   'winning',
#   'soccer',
#   'match',
#   'coronavirus',
#   'thanks',
#   'coach',
#   'bolsonaro'],
#  ['cdc', 'recommends', 'canceling', 'postponing', 'gatherings', 'people'],
#  ['ohio',
#   'illinois',
#   'announce',
#   'closure',
#   'restaurants',
#   'bars',
#   'amid',
#   'coronavirus',
#   'pandemic'],
#  ['celtics',
#   'marcus',
#   'smart',
#   'two',
#   'lakers',
#   'test',
#   'positive',
#   'coronavirus'],
#  ['ucla',
#   'duke',
#   'join',
#   'growing',
#   'list',
#   'coronavirus',
#   'campus',
#   'closures'],
#  ['lindsey',
#   'graham',
#   'absolutely',
#   'eb',
#   'green',
#   'card',
#   'expansion',
#   'coronavirus',
#   'bill'],
#  ['biden',
#   'coronavirus',
#   'proposal',
#   'cribs',
#   'heavily',
#   'trump',
#   'administration'],
#  ['iranian',
#   'president',
#   'contradicts',
#   'ayatollah',
#   'urges',
#   'serious',
#   'concern',
#   'chinese',
#   'coronavirus'],
#  ['watch',
#   'live',
#   'president',
#   'donald',
#   'trump',
#   'gives',
#   'oval',
#   'office',
#   'address',
#   'nation',
#   'coronavirus'],
#  ['bernie', 'sanders', 'predicts', 'win', 'michigan', 'primary'],
#  ['joe', 'biden', 'projected', 'winner', 'maine', 'primary'],
#  ['plouffe', 'either', 'bernie', 'sanders', 'joe', 'biden', 'nominee'],
#  ['carville', 'shut', 'puppy', 'biden', 'sanders', 'respect', 'voters'],
#  ['carville', 'klobuchar', 'buttigieg', 'probably', 'wednesday'],
#  ['best',
#   'presidential',
#   'candidate',
#   'years',
#   'michael',
#   'douglas',
#   'hits',
#   'campaign',
#   'trail',
#   'bloomberg'],
#  ['jussie',
#   'smollett',
#   'prosecutor',
#   'kim',
#   'foxx',
#   'fends',
#   'primary',
#   'challengers'],
#  ['joe',
#   'biden',
#   'declared',
#   'winner',
#   'missouri',
#   'democrat',
#   'primary',
#   'race'],
#  ['democrats',
#   'condemn',
#   'bernie',
#   'sanders',
#   'praise',
#   'fidel',
#   'castro',
#   'absolutely',
#   'unacceptable'],
#  ['poll',
#   'bernie',
#   'sanders',
#   'takes',
#   'national',
#   'lead',
#   'among',
#   'black',
#   'voters'],
#  ['mccaskill',
#   'biden',
#   'confrontation',
#   'voter',
#   'help',
#   'white',
#   'non',
#   'college',
#   'voters'],
#  ['biden',
#   'deputy',
#   'manager',
#   'bedingfield',
#   'voter',
#   'confrontation',
#   'voters',
#   'looking',
#   'someone',
#   'allow',
#   'distortions'],
#  ['poll', 'joe', 'biden', 'national', 'lead', 'shrinks', 'single', 'digits'],
#  ['james', 'comey', 'endorses', 'votes', 'joe', 'biden', 'virginia'],
#  ['uk', 'schools', 'close', 'two', 'coronavirus', 'cases', 'confirmed'],
#  ['trump',
#   'mike',
#   'bloomberg',
#   'failed',
#   'campaign',
#   'worst',
#   'embarrassing',
#   'experience',
#   'life'],
#  ['harvard',
#   'counsels',
#   'students',
#   'combat',
#   'coronavirus',
#   'anxiety',
#   'yoga'],
#  ['cnn', 'guest', 'think', 'nobody', 'want', 'donald', 'trump', 'defeated'],
#  ['bill', 'de', 'blasio', 'warns', 'joe', 'biden', 'vetted'],
#  ['bernie',
#   'sanders',
#   'vows',
#   'debate',
#   'biden',
#   'drop',
#   'michigan',
#   'defeat'],
#  ['video', 'tom', 'steyer', 'dances', 'back', 'azz', 'rapper', 'juvenile'],
#  ['carville',
#   'calls',
#   'sanders',
#   'exit',
#   'clyburn',
#   'saved',
#   'democratic',
#   'party'],
#  ['rigged',
#   'jim',
#   'clyburn',
#   'suggests',
#   'dnc',
#   'cancel',
#   'debates',
#   'primaries',
#   'anoint',
#   'biden'],
#  ['poll', 'bernie', 'sanders', 'joe', 'biden', 'neck', 'neck', 'texas'],
#  ['dnc',
#   'change',
#   'debate',
#   'rules',
#   'tulsi',
#   'gabbard',
#   'reaches',
#   'delegate',
#   'requirement'],
#  ['dnc',
#   'changes',
#   'debate',
#   'rules',
#   'tulsi',
#   'gabbard',
#   'reaches',
#   'previous',
#   'requirement'],
#  ['politico',
#   'democrat',
#   'establishment',
#   'panic',
#   'mode',
#   'bernie',
#   'sanders'],
#  ['super', 'tuesday', 'race', 'tightens', 'amy', 'klobuchar', 'minnesota'],
#  ['live', 'updates', 'democrats', 'debate', 'south', 'carolina'],
#  ['jumanji', 'star', 'jack', 'black', 'elizabeth', 'warren'],
#  ['live', 'updates', 'super', 'tuesday', 'election', 'results'],
#  ['cory',
#   'booker',
#   'endorses',
#   'joe',
#   'biden',
#   'restore',
#   'honor',
#   'oval',
#   'office'],
#  ['nolte',
#   'poll',
#   'shows',
#   'trump',
#   'earns',
#   'twice',
#   'much',
#   'trust',
#   'media'],
#  ['donald',
#   'trump',
#   'delights',
#   'cpac',
#   'crowd',
#   'election',
#   'year',
#   'performance',
#   'see',
#   'next',
#   'year'],
#  ['sanders',
#   'establishment',
#   'forced',
#   'klobuchar',
#   'buttigieg',
#   'try',
#   'defeat'],
#  ['coronavirus', 'arizona', 'democrats', 'push', 'mail', 'voting', 'election'],
#  ['marianne',
#   'williamson',
#   'backs',
#   'bernie',
#   'sanders',
#   'energy',
#   'unquestionably'],
#  ['msnbc',
#   'chris',
#   'matthews',
#   'facing',
#   'calls',
#   'resign',
#   'comparing',
#   'sanders',
#   'win',
#   'nazi',
#   'invasion'],
#  ['clyburn',
#   'rushes',
#   'save',
#   'biden',
#   'south',
#   'carolina',
#   'firewall',
#   'sanders',
#   'threat',
#   'looms'],
#  ['marianne',
#   'williamson',
#   'slams',
#   'joe',
#   'biden',
#   'rise',
#   'resurrection',
#   'coup'],
#  ['president', 'trump', 'offers', 'hope', 'coronavirus', 'one', 'day', 'say'],
#  ['report',
#   'joe',
#   'biden',
#   'already',
#   'choosing',
#   'cabinet',
#   'picks',
#   'kerry',
#   'rice',
#   'return'],
#  ['video',
#   'joe',
#   'biden',
#   'senior',
#   'adviser',
#   'symone',
#   'sanders',
#   'knocked',
#   'ground',
#   'rally',
#   'scrum'],
#  ['maxine', 'waters', 'know', 'biden', 'beat', 'trump'],
#  ['team',
#   'warren',
#   'endorses',
#   'bernie',
#   'sanders',
#   'elizabeth',
#   'warren',
#   'remains',
#   'silent'],
#  ['trevor',
#   'noah',
#   'mocks',
#   'kamala',
#   'harris',
#   'hostage',
#   'style',
#   'video',
#   'endorsement',
#   'biden'],
#  ['nolte', 'trump', 'russia', 'hoax', 'already', 'crashed', 'burned'],
#  ['nolte',
#   'polls',
#   'show',
#   'elizabeth',
#   'warren',
#   'losing',
#   'home',
#   'state',
#   'tuesday'],
#  ['exclusive',
#   'coronavirus',
#   'crisis',
#   'rages',
#   'tom',
#   'cotton',
#   'launches',
#   'television',
#   'ads',
#   'exposing',
#   'joe',
#   'biden',
#   'chinese',
#   'corruption'],
#  ['report',
#   'sen',
#   'ron',
#   'johnson',
#   'planning',
#   'release',
#   'interim',
#   'findings',
#   'burisma',
#   'biden',
#   'probe'],
#  ['report', 'nba', 'bracing', 'mid', 'late', 'june', 'return', 'earliest'],
#  ['ryan',
#   'helfenbein',
#   'biden',
#   'sanders',
#   'two',
#   'sides',
#   'democratic',
#   'coin'],
#  ['sanders', 'trump', 'greatest', 'threat', 'country', 'modern', 'history'],
#  ['pollak',
#   'bernie',
#   'sanders',
#   'supporters',
#   'get',
#   'taste',
#   'media',
#   'abuse',
#   'trump'],
#  ['live', 'updates', 'south', 'carolina', 'primary', 'results'],
#  ['maryland', 'postpones', 'presidential', 'primary', 'election'],
#  ['rahm',
#   'emanuel',
#   'democrats',
#   'low',
#   'primary',
#   'turnout',
#   'flashing',
#   'yellow',
#   'light'],
#  ['joe', 'biden', 'projected', 'winner', 'south', 'carolina', 'primary'],
#  ['joe', 'biden', 'wins', 'mississippi', 'democratic', 'primary'],
#  ['joe', 'biden', 'projected', 'winner', 'michigan', 'primary'],
#  ['axelrod', 'buttigieg', 'needs', 'consider', 'wants', 'stay'],
#  ['joe',
#   'biden',
#   'mistakenly',
#   'endorses',
#   'jaime',
#   'harrison',
#   'president',
#   'south',
#   'carolina',
#   'victory',
#   'speech'],
#  ['democrats',
#   'make',
#   'pitch',
#   'al',
#   'sharpton',
#   'breakfast',
#   'south',
#   'carolina'],
#  ['joe',
#   'biden',
#   'slips',
#   'southern',
#   'accent',
#   'declaring',
#   'south',
#   'carolina',
#   'victory'],
#  ['california', 'primary', 'darrell', 'issa', 'could', 'return', 'congress'],
#  ['charles',
#   'hurt',
#   'democrats',
#   'goofball',
#   'primary',
#   'continues',
#   'amid',
#   'global',
#   'pandemic'],
#  ['joe',
#   'biden',
#   'routs',
#   'bernie',
#   'sanders',
#   'florida',
#   'democrat',
#   'primary'],
#  ['louisiana',
#   'postpones',
#   'presidential',
#   'primary',
#   'elections',
#   'coronavirus',
#   'fears'],
#  ['bernie',
#   'sanders',
#   'wins',
#   'california',
#   'primary',
#   'though',
#   'votes',
#   'still',
#   'coming'],
#  ['brooks', 'unlikely', 'another', 'twist', 'democratic', 'primary'],
#  ['pelosi', 'bernie', 'sanders', 'drop', 'democrat', 'primary'],
#  ['joe', 'biden', 'projected', 'win', 'idaho', 'democrat', 'primary'],
#  ['joe',
#   'biden',
#   'becomes',
#   'youngest',
#   'male',
#   'candidate',
#   'democrat',
#   'primary'],
#  ['joe', 'biden', 'projected', 'winner', 'illinois', 'primary'],
#  ['joe', 'biden', 'declared', 'winner', 'arizona', 'democrat', 'primary'],
#  ['dennis', 'lennox', 'michigan', 'could', 'end', 'bernie', 'sanders'],
#  ['bernie',
#   'sanders',
#   'congratulates',
#   'joe',
#   'biden',
#   'south',
#   'carolina',
#   'victory',
#   'nobody',
#   'wins'],
#  ['axelrod', 'know', 'democratic', 'race', 'end'],
#  ['cbs',
#   'moderators',
#   'struggle',
#   'control',
#   'chaotic',
#   'tenth',
#   'democrat',
#   'debate'],
#  ['mcauliffe',
#   'endorsing',
#   'biden',
#   'buttigieg',
#   'klobuchar',
#   'steyer',
#   'bloomberg',
#   'consider',
#   'dropping'],
#  ['joe',
#   'biden',
#   'delivers',
#   'speech',
#   'coronavirus',
#   'primary',
#   'wins',
#   'florida',
#   'illinois'],
#  ['watch',
#   'cnn',
#   'graphic',
#   'mistakenly',
#   'calls',
#   'mississippi',
#   'bernie',
#   'sanders'],
#  ['ohio',
#   'postpones',
#   'election',
#   'way',
#   'good',
#   'conscience',
#   'could',
#   'order',
#   'election'],
#  ['joe',
#   'biden',
#   'takes',
#   'lead',
#   'bernie',
#   'sanders',
#   'popular',
#   'vote',
#   'democratic',
#   'presidential',
#   'primary'],
#  ['nolte',
#   'biden',
#   'brain',
#   'freezes',
#   'pile',
#   'days',
#   'away',
#   'make',
#   'break',
#   'south',
#   'carolina',
#   'primary'],
#  ['obama',
#   'breaks',
#   'silence',
#   'ahead',
#   'super',
#   'tuesday',
#   'showdown',
#   'sanders',
#   'biden'],
#  ['pete', 'buttigieg', 'end', 'presidential', 'campaign'],
#  ['michigan',
#   'primary',
#   'donald',
#   'trump',
#   'earns',
#   'three',
#   'times',
#   'votes',
#   'barack',
#   'obama'],
#  ['fifth',
#   'member',
#   'squad',
#   'marie',
#   'newman',
#   'unseats',
#   'dan',
#   'lipinski',
#   'il',
#   'democrat',
#   'primary'],
#  ['joe',
#   'biden',
#   'wins',
#   'texas',
#   'completing',
#   'super',
#   'tuesday',
#   'sweep',
#   'south'],
#  ['kentucky', 'postpones', 'election', 'coronavirus', 'concerns', 'grow'],
#  ['watch',
#   'protesters',
#   'rush',
#   'stage',
#   'joe',
#   'biden',
#   'super',
#   'tuesday',
#   'speech'],
#  ['donald',
#   'trump',
#   'elizabeth',
#   'warren',
#   'dropping',
#   'late',
#   'save',
#   'crazy',
#   'bernie'],
#  ['illegal',
#   'aliens',
#   'hope',
#   'influence',
#   'super',
#   'tuesday',
#   'primaries',
#   'democrats'],
#  ['national',
#   'poll',
#   'joe',
#   'biden',
#   'takes',
#   'double',
#   'digit',
#   'lead',
#   'sanders'],
#  ['tulsi',
#   'gabbard',
#   'drops',
#   'presidential',
#   'race',
#   'endorses',
#   'joe',
#   'biden'],
#  ['coronavirus',
#   'rod',
#   'blagojevich',
#   'urges',
#   'illinois',
#   'cancel',
#   'primaries'],
#  ['poll', 'sanders', 'bloomberg', 'leapfrog', 'biden', 'new', 'york'],
#  ['mike', 'bloomberg', 'bad', 'jokes', 'fall', 'flat', 'democrat', 'debate'],
#  ['biden',
#   'urges',
#   'rivals',
#   'quit',
#   'fail',
#   'attract',
#   'support',
#   'black',
#   'voters'],
#  ['biden', 'wins', 'south', 'carolina', 'primary'],
#  ['direct',
#   'primary',
#   'care',
#   'solution',
#   'america',
#   'health',
#   'care',
#   'woes'],
#  ['sanders', 'leads', 'california', 'primary', 'exit', 'polls'],
#  ['biden', 'wins', 'florida', 'primary', 'blowout'],
#  ['sanders', 'assess', 'campaign', 'following', 'primary', 'defeats'],
#  ['pro',
#   'life',
#   'dem',
#   'dan',
#   'lipinksi',
#   'loses',
#   'primary',
#   'progressive',
#   'challenger'],
#  ['biden',
#   'wins',
#   'minnesota',
#   'democratic',
#   'primary',
#   'klobuchar',
#   'endorsement'],
#  ['sanders',
#   'wins',
#   'colorado',
#   'democratic',
#   'primary',
#   'biden',
#   'takes',
#   'oklahoma',
#   'tennessee'],
#  ['louisiana', 'becomes', 'first', 'state', 'delay', 'primary', 'coronavirus'],
#  ['race', 'succeed', 'mark', 'meadows', 'dan', 'driscoll', 'break', 'pack'],
#  ['biden',
#   'captures',
#   'north',
#   'carolina',
#   'democratic',
#   'primary',
#   'second',
#   'super',
#   'tuesday',
#   'win'],
#  ['pro',
#   'life',
#   'group',
#   'launches',
#   'campaign',
#   'reelect',
#   'democrat',
#   'dan',
#   'lipinski'],
#  ['bloomberg',
#   'claims',
#   'russia',
#   'aiding',
#   'sanders',
#   'primary',
#   'aid',
#   'trump',
#   'general',
#   'election'],
#  ['buttigieg',
#   'reid',
#   'join',
#   'biden',
#   'endorsement',
#   'train',
#   'ahead',
#   'super',
#   'tuesday'],
#  ['biden',
#   'builds',
#   'super',
#   'tuesday',
#   'momentum',
#   'big',
#   'win',
#   'michigan',
#   'primary'],
#  ['pete', 'buttigieg', 'drop', 'presidential', 'race'],
#  ['poll',
#   'biden',
#   'leads',
#   'sanders',
#   'michigan',
#   'following',
#   'dominant',
#   'super',
#   'tuesday',
#   'performance'],
#  ['biden',
#   'wins',
#   'virginia',
#   'democratic',
#   'presidential',
#   'primary',
#   'first',
#   'super',
#   'tuesday',
#   'result'],
#  ['obama', 'called', 'biden', 'congratulate', 'south', 'carolina', 'win'],
#  ['dnc',
#   'moves',
#   'debate',
#   'washington',
#   'c',
#   'avoid',
#   'coronavirus',
#   'outbreak'],
#  ['biden',
#   'neck',
#   'neck',
#   'sanders',
#   'washington',
#   'state',
#   'amid',
#   'coronavirus',
#   'fears'],
#  ['kim',
#   'foxx',
#   'wins',
#   'dem',
#   'primary',
#   'despite',
#   'backlash',
#   'handling',
#   'jussie',
#   'smollett',
#   'prosecution'],
#  ['gop',
#   'michigan',
#   'mayor',
#   'former',
#   'trump',
#   'voter',
#   'endorses',
#   'biden',
#   'ahead',
#   'primary'],
#  ['poll',
#   'biden',
#   'surges',
#   'south',
#   'carolina',
#   'win',
#   'trails',
#   'sanders',
#   'three',
#   'points',
#   'ahead',
#   'super',
#   'tuesday'],
#  ['trump',
#   'mocks',
#   'jeff',
#   'sessions',
#   'forced',
#   'enter',
#   'run',
#   'alabama',
#   'senate',
#   'primary'],
#  ['sherrod',
#   'brown',
#   'concerned',
#   'trump',
#   'could',
#   'cite',
#   'ohio',
#   'primary',
#   'precedent',
#   'delay',
#   'presidential',
#   'election'],
#  ['ohio',
#   'governor',
#   'attempts',
#   'extend',
#   'primary',
#   'june',
#   'forbid',
#   'person',
#   'voting'],
#  ['clyburn',
#   'calls',
#   'cancel',
#   'debates',
#   'biden',
#   'victories',
#   'shut',
#   'primary'],
#  ['ohio',
#   'gov',
#   'declares',
#   'health',
#   'emergency',
#   'postpone',
#   'primary',
#   'florida',
#   'illinois',
#   'arizona',
#   'keep',
#   'polls',
#   'open'],
#  ['democratic', 'primary'],
#  ['coronavirus',
#   'interrupts',
#   'democratic',
#   'presidential',
#   'primary',
#   'elections'],
#  ['nr', 'tweets', 'democratic', 'debate'],
#  ['sanders',
#   'make',
#   'comeback',
#   'tonight',
#   'nr',
#   'tweets',
#   'six',
#   'states',
#   'vote'],
#  ['state', 'democratic', 'race'],
#  ['poll',
#   'bloomberg',
#   'may',
#   'help',
#   'sanders',
#   'win',
#   'texas',
#   'super',
#   'tuesday'],
#  ['establishment', 'democrats', 'played', 'hardball'],
#  ['nearly', 'half', 'states', 'voted', 'next', 'debate'],
#  ['twenty',
#   'things',
#   'caught',
#   'eye',
#   'today',
#   'coronavirus',
#   'churches',
#   'iraq',
#   'march'],
#  ['chinese', 'virus'],
#  ['washington', 'response', 'virus'],
#  ['inside', 'controversy', 'chinese', 'virus'],
#  ['helping', 'airlines', 'pull', 'virus', 'nosedive'],
#  ['media', 'china', 'syndrome'],
#  ['please', 'sober', 'minded', 'coronavirus'],
#  ['trump',
#   'defends',
#   'labeling',
#   'coronavirus',
#   'chinese',
#   'virus',
#   'comes',
#   'china'],
#  ['covid', 'downplayers', 'doomsayers'],
#  ['chinese',
#   'authorities',
#   'gagged',
#   'laboratories',
#   'december',
#   'coronavirus',
#   'sars',
#   'connection'],
#  ['trump',
#   'activates',
#   'national',
#   'guard',
#   'assist',
#   'california',
#   'new',
#   'york',
#   'washington'],
#  ['doj',
#   'threatens',
#   'prosecute',
#   'company',
#   'fixing',
#   'medical',
#   'item',
#   'prices',
#   'capitalize',
#   'coronavirus'],
#  ['trump',
#   'bashes',
#   'chinese',
#   'propagandists',
#   'blaming',
#   'virus',
#   'outbreak',
#   'u',
#   'military'],
#  ['medieval', 'approach', 'virus', 'control'],
#  ['threatening', 'coronavirus'],
#  ['coronavirus', 'truth', 'racist'],
#  ['join', 'nri', 'virus', 'free', 'forums', 'spring'],
#  ['bring', 'early', 'spring'],
#  ['questions', 'coronavirus'],
#  ['county', 'seal', 'borders', 'coronavirus', 'outbreak'],
#  ['nr', 'coronavirus', 'update', 'cross', 'state', 'comparisons', 'u'],
#  ['covid', 'scary', 'enough', 'without', 'scaremongering'],
#  ['happening', 'italy'],
#  ['conversion', 'therapy'],
#  ['real', 'resistance', 'looks', 'like'],
#  ['sanders', 'takes'],
#  ['good', 'chinese', 'soft', 'power'],
#  ['world', 'saddest', 'happiest', 'countries'],
#  ['jurisprudence', 'revolution'],
#  ['end', 'near', 'three', 'apocalyptic', 'novels'],
#  ['chinese', 'wild', 'animal', 'industry', 'wet', 'markets', 'must', 'go'],
#  ['free', 'market', 'economist', 'thoughts', 'coronavirus'],
#  ['dnc',
#   'spokeswoman',
#   'encourages',
#   'sanders',
#   'go',
#   'florida',
#   'listen',
#   'cubans',
#   'went'],
#  ['thing', 'price', 'gouging'],
#  ['abortion', 'fight', 'getting', 'started'],
#  ['china', 'mask', 'mercantilism'],
#  ['history',
#   'small',
#   'state',
#   'presidential',
#   'candidates',
#   'tells',
#   'us',
#   'biden',
#   'chances'],
#  ['cuomo',
#   'urges',
#   'states',
#   'learn',
#   'n',
#   'coronavirus',
#   'outbreak',
#   'future'],
#  ['gene', 'revolution', 'already'],
#  ['limits', 'law'],
#  ['bernie', 'sanders', 'left', 'fake', 'fiscal', 'history', 'america'],
#  ['killing', 'senator'],
#  ['south', 'korea', 'got', 'right'],
#  ['happening', 'italy'],
#  ['establishment', 'democrats', 'played', 'hardball'],
#  ['know', 'cpac', 'coronavirus', 'response'],
#  ['fed'],
#  ['republicans', 'voted'],
#  ['fed'],
#  ['conclude', 'silent', 'spread', 'coronavirus'],
#  ['tweeting', 'market', 'back', 'life'],
#  ['happens',
#   'nation',
#   'elderly',
#   'smokers',
#   'faces',
#   'viral',
#   'respiratory',
#   'illness'],
#  ['testing', 'problem'],
#  ['misleading', 'use', 'wow'],
#  ['coronavirus', 'comes', 'parliament'],
#  ['yale', 'universities', 'ditching', 'western', 'art'],
#  ['biden', 'trump', 'black', 'vote'],
#  ['different',
#   'kind',
#   'saint',
#   'patrick',
#   'day',
#   'coronavirus',
#   'strips',
#   'away',
#   'non',
#   'essentials'],
#  ['constitution', 'suspended', 'coronovirus'],
#  ['watch',
#   'kat',
#   'timpf',
#   'calls',
#   'warren',
#   'campaign',
#   'protest',
#   'lack',
#   'media',
#   'coverage',
#   'laughable'],
#  ['boot', 'vs', 'barr'],
#  ['american', 'public', 'obey', 'quarantine', 'rules', 'forever'],
#  ['missed', 'opportunity', 'replicate', 'south', 'korea', 'experience'],
#  ['inside', 'april', 'issue'],
#  ['coronavirus', 'middle', 'distance'],
#  ['going', 'war'],
#  ['joe', 'wh', 'response', 'virus', 'one', 'mistake', 'another'],
#  ['officials', 'say', 'americans', 'prepare', 'coronavirus', 'spread'],
#  ['elizabeth',
#   'warren',
#   'mike',
#   'pence',
#   'leading',
#   'coronavirus',
#   'response',
#   'cannot',
#   'think',
#   'worse',
#   'person'],
#  ['trump', 'racist', 'call', 'coronavirus', 'chinese', 'virus'],
#  ['virus',
#   'scandal',
#   'senators',
#   'accused',
#   'profiting',
#   'coronavirus',
#   'info'],
#  ['u', 'healthcare', 'workers', 'confronting', 'spike', 'virus', 'cases'],
# ...
#   'think',
#   'government',
#   'slow',
#   'act',
#   'tory',
#   'mps',
#   'agree'],
#  ['schools', 'uk', 'close', 'friday', 'coronavirus', 'spreads'],
#  ['everyone', 'uk', 'full', 'coronavirus', 'lockdown'],
#  ['people',
#   'losing',
#   'ability',
#   'taste',
#   'smell',
#   'could',
#   'indicate',
#   'coronavirus',
#   'infection'],
#  ['interview',
#   'joe',
#   'rogan',
#   'infectious',
#   'disease',
#   'expert',
#   'coronavirus',
#   'trending',
#   'youtube',
#   'watched',
#   'things',
#   'said'],
#  ['idris',
#   'elba',
#   'explained',
#   'got',
#   'tested',
#   'coronavirus',
#   'despite',
#   'showing',
#   'symptoms'],
#  ['uk',
#   'government',
#   'reacted',
#   'incredulity',
#   'genuine',
#   'disbelief',
#   'trump',
#   'handling',
#   'coronavirus'],
#  ['gareth',
#   'southgate',
#   'coronavirus',
#   'message',
#   'england',
#   'fans',
#   'look',
#   'please',
#   'suffer',
#   'alone'],
#  ['men',
#   'detention',
#   'washing',
#   'hands',
#   'shampoo',
#   'conditioner',
#   'coronavirus',
#   'spreads'],
#  ['prime', 'minister', 'questions', 'looks', 'like', 'age', 'coronavirus'],
#  ['coronavirus', 'affecting', 'real', 'people', 'lives', 'around', 'world'],
#  ['guard',
#   'worked',
#   'brisbane',
#   'detention',
#   'centre',
#   'tested',
#   'positive',
#   'covid'],
#  ['schools', 'nurseries', 'confused', 'new', 'key', 'worker', 'policy'],
#  ['boris',
#   'johnson',
#   'says',
#   'everyone',
#   'uk',
#   'must',
#   'avoid',
#   'unnecessary',
#   'social',
#   'contact',
#   'people'],
#  ['australia',
#   'let',
#   'people',
#   'visit',
#   'immigration',
#   'detainees',
#   'coronavirus',
#   'fears'],
#  ['coronavirus', 'shut', 'parliament', 'staff', 'say', 'afraid', 'health'],
#  ['pickles',
#   'online',
#   'bridge',
#   'risk',
#   'people',
#   'making',
#   'coronavirus',
#   'pandemic'],
#  ['young',
#   'man',
#   'severe',
#   'mental',
#   'health',
#   'issues',
#   'told',
#   'detention',
#   'week',
#   'months'],
#  ['pessoas',
#   'estão',
#   'fazendo',
#   'vídeos',
#   'de',
#   'asmr',
#   'sobre',
#   'coronavírus',
#   'agora',
#   'porque',
#   'é',
#   'assim'],
#  ['prep', 'drug', 'prevents', 'hiv', 'finally', 'fully', 'rolled', 'england'],
#  ['need', 'know', 'coronavirus', 'hiv', 'positive'],
#  ['teachers',
#   'australia',
#   'anxious',
#   'schools',
#   'staying',
#   'open',
#   'coronavirus',
#   'outbreak'],
#  ['assemble', 'coronavirus', 'preparedness', 'kit'],
#  ['minute',
#   'asmr',
#   'video',
#   'turtle',
#   'eating',
#   'coronavirus',
#   'shaped',
#   'watermelon',
#   'youtube'],
#  ['detained',
#   'refugees',
#   'praying',
#   'man',
#   'holds',
#   'key',
#   'freedom',
#   'recovers'],
#  ['spiritual', 'bill', 'gates', 'quote', 'coronavirus', 'internet', 'fake'],
#  ['britain',
#   'way',
#   'life',
#   'change',
#   'months',
#   'senior',
#   'ministers',
#   'warned',
#   'prepare',
#   'emergency',
#   'measures',
#   'fight',
#   'coronavirus'],
#  ['boris',
#   'johnson',
#   'says',
#   'hesitate',
#   'go',
#   'necessary',
#   'considers',
#   'stricter',
#   'measures',
#   'london'],
#  ['britain', 'stepping', 'fight', 'slow', 'spread', 'coronavirus'],
#  ['viral',
#   'misinformation',
#   'coronavirus',
#   'bad',
#   'news',
#   'sometimes',
#   'positive',
#   'news',
#   'misleading'],
#  ['boris',
#   'johnson',
#   'defended',
#   'government',
#   'decision',
#   'enforce',
#   'tougher',
#   'measures',
#   'halt',
#   'spread',
#   'coronavirus'],
#  ['facebook',
#   'struggling',
#   'clamp',
#   'coronavirus',
#   'misinformation',
#   'languages',
#   'besides',
#   'english'],
#  ['medical', 'students', 'graduated', 'early', 'fast', 'tracked', 'hospitals'],
#  ['british', 'army', 'marching', 'london', 'coronavirus'],
#  ['days',
#   'changed',
#   'britain',
#   'heated',
#   'debate',
#   'scientists',
#   'forced',
#   'boris',
#   'johnson',
#   'act',
#   'coronavirus'],
#  ['aussies', 'need', 'know', 'travelling', 'coronavirus', 'outbreak'],
#  ['mother',
#   'took',
#   'son',
#   'school',
#   'protect',
#   'father',
#   'coronavirus',
#   'could',
#   'fined'],
#  ['number',
#   'italian',
#   'health',
#   'workers',
#   'infected',
#   'coronavirus',
#   'shows',
#   'urgent',
#   'need',
#   'protective',
#   'equipment'],
#  ['tweets', 'primary', 'school', 'funny', 'true'],
#  ['schools', 'nurseries', 'confused', 'new', 'key', 'worker', 'policy'],
#  ['coronavirus', 'affecting', 'real', 'people', 'lives', 'around', 'world'],
#  ['need', 'know', 'coronavirus', 'hiv', 'positive'],
#  ['tweets', 'primary', 'school', 'nostalgic', 'funny'],
#  ['asked',
#   'experts',
#   'popular',
#   'tea',
#   'instagram',
#   'women',
#   'say',
#   'helping',
#   'fall',
#   'pregnant'],
#  ['dog', 'posts', 'week', 'take', 'mind', 'news'],
#  ['black',
#   'ish',
#   'actor',
#   'refused',
#   'stay',
#   'quiet',
#   'trolls',
#   'attacked',
#   'anti',
#   'gay',
#   'comments',
#   'red',
#   'carpet',
#   'outfit'],
#  ['mother',
#   'took',
#   'son',
#   'school',
#   'protect',
#   'father',
#   'coronavirus',
#   'could',
#   'fined'],
#  ['teens', 'want', 'schools', 'closed', 'protect', 'families', 'coronavirus'],
#  ['detention',
#   'guard',
#   'diagnosed',
#   'covid',
#   'refugees',
#   'demanded',
#   'answers',
#   'immigration',
#   'heated',
#   'meeting'],
#  ['available', 'watch', 'quibi', 'launches', 'april'],
#  ['uk', 'media', 'organisations', 'getting', 'ready', 'coronavirus'],
#  ['bbc',
#   'insiders',
#   'say',
#   'coronavirus',
#   'defining',
#   'moment',
#   'broadcaster'],
#  ['people', 'panicking', 'toilet', 'paper', 'media', 'helping'],
#  ['hilary',
#   'duff',
#   'asked',
#   'disney',
#   'move',
#   'lizzie',
#   'mcguire',
#   'reboot',
#   'hulu',
#   'show',
#   'authentic'],
#  ['behind',
#   'scenes',
#   'secrets',
#   'office',
#   'make',
#   'show',
#   'even',
#   'rewatchable'],
#  ['australia',
#   'forgotten',
#   'year',
#   'old',
#   'died',
#   'nauru',
#   'whistleblower',
#   'nurse'],
#  ['release',
#   'hundreds',
#   'asylum',
#   'seekers',
#   'community',
#   'self',
#   'isolate',
#   'experts'],
#  ['police',
#   'england',
#   'run',
#   'hundreds',
#   'searches',
#   'new',
#   'facial',
#   'recognition',
#   'tool'],
#  ['nationwide',
#   'shortage',
#   'pneumonia',
#   'vaccine',
#   'putting',
#   'vulnerable',
#   'patients',
#   'risk'],
#  ['boris',
#   'johnson',
#   'summoned',
#   'major',
#   'tech',
#   'companies',
#   'downing',
#   'street',
#   'help',
#   'fight',
#   'coronavirus'],
#  ['around',
#   'disabled',
#   'kids',
#   'extremely',
#   'vulnerable',
#   'coronavirus',
#   'teachers',
#   'say',
#   'government',
#   'got',
#   'plan',
#   'protect'],
#  ['year',
#   'old',
#   'refugee',
#   'died',
#   'mysteriously',
#   'nauru',
#   'australia',
#   'says',
#   'nauru',
#   'problem'],
#  ['private',
#   'citizens',
#   'running',
#   'websites',
#   'twitter',
#   'accounts',
#   'tracking',
#   'spread',
#   'covid'],
#  ['travellers',
#   'uk',
#   'airports',
#   'say',
#   'one',
#   'telling',
#   'whether',
#   'self',
#   'isolate'],
#  ['teachers',
#   'say',
#   'schools',
#   'become',
#   'breeding',
#   'grounds',
#   'coronavirus',
#   'without',
#   'government',
#   'support'],
#  ['travellers',
#   'stranded',
#   'abroad',
#   'coronavirus',
#   'say',
#   'nobody',
#   'helping',
#   'get',
#   'home'],
#  ['number',
#   'italian',
#   'health',
#   'workers',
#   'infected',
#   'coronavirus',
#   'shows',
#   'urgent',
#   'need',
#   'protective',
#   'equipment'],
#  ['mother',
#   'immunosuppressed',
#   'four',
#   'year',
#   'old',
#   'coronavirus',
#   'outbreak',
#   'easy'],
#  ['major',
#   'wine',
#   'retailer',
#   'calling',
#   'essential',
#   'coronavirus',
#   'lockdown',
#   'everyone',
#   'happy'],
#  ['art',
#   'gallery',
#   'director',
#   'told',
#   'vietnamese',
#   'artist',
#   'presence',
#   'london',
#   'art',
#   'fair',
#   'could',
#   'create',
#   'hesitation',
#   'coronavirus'],
#  ['could',
#   'get',
#   'easier',
#   'people',
#   'say',
#   'yuck',
#   'stuff',
#   'women',
#   'workplace',
#   'attorney',
#   'general',
#   'lawyers',
#   'yes'],
#  ['include', 'coronavirus', 'preparedness', 'kit'],
#  ['doctors',
#   'meant',
#   'travel',
#   'interstate',
#   'provide',
#   'abortions',
#   'know',
#   'anymore'],
#  ['anti',
#   'vaxxer',
#   'group',
#   'warned',
#   'using',
#   'world',
#   'health',
#   'organisation',
#   'logo',
#   'press',
#   'release'],
#  ['tiktoker', 'takes', 'inside', 'wuhan', 'coronavirus', 'quarantine'],
#  ['food',
#   'industry',
#   'wants',
#   'government',
#   'second',
#   'hospitality',
#   'workers',
#   'production',
#   'lines'],
#  ['survivors', 'aids', 'crisis', 'speak', 'coronavirus', 'get'],
#  ['people',
#   'shared',
#   'worst',
#   'date',
#   'new',
#   'york',
#   'boy',
#   'oh',
#   'boy',
#   'doozy'],
#  ['new',
#   'jury',
#   'trials',
#   'cancelled',
#   'bail',
#   'applications',
#   'likely',
#   'rise',
#   'coronavirus',
#   'spreads'],
#  ['tinder',
#   'users',
#   'setting',
#   'locations',
#   'wuhan',
#   'get',
#   'coronavirus',
#   'news',
#   'pick'],
#  ['racist',
#   'hoaxes',
#   'chinese',
#   'people',
#   'stockpiling',
#   'coronavirus',
#   'pandemic',
#   'keep',
#   'going',
#   'viral'],
#  ['nhk中国語版が', '日本新型コロナウイルス', 'と報じた', '誤り', '国会議員らが指摘したが'],
#  ['残念な裁判だった', '相模原事件で死刑判決', '被害者の父親の思いとは'],
#  ['コロナだけが感染症じゃない', 'マスク盗難が相次ぐ病院', '看護師の嘆き'],
#  ['bts',
#   'smashes',
#   'youtube',
#   'records',
#   'new',
#   'music',
#   'video',
#   'week',
#   'best',
#   'k',
#   'pop',
#   'stories'],
#  ['aussie',
#   'women',
#   'spending',
#   'serious',
#   'money',
#   'sex',
#   'toys',
#   'coronavirus',
#   'outbreak',
#   'tbh'],
#  ['mayor',
#   'italy',
#   'worst',
#   'hit',
#   'city',
#   'coronavirus',
#   'bringing',
#   'daughters',
#   'home',
#   'uk'],
#  ['hospital',
#   'doctors',
#   'battling',
#   'coronavirus',
#   'think',
#   'government',
#   'slow',
#   'act',
#   'tory',
#   'mps',
#   'agree'],
#  ['people',
#   'told',
#   'easily',
#   'beat',
#   'coronavirus',
#   'data',
#   'suggests',
#   'way',
#   'mild',
#   'illness'],
#  ['coronavirus', 'impacting', 'production', 'favorite', 'tv', 'shows'],
#  ['youtube',
#   'letting',
#   'millions',
#   'people',
#   'watch',
#   'videos',
#   'promoting',
#   'misinformation',
#   'coronavirus'],
#  ['son', 'died', 'mysterious', 'causes', 'dying', 'wish', 'find', 'killed'],
#  ['schools', 'uk', 'close', 'friday', 'coronavirus', 'spreads'],
#  ['pubs',
#   'cafés',
#   'theatres',
#   'worried',
#   'insurance',
#   'boris',
#   'johnson',
#   'coronavirus',
#   'speech'],
#  ['men',
#   'rights',
#   'activist',
#   'prestigious',
#   'honour',
#   'senior',
#   'politician',
#   'asked',
#   'review'],
#  ['small',
#   'business',
#   'owners',
#   'told',
#   'diverse',
#   'skin',
#   'tone',
#   'plasters',
#   'niche',
#   'big',
#   'retailers',
#   'without'],
#  ['big', 'brother', 'australia', 'contestants', 'know', 'coronavirus'],
#  ['gumtree',
#   'big',
#   'australian',
#   'classifieds',
#   'site',
#   'letting',
#   'people',
#   'price',
#   'gouge',
#   'coronavirus',
#   'supplies'],
#  ['cabinet',
#   'ministers',
#   'senior',
#   'aides',
#   'threatening',
#   'full',
#   'scale',
#   'mutiny',
#   'boris',
#   'johnson',
#   'enforce',
#   'lockdown'],
#  ['australia',
#   'unlikely',
#   'coronavirus',
#   'celebrity',
#   'boomer',
#   'health',
#   'journalist'],
#  ['refugee', 'death', 'australia', 'forgot'],
#  ['facebook', 'sued', 'australia', 'cambridge', 'analytica', 'scandal'],
#  ['doomsday', 'facebook', 'portal', 'good'],
#  ['driving', 'city', 'bus', 'global', 'pandemic', 'extremely', 'stressful'],
#  ['tips', 'working', 'home', 'without', 'losing', 'mind'],
#  ['need', 'know', 'coronavirus', 'uk'],
#  ['need', 'know', 'coronavirus', 'transmitted', 'people', 'uk'],
#  ['iceland',
#   'entire',
#   'population',
#   'get',
#   'tested',
#   'coronavirus',
#   'could',
#   'help',
#   'us'],
#  ['tokyo',
#   'olympics',
#   'could',
#   'possibly',
#   'canceled',
#   'coronavirus',
#   'everyone',
#   'talk',
#   'dick',
#   'pound'],
#  ['australia', 'major', 'news', 'wire', 'shutting'],
#  ['times', 'tumblr', 'completely', 'roasted', 'twilight'],
#  ['hilary',
#   'duff',
#   'dragged',
#   'tabloid',
#   'said',
#   'marriage',
#   'rocks',
#   'three',
#   'months'],
#  ['european',
#   'diplomats',
#   'puzzled',
#   'donald',
#   'trump',
#   'coronavirus',
#   'travel',
#   'ban'],
#  ['thousands', 'europeans', 'left', 'britain', 'week', 'coronavirus'],
#  ['looks',
#   'like',
#   'love',
#   'blind',
#   'couple',
#   'split',
#   'got',
#   'back',
#   'together',
#   'freaking',
#   'news'],
#  ['boris',
#   'lackey',
#   'civil',
#   'service',
#   'moral',
#   'compass',
#   'mark',
#   'sedwill',
#   'finds',
#   'cabinet',
#   'secretary',
#   'wants'],
#  ['boris',
#   'johnson',
#   'government',
#   'lost',
#   'another',
#   'top',
#   'civil',
#   'servant'],
#  ['emily',
#   'alyn',
#   'lind',
#   'first',
#   'lead',
#   'actor',
#   'announced',
#   'gossip',
#   'girl',
#   'reboot'],
#  ['conspiracy',
#   'theory',
#   'bullied',
#   'year',
#   'old',
#   'quaden',
#   'bayles',
#   'explained'],
#  ['uk',
#   'government',
#   'reacted',
#   'incredulity',
#   'genuine',
#   'disbelief',
#   'trump',
#   'handling',
#   'coronavirus'],
#  ['funny', 'tweets', 'month', 'hopefully', 'give', 'break', 'chaos'],
#  ['really',
#   'brought',
#   'game',
#   'emails',
#   'behind',
#   'bizarre',
#   'horoscopes',
#   'poster',
#   'designed',
#   'scare',
#   'refugees'],
#  ['bunch',
#   'media',
#   'outlets',
#   'deleted',
#   'withdrawn',
#   'comments',
#   'men',
#   'rights',
#   'activist',
#   'attacking',
#   'journalist'],
#  ['guard',
#   'worked',
#   'brisbane',
#   'detention',
#   'centre',
#   'tested',
#   'positive',
#   'covid'],
#  ['australia',
#   'let',
#   'people',
#   'visit',
#   'immigration',
#   'detainees',
#   'coronavirus',
#   'fears'],
#  ['men',
#   'detention',
#   'washing',
#   'hands',
#   'shampoo',
#   'conditioner',
#   'coronavirus',
#   'spreads'],
#  ['happened',
#   'egg',
#   'boy',
#   'racist',
#   'politician',
#   'year',
#   'since',
#   'christchurch',
#   'attack'],
#  ['coronavirus', 'shut', 'parliament', 'staff', 'say', 'afraid', 'health'],
#  ['fake',
#   'facebook',
#   'account',
#   'pretending',
#   'chinese',
#   'woman',
#   'hoarding',
#   'toilet',
#   'paper',
#   'shared',
#   'right',
#   'wing',
#   'pages'],
#  ['tube',
#   'still',
#   'packed',
#   'despite',
#   'coronavirus',
#   'lockdown',
#   'london',
#   'mayor',
#   'government',
#   'give',
#   'different',
#   'advice',
#   'construction',
#   'workers'],
#  ['italian',
#   'tourists',
#   'fear',
#   'stranded',
#   'uk',
#   'country',
#   'coronavirus',
#   'lockdown'],
#  ['young',
#   'man',
#   'severe',
#   'mental',
#   'health',
#   'issues',
#   'told',
#   'detention',
#   'week',
#   'months'],
#  ['schools', 'nurseries', 'confused', 'new', 'key', 'worker', 'policy'],
#  ['probably',
#   'saw',
#   'hoax',
#   'australia',
#   'enforcing',
#   'mandatory',
#   'lockdown',
#   'story',
#   'behind'],
#  ['rebecca',
#   'long',
#   'bailey',
#   'worked',
#   'legal',
#   'team',
#   'advised',
#   'pfi',
#   'deal',
#   'hospital',
#   'costing',
#   'liverpool',
#   'millions'],
#  ['hilarious', 'coronavirus', 'voice', 'notes', 'going', 'viral', 'whatsapp'],
#  ['immunosuppressed',
#   'scientist',
#   'using',
#   'self',
#   'isolation',
#   'time',
#   'map',
#   'coronavirus'],
#  ['pickles',
#   'online',
#   'bridge',
#   'risk',
#   'people',
#   'making',
#   'coronavirus',
#   'pandemic'],
#  ['coronavirus', 'affecting', 'real', 'people', 'lives', 'around', 'world'],
#  ['você',
#   'consegue',
#   'acertar',
#   'se',
#   'essas',
#   'notícias',
#   'sobre',
#   'coronavírus',
#   'são',
#   'verdadeiras',
#   'ou',
#   'fake',
#   'news'],
#  ['boulos',
#   'lança',
#   'candidatura',
#   'prefeito',
#   'de',
#   'sp',
#   'mas',
#   'terá',
#   'de',
#   'enfrentar',
#   'prévias',
#   'psol'],
#  ['bolsonaro',
#   'diz',
#   'que',
#   'exames',
#   'deram',
#   'negativo',
#   'para',
#   'coronavírus'],
#  ['ela',
#   'foi',
#   'uma',
#   'festa',
#   'sem',
#   'esperar',
#   'resultado',
#   'exame',
#   'namorado',
#   'deu',
#   'positivo',
#   'e',
#   'boate',
#   'fechou'],
#  ['mulher',
#   'xinga',
#   'negra',
#   'de',
#   'macaca',
#   'sem',
#   'educação',
#   'em',
#   'shopping',
#   'rio',
#   'e',
#   'é',
#   'presa',
#   'em',
#   'flagrante'],
#  ['doj',
#   'let',
#   'immigration',
#   'judges',
#   'hang',
#   'posters',
#   'coronavirus',
#   'reason'],
#  ['regret', 'inform', 'coronavirus', 'songs', 'slap'],
#  ['coronavirus', 'starting', 'hit', 'u', 'military'],
#  ['hotels',
#   'convention',
#   'centers',
#   'emptied',
#   'coronavirus',
#   'sheltering',
#   'homeless'],
#  ['coronavirus', 'threat', 'got', 'real', 'europe'],
#  ['coronavirus', 'merch', 'buying'],
#  ['iran', 'says', 'dead', 'coronavirus', 'see', 'mass', 'graves', 'space'],
#  ['personally', 'coronavirus'],
#  ['soul', 'patch', 'putting', 'risk', 'coronavirus', 'outbreak'],
#  ['canadian', 'researchers', 'isolated', 'novel', 'coronavirus'],
#  ['surprise', 'people', 'making', 'terrible', 'tiktoks', 'coronavirus'],
#  ['believe', 'wild', 'coronavirus', 'conspiracy', 'theories'],
#  ['iranian', 'officials', 'keep', 'dying', 'coronavirus'],
#  ['talk', 'doctor', 'center', 'south', 'korea', 'coronavirus', 'explosion'],
#  ['worried', 'college', 'students', 'asking', 'schools', 'cancel', 'class'],
#  ['coronavirus', 'spreads', 'artists', 'coping', 'waifus', 'fursona', 'art'],
#  ...]

# %%
MarchNews.insert(8,'TitleCleaned', Title)
MarchNews.insert(9,'DescriptionCleaned', Description)
MarchNews.insert(10,'ContentCleaned', Content)
print(MarchNews)
# Out:
#                                       source                 author  \
# 0     {'id': 'fox-news', 'name': 'Fox News'}                    NaN
# 1     {'id': 'fox-news', 'name': 'Fox News'}                    NaN
# 2     {'id': 'fox-news', 'name': 'Fox News'}        William Sanchez
# 3     {'id': 'fox-news', 'name': 'Fox News'}    Wyatt DobrovichFago
# 4     {'id': 'fox-news', 'name': 'Fox News'}        William Sanchez
# ...                                      ...                    ...
# 1779  {'id': 'cbs-news', 'name': 'CBS News'}               CBS News
# 1780  {'id': 'cbs-news', 'name': 'CBS News'}  Camilo Montoya-Galvez
# 1781  {'id': 'cbs-news', 'name': 'CBS News'}               CBS News
# 1782  {'id': 'cbs-news', 'name': 'CBS News'}         Stephen Gandel
# 1783  {'id': 'cbs-news', 'name': 'CBS News'}               CBS News
#
#                                                   title  \
# 0     South Carolina primary is do-or-die for Biden ...
# 1     Sanders supporters react to DNC reportedly att...
# 2     Contentious Race Democratic Race Heads to Sout...
# 3     Federalist Editor Mollie Hemingway On Biden’s ...
# 4             Will Biden Get a Bounce on Super Tuesday?
# ...                                                 ...
# 1779  With U.S. in lockdown, hope and calm beat nerv...
# 1780  First immigrant in ICE custody tests positive ...
# 1781  Doctor answers your most pressing coronavirus ...
# 1782  South by Southwest festival canceled due to co...
# 1783  Coronavirus updates: Fear batters the economy ...
#
#                                             description  \
# 0     Reaction from former White House Chief of Staf...
# 1     Fox News contributor Lawrence Jones speaks to ...
# 2     We are days away from the South Carolina prima...
# 3     Former Vice President Joe Biden called his vic...
# 4     Howie Kurtz on Joe Biden winning the South Car...
# ...                                                 ...
# 1779  Some report stress but most stay optimistic as...
# 1780  Former ICE acting director John Sandweg told C...
# 1781  CBS News medical contributor Dr. Tara Narula j...
# 1782  Announcement comes after Apple, Facebook and o...
# 1783  Oil and stock prices have plummeted as Europe ...
#
#                                                     url  \
# 0             http://video.foxnews.com/v/6137137518001/
# 1             http://video.foxnews.com/v/6136724620001/
# 2     https://radio.foxnews.com/2020/02/27/the-fox-n...
# 3     https://radio.foxnews.com/2020/03/02/federalis...
# 4     https://radio.foxnews.com/2020/03/02/will-bide...
# ...                                                 ...
# 1779  https://www.cbsnews.com/news/with-americans-in...
# 1780  https://www.cbsnews.com/news/coronavirus-ice-f...
# 1781  https://www.cbsnews.com/news/coronavirus-press...
# 1782  https://www.cbsnews.com/news/coronavirus-south...
# 1783  https://www.cbsnews.com/live-updates/coronavir...
#
#                                              urlToImage           publishedAt  \
# 0     https://cf-images.us-east-1.prod.boltdns.net/v...  2020-02-29T02:49:49Z
# 1     https://cf-images.us-east-1.prod.boltdns.net/v...  2020-02-28T03:43:40Z
# 2     https://radio.foxnews.com/wp-content/uploads/2...  2020-02-27T10:00:02Z
# 3     https://radio.foxnews.com/wp-content/uploads/2...  2020-03-02T23:32:11Z
# 4     https://radio.foxnews.com/wp-content/uploads/2...  2020-03-02T17:55:01Z
# ...                                                 ...                   ...
# 1779  https://cbsnews3.cbsistatic.com/hub/i/r/2020/0...  2020-03-24T11:00:26Z
# 1780  https://cbsnews1.cbsistatic.com/hub/i/r/2020/0...  2020-03-24T20:19:32Z
# 1781  https://cbsnews2.cbsistatic.com/hub/i/r/2020/0...  2020-03-21T00:58:30Z
# 1782  https://cbsnews1.cbsistatic.com/hub/i/r/2020/0...  2020-03-06T22:31:53Z
# 1783  https://cbsnews3.cbsistatic.com/hub/i/r/2020/0...  2020-03-09T20:47:05Z
#
#                                                 content  \
# 0                                                  None
# 1                                                  None
# 2     We are days away from the South Carolina prima...
# 3     Former Vice President Joe Biden called his vic...
# 4                                                  None
# ...                                                 ...
# 1779  Amid the coronavirus outbreak, the personal ha...
# 1780  Immigration and Customs Enforcement (ICE) on T...
# 1781  The number of reported coronavirus cases in th...
# 1782  pulled out of the eventThe upcoming South by S...
# 1783  As China appeared to be getting over the initi...
#
#                                            TitleCleaned  \
# 0      [south, carolina, primary, die, biden, campaign]
# 1     [sanders, supporters, react, dnc, reportedly, ...
# 2     [contentious, race, democratic, race, heads, s...
# 3     [federalist, editor, mollie, hemingway, biden,...
# 4                  [biden, get, bounce, super, tuesday]
# ...                                                 ...
# 1779  [u, lockdown, hope, calm, beat, nervousness, c...
# 1780  [first, immigrant, ice, custody, tests, positi...
# 1781  [doctor, answers, pressing, coronavirus, quest...
# 1782  [south, southwest, festival, canceled, due, co...
# 1783  [coronavirus, updates, fear, batters, economy,...
#
#                                      DescriptionCleaned  \
# 0     [reaction, former, white, house, chief, staff,...
# 1     [fox, news, contributor, lawrence, jones, spea...
# 2     [days, away, south, carolina, primary, last, p...
# 3     [former, vice, president, joe, biden, called, ...
# 4     [howie, kurtz, joe, biden, winning, south, car...
# ...                                                 ...
# 1779  [report, stress, stay, optimistic, life, changes]
# 1780  [former, ice, acting, director, john, sandweg,...
# 1781  [cbs, news, medical, contributor, dr, tara, na...
# 1782  [announcement, comes, apple, facebook, big, co...
# 1783  [oil, stock, prices, plummeted, europe, u, beg...
#
#                                          ContentCleaned
# 0                                                    []
# 1                                                    []
# 2     [days, away, south, carolina, primary, last, p...
# 3     [former, vice, president, joe, biden, called, ...
# 4                                                    []
# ...                                                 ...
# 1779  [amid, coronavirus, outbreak, personal, become...
# 1780  [immigration, customs, enforcement, ice, tuesd...
# 1781  [number, reported, coronavirus, cases, u, cont...
# 1782  [pulled, eventthe, upcoming, south, southwest,...
# 1783  [china, appeared, getting, initial, onslaught,...
#
# [1784 rows x 11 columns]

# %% [markdown]
# # Generate Word Count Matrices

# %%
# get unique words for each column
uniqueWords = []

for i in range(len(MarchNews['ContentCleaned'])):
    # create empty lsit each iteration
    lst = []
    # get all word in title, content, and description
    [lst.append(words) for words in MarchNews['TitleCleaned'][i]]
    [lst.append(words) for words in MarchNews['ContentCleaned'][i]]
    [lst.append(words) for words in MarchNews['DescriptionCleaned'][i]]
    #transform list into set of unique words
    unique = set(lst)
    #assign unique word set to each row or whole df
    uniqueWords.append(unique)
# Out:
# [{'biden',
#   'bruce',
#   'campaign',
#   'carolina',
#   'chief',
#   'contributor',
#   'die',
#   'former',
#   'fox',
#   'house',
#   'news',
#   'priebus',
#   'primary',
#   'reaction',
#   'reince',
#   'south',
#   'staff',
#   'tammy',
#   'white'},
#  {'attempting',
#   'contributor',
#   'dnc',
#   'fox',
#   'give',
#   'jones',
#   'lawrence',
#   'leadership',
#   'news',
#   'nomination',
#   'primary',
#   'react',
#   'reportedly',
#   'result',
#   'sanders',
#   'speaks',
#   'subvert',
#   'supporters',
#   'voters',
#   'wanting'},
#  {'anchor',
#   'away',
#   'baier',
#   'biden',
#   'break',
#   'bret',
#   'candidates',
#   'carolina',
#   'chief',
#   'colin',
#   'commentary',
#   'contentious',
#   'days',
#   'democratic',
#   'discusses',
#   'former',
#   'fox',
#   'heads',
#   'joe',
#   'last',
#   'like',
#   'look',
#   'make',
#   'news',
#   'plus',
#   'political',
#   'president',
#   'primary',
#   'race',
#   'reed',
#   'south',
#   'super',
#   'tuesday',
#   'vice'},
#  {'appeared',
#   'away',
#   'biden',
#   'blew',
#   'called',
#   'carolina',
#   'carry',
#   'comeback',
#   'confident',
#   'democratic',
#   'editor',
#   'expectations',
#   'federalist',
#   'former',
#   'fox',
#   'hemingway',
#   'joe',
#   'looks',
#   'mollie',
#   'momentum',
#   'news',
#   'night',
#   'people',
#   'president',
#   'primaries',
#   'primary',
#   'real',
#   'saturday',
#   'sc',
#   'seemed',
#   'south',
#   'sunday',
#   'super',
#   'tuesday',
#   'upcoming',
#   'vice',
#   'victory',
#   'win'},
#  {'bid',
#   'biden',
#   'bounce',
#   'buttigieg',
#   'carolina',
#   'click',
#   'deal',
#   'ending',
#   'follow',
#   'get',
#   'howardkurtz',
#   'howie',
#   'joe',
#   'kurtz',
#   'mediabuzz',
#   'pete',
#   'presidency',
#   'primary',
#   'reaching',
#   'south',
#   'super',
#   'taliban',
#   'tuesday',
#   'twitter',
#   'u',
#   'winning'},
#  {'analyst',
#   'benson',
#   'bernie',
#   'biden',
#   'carolina',
#   'contests',
#   'dem',
#   'democratic',
#   'editor',
#   'fox',
#   'gave',
#   'guy',
#   'josh',
#   'journal',
#   'kraushaar',
#   'national',
#   'news',
#   'nominee',
#   'political',
#   'politics',
#   'predictions',
#   'prim',
#   'primary',
#   'race',
#   'radio',
#   'sanders',
#   'saying',
#   'south',
#   'talked',
#   'upcoming',
#   'win'},
#  {'bashing',
#   'bernie',
#   'biden',
#   'big',
#   'blowout',
#   'concerns',
#   'coronavirus',
#   'crisis',
#   'day',
#   'extra',
#   'fights',
#   'follow',
#   'health',
#   'holding',
#   'howardkurtz',
#   'howie',
#   'joe',
#   'journalists',
#   'kurtz',
#   'latest',
#   'lead',
#   'management',
#   'media',
#   'michigan',
#   'polls',
#   'president',
#   'primary',
#   'show',
#   'survival',
#   'trump',
#   'twitter'},
#  {'action',
#   'bailouts',
#   'believe',
#   'big',
#   'brian',
#   'companies',
#   'concerns',
#   'coronavirus',
#   'drastic',
#   'favor',
#   'fl',
#   'florida',
#   'kilmeade',
#   'listen',
#   'need',
#   'period',
#   'primary',
#   'r',
#   'rick',
#   'safety',
#   'scott',
#   'sen',
#   'spoke',
#   'spread',
#   'stop',
#   'today',
#   'voters'},
#  {'battle',
#   'benson',
#   'bernie',
#   'biden',
#   'cafaro',
#   'capri',
#   'consistently',
#   'delegates',
#   'democratic',
#   'former',
#   'fox',
#   'guy',
#   'head',
#   'joe',
#   'leader',
#   'minority',
#   'news',
#   'nomination',
#   'numbers',
#   'ohio',
#   'performance',
#   'polls',
#   'primary',
#   'race',
#   'radio',
#   'sander',
#   'sanders',
#   'senate',
#   'six',
#   'states',
#   'super',
#   'talked',
#   'tuesday',
#   'underperformed',
#   'voters'},
#  {'abby',
#   'become',
#   'bernie',
#   'biden',
#   'biggest',
#   'boost',
#   'calendar',
#   'comeback',
#   'commentary',
#   'day',
#   'delegates',
#   'demo',
#   'democratic',
#   'establishment',
#   'former',
#   'get',
#   'high',
#   'hornacek',
#   'hours',
#   'joe',
#   'kid',
#   'make',
#   'many',
#   'nominee',
#   'plus',
#   'possible',
#   'president',
#   'preview',
#   'primary',
#   'sanders',
#   'senator',
#   'stakes',
#   'super',
#   'today',
#   'tuesday',
#   'vice',
#   'vt'},
#  {'america',
#   'among',
#   'bern',
#   'bernie',
#   'caucus',
#   'caucuses',
#   'concept',
#   'contributor',
#   'delegates',
#   'democ',
#   'different',
#   'ease',
#   'favorite',
#   'feeling',
#   'fox',
#   'fundamentally',
#   'hampshire',
#   'iowa',
#   'kim',
#   'nevada',
#   'new',
#   'news',
#   'primary',
#   'sanders',
#   'saturday',
#   'sen',
#   'socialism',
#   'strassel',
#   'takes',
#   'though',
#   'votes'},
#  {'alabama',
#   'batura',
#   'carolina',
#   'commentary',
#   'congress',
#   'control',
#   'could',
#   'crucial',
#   'democratic',
#   'fight',
#   'fox',
#   'j',
#   'look',
#   'new',
#   'nomination',
#   'north',
#   'paul',
#   'plus',
#   'presidential',
#   'primary',
#   'race',
#   'races',
#   'republicans',
#   'senate',
#   'stay',
#   'super',
#   'texas',
#   'thing',
#   'three',
#   'tuesday'},
#  {'bernie',
#   'broadest',
#   'candidate',
#   'candidates',
#   'carolina',
#   'caucus',
#   'democrat',
#   'democrats',
#   'director',
#   'landslide',
#   'moderate',
#   'momentum',
#   'nevada',
#   'next',
#   'panic',
#   'primary',
#   'prove',
#   'ride',
#   'sanders',
#   'set',
#   'sights',
#   'south',
#   'speeds',
#   'support',
#   'win'},
#  {'amid',
#   'average',
#   'business',
#   'commentary',
#   'coronavirus',
#   'correspondent',
#   'dow',
#   'dr',
#   'fears',
#   'fox',
#   'industrial',
#   'investors',
#   'joins',
#   'jones',
#   'kristina',
#   'madness',
#   'marc',
#   'march',
#   'monday',
#   'new',
#   'oil',
#   'partsinevelos',
#   'plummet',
#   'plunge',
#   'plus',
#   'points',
#   'price',
#   'rundown',
#   'sank',
#   'scrambling',
#   'sent',
#   'siegel',
#   'spread',
#   'stock',
#   'stocks',
#   'war',
#   'york'},
#  {'across',
#   'america',
#   'behind',
#   'biggest',
#   'brady',
#   'breaks',
#   'challenges',
#   'choose',
#   'contributor',
#   'democratic',
#   'democrats',
#   'divided',
#   'earlier',
#   'eight',
#   'extra',
#   'fox',
#   'host',
#   'karl',
#   'less',
#   'lisa',
#   'months',
#   'news',
#   'nominee',
#   'party',
#   'president',
#   'race',
#   'republican',
#   'rove',
#   'rundown',
#   'running',
#   'spoke',
#   'state',
#   'strategist',
#   'time',
#   'unite',
#   'voters',
#   'week'},
#  {'bernie',
#   'bets',
#   'briefing',
#   'channel',
#   'chris',
#   'co',
#   'daily',
#   'dana',
#   'democratic',
#   'editor',
#   'fat',
#   'field',
#   'five',
#   'following',
#   'former',
#   'fox',
#   'goings',
#   'host',
#   'house',
#   'make',
#   'march',
#   'news',
#   'perino',
#   'politics',
#   'press',
#   'primaries',
#   'run',
#   'sanders',
#   'secretary',
#   'shave',
#   'skinny',
#   'stands',
#   'stirewalt',
#   'time',
#   'tuesday',
#   'week',
#   'weigh',
#   'white'},
#  {'benson',
#   'capitol',
#   'citiz',
#   'congresswoman',
#   'coronavirus',
#   'discussed',
#   'district',
#   'done',
#   'economy',
#   'elise',
#   'ensure',
#   'explanation',
#   'federal',
#   'fox',
#   'guy',
#   'health',
#   'hill',
#   'lack',
#   'new',
#   'news',
#   'ny',
#   'pace',
#   'radio',
#   'rep',
#   'response',
#   'slow',
#   'stefanik',
#   'talks',
#   'testing',
#   'u',
#   'work',
#   'york'},
#  {'benson',
#   'bills',
#   'blocking',
#   'carolina',
#   'caucus',
#   'debate',
#   'democratic',
#   'democrats',
#   'dems',
#   'discuss',
#   'ernst',
#   'fia',
#   'filibuster',
#   'fox',
#   'go',
#   'guy',
#   'heartbroken',
#   'ia',
#   'including',
#   'infanticide',
#   'issue',
#   'joni',
#   'life',
#   'needs',
#   'news',
#   'pro',
#   'r',
#   'radio',
#   'sat',
#   'senate',
#   'senator',
#   'south',
#   'thoughts',
#   'topics',
#   'two',
#   'variety',
#   'whether'},
#  {'ahead',
#   'analysis',
#   'candidates',
#   'carolina',
#   'democrats',
#   'final',
#   'last',
#   'make',
#   'minute',
#   'panel',
#   'pitches',
#   'primary',
#   'rally',
#   'reaction',
#   'report',
#   'south',
#   'special',
#   'star',
#   'supporters'},
#  {'ahead',
#   'carolina',
#   'democrats',
#   'doocy',
#   'momentum',
#   'nevada',
#   'next',
#   'peter',
#   'primary',
#   'report',
#   'sanders',
#   'south',
#   'taking',
#   'trail'},
#  {'change',
#   'correspondent',
#   'democratic',
#   'democrats',
#   'doocy',
#   'fox',
#   'half',
#   'important',
#   'leads',
#   'news',
#   'nominee',
#   'peter',
#   'political',
#   'poll',
#   'primary',
#   'reports',
#   'sanders',
#   'say',
#   'system',
#   'voters',
#   'want'},
#  {'ahead',
#   'battle',
#   'bernie',
#   'biden',
#   'class',
#   'correspondent',
#   'democratic',
#   'emanuel',
#   'former',
#   'fox',
#   'joe',
#   'michigan',
#   'mike',
#   'news',
#   'nomination',
#   'political',
#   'president',
#   'presidential',
#   'primary',
#   'reports',
#   'sanders',
#   'sen',
#   'senior',
#   'vice',
#   'voters',
#   'working'},
#  {'c',
#   'carolina',
#   'choose',
#   'columbia',
#   'first',
#   'hampshire',
#   'holds',
#   'house',
#   'independents',
#   'look',
#   'new',
#   'open',
#   'party',
#   'past',
#   'presidential',
#   'primary',
#   'race',
#   'south',
#   'southern',
#   'th',
#   'traditionally',
#   'unlike',
#   'vote',
#   'want',
#   'white',
#   'winners'},
#  {'african',
#   'american',
#   'among',
#   'bernie',
#   'biden',
#   'black',
#   'came',
#   'carolina',
#   'democratic',
#   'distant',
#   'downplayed',
#   'downplays',
#   'following',
#   'former',
#   'front',
#   'frontrunner',
#   'joe',
#   'loss',
#   'poor',
#   'president',
#   'presidential',
#   'primary',
#   'runner',
#   'said',
#   'sanders',
#   'saturday',
#   'second',
#   'shortcomings',
#   'showing',
#   'south',
#   'vice',
#   'voters',
#   'w'},
#  {'amid',
#   'announced',
#   'april',
#   'ballot',
#   'concerns',
#   'coronavirus',
#   'due',
#   'election',
#   'friday',
#   'includes',
#   'local',
#   'louisiana',
#   'mayoral',
#   'moving',
#   'officials',
#   'outbreak',
#   'pandemic',
#   'postpone',
#   'postpones',
#   'presidential',
#   'primary',
#   'propositions',
#   'races',
#   'state',
#   'well'},
#  {'biden',
#   'caroli',
#   'carolina',
#   'carry',
#   'democratic',
#   'five',
#   'former',
#   'friday',
#   'geraldo',
#   'impact',
#   'joe',
#   'keep',
#   'momentum',
#   'panelist',
#   'people',
#   'predicted',
#   'president',
#   'presidential',
#   'primary',
#   'race',
#   'rivera',
#   'saturday',
#   'south',
#   'super',
#   'think',
#   'tuesday',
#   'underestimating',
#   'vice',
#   'victory',
#   'win'},
#  {'ahead',
#   'banking',
#   'biden',
#   'black',
#   'boost',
#   'c',
#   'carolina',
#   'charleston',
#   'clyburn',
#   'democratic',
#   'endorsed',
#   'endorses',
#   'former',
#   'giving',
#   'house',
#   'james',
#   'joe',
#   'majority',
#   'nomination',
#   'president',
#   'primar',
#   'primary',
#   'propel',
#   'south',
#   'strong',
#   'support',
#   'vice',
#   'victory',
#   'voters',
#   'wednesday',
#   'whip'},
#  {'activist',
#   'bid',
#   'biden',
#   'billionaire',
#   'came',
#   'campaign',
#   'carolina',
#   'democratic',
#   'ending',
#   'ends',
#   'environmental',
#   'former',
#   'fox',
#   'joe',
#   'move',
#   'news',
#   'patrick',
#   'president',
#   'presidential',
#   'primary',
#   'saturday',
#   'shortly',
#   'south',
#   'steyer',
#   'told',
#   'tom',
#   'vice',
#   'ward',
#   'wins'},
#  {'also',
#   'battle',
#   'battleground',
#   'bernie',
#   'biden',
#   'contests',
#   'crucial',
#   'democratic',
#   'election',
#   'former',
#   'general',
#   'joe',
#   'michigan',
#   'midwestern',
#   'nomination',
#   'past',
#   'play',
#   'president',
#   'presidential',
#   'primary',
#   'race',
#   'role',
#   'sanders',
#   'sen',
#   'state',
#   'vermont',
#   'vice',
#   'winners'},
#  {'absurd',
#   'back',
#   'biggest',
#   'california',
#   'carlson',
#   'carolina',
#   'cbs',
#   'chaos',
#   'debate',
#   'democratic',
#   'descended',
#   'diminished',
#   'everyone',
#   'field',
#   'final',
#   'forum',
#   'ho',
#   'ideas',
#   'includes',
#   'last',
#   'likely',
#   'look',
#   'matter',
#   'next',
#   'night',
#   'one',
#   'ones',
#   'primary',
#   'season',
#   'south',
#   'states',
#   'texas',
#   'total',
#   'tucker',
#   'tuesday'},
#  {'activists',
#   'attack',
#   'c',
#   'carolina',
#   'chair',
#   'chairman',
#   'columbia',
#   'conservative',
#   'democracy',
#   'democratic',
#   'dems',
#   'digest',
#   'effort',
#   'factor',
#   'fellow',
#   'gop',
#   'open',
#   'party',
#   'potential',
#   'preside',
#   'primary',
#   'republicans',
#   'right',
#   'robertson',
#   'saturday',
#   'says',
#   'south',
#   'state',
#   'system',
#   'talking',
#   'trav',
#   'urge',
#   'vote',
#   'voters'},
#  {'answe',
#   'answer',
#   'answers',
#   'blog',
#   'care',
#   'coronavirus',
#   'covid',
#   'dr',
#   'editors',
#   'favini',
#   'forward',
#   'fox',
#   'lead',
#   'live',
#   'medical',
#   'nate',
#   'news',
#   'novel',
#   'physician',
#   'practice',
#   'primary',
#   'question',
#   'questions',
#   'selected',
#   'session',
#   'submitted',
#   'welcome'},
#  {'accused',
#   'b',
#   'bad',
#   'behavior',
#   'bernie',
#   'bullhorn',
#   'called',
#   'chairman',
#   'dem',
#   'democratic',
#   'evening',
#   'friday',
#   'front',
#   'frontrunner',
#   'gathered',
#   'group',
#   'home',
#   'last',
#   'late',
#   'nevada',
#   'night',
#   'officials',
#   'outside',
#   'party',
#   'presidential',
#   'primary',
#   'protests',
#   'runner',
#   'sanders',
#   'supporters',
#   'time'},
#  {'ahead',
#   'begin',
#   'bid',
#   'biden',
#   'carolina',
#   'congress',
#   'coronavirus',
#   'day',
#   'every',
#   'first',
#   'fox',
#   'halftime',
#   'inbox',
#   'knocks',
#   'looking',
#   'national',
#   'news',
#   'package',
#   'place',
#   'poll',
#   'primary',
#   'qua',
#   'report',
#   'republicans',
#   'resurrect',
#   'roster',
#   'sanders',
#   'sign',
#   'south',
#   'time',
#   'want',
#   'zeroing'},
#  {'according',
#   'back',
#   'blac',
#   'chyna',
#   'custody',
#   'daughter',
#   'denied',
#   'dream',
#   'emergency',
#   'ex',
#   'filed',
#   'january',
#   'judge',
#   'kardashian',
#   'motion',
#   'old',
#   'parte',
#   'primary',
#   'reports',
#   'request',
#   'rob',
#   'seeking',
#   'three',
#   'year'},
#  {'across',
#   'biden',
#   'boosted',
#   'c',
#   'campaign',
#   'carolina',
#   'columbia',
#   'country',
#   'euphoric',
#   'flagging',
#   'former',
#   'hold',
#   'joe',
#   'landslide',
#   'next',
#   'pointing',
#   'president',
#   'presidential',
#   'primaries',
#   'primary',
#   'revolution',
#   'sanders',
#   'saturday',
#   'south',
#   'states',
#   'swipes',
#   'thanked',
#   'touts',
#   'vice',
#   'victory',
#   'week'},
#  {'also',
#   'another',
#   'bernie',
#   'biden',
#   'deliver',
#   'democratic',
#   'dimmer',
#   'endured',
#   'forward',
#   'front',
#   'grows',
#   'joe',
#   'looks',
#   'losses',
#   'maj',
#   'mentum',
#   'night',
#   'nomination',
#   'one',
#   'path',
#   'presidential',
#   'primary',
#   'rival',
#   'round',
#   'runner',
#   'sanders',
#   'sen',
#   'statement',
#   'time',
#   'trouncing',
#   'tuesday'},
#  {'alabama',
#   'arkansas',
#   'biden',
#   'called',
#   'carolina',
#   'contests',
#   'democratic',
#   'former',
#   'giving',
#   'joe',
#   'last',
#   'maine',
#   'massac',
#   'minnesota',
#   'north',
#   'oklahoma',
#   'president',
#   'presidential',
#   'primaries',
#   'primary',
#   'state',
#   'super',
#   'swept',
#   'texas',
#   'tuesday',
#   'vice',
#   'victories',
#   'winning',
#   'wins'},
#  {'afternoon',
#   'americans',
#   'amid',
#   'chicago',
#   'comparison',
#   'coronavirus',
#   'dampens',
#   'democracy',
#   'digest',
#   'early',
#   'forced',
#   'holding',
#   'homes',
#   'illinois',
#   'isolate',
#   'low',
#   'noticeably',
#   'one',
#   'pandemic',
#   'parts',
#   'presidential',
#   'primaries',
#   'primary',
#   'scare',
#   'self',
#   'states',
#   'three',
#   'tuesday',
#   'turnout'},
#  {'according',
#   'associated',
#   'count',
#   'delegate',
#   'delegates',
#   'florida',
#   'gop',
#   'illinois',
#   'needed',
#   'nomina',
#   'nomination',
#   'officially',
#   'president',
#   'presidential',
#   'press',
#   'primaries',
#   'primary',
#   'republican',
#   'secure',
#   'secured',
#   'secures',
#   'surpassed',
#   'trump',
#   'tuesday',
#   'victories'},
#  {'abortion',
#   'alexandria',
#   'anti',
#   'aoc',
#   'beats',
#   'business',
#   'challenged',
#   'challenger',
#   'cortez',
#   'daniel',
#   'democrat',
#   'edge',
#   'endorsed',
#   'far',
#   'house',
#   'ill',
#   'incumbent',
#   'left',
#   'lipinski',
#   'lost',
#   'marie',
#   'n',
#   'newman',
#   'ocasio',
#   'owner',
#   'party',
#   'pick',
#   'primary',
#   'race',
#   'rare',
#   'rep',
#   'seat',
#   'small'},
#  {'allows',
#   'along',
#   'arizona',
#   'battleground',
#   'contests',
#   'crucial',
#   'delegates',
#   'democratic',
#   'election',
#   'elections',
#   'florida',
#   'general',
#   'holds',
#   'illinois',
#   'look',
#   'meaning',
#   'midwestern',
#   'ohio',
#   'open',
#   'past',
#   'pledged',
#   'presidential',
#   'primaries',
#   'primary',
#   'recent',
#   'stake',
#   'state',
#   'tuesday',
#   'voter',
#   'winners'},
#  {'alabama',
#   'attorney',
#   'auburn',
#   'coach',
#   'endorsed',
#   'endorses',
#   'football',
#   'former',
#   'general',
#   'gop',
#   'great',
#   'jeff',
#   'opponent',
#   'president',
#   'primary',
#   'race',
#   'running',
#   'runoff',
#   'senate',
#   'sessions',
#   'snub',
#   'snubs',
#   'tommy',
#   'trump',
#   'tuberville',
#   'u',
#   'university'},
#  {'amid',
#   'announced',
#   'april',
#   'confere',
#   'coronavirus',
#   'election',
#   'fears',
#   'gov',
#   'governor',
#   'hogan',
#   'june',
#   'larry',
#   'making',
#   'maryland',
#   'move',
#   'postpone',
#   'postponing',
#   'press',
#   'primaries',
#   'primary',
#   'put',
#   'says',
#   'sixth',
#   'state',
#   'territory',
#   'tuesday'},
#  {'biden',
#   'counting',
#   'days',
#   'declared',
#   'democratic',
#   'five',
#   'former',
#   'giving',
#   'held',
#   'joe',
#   'march',
#   'monday',
#   'nearly',
#   'onto',
#   'president',
#   'presidential',
#   'primary',
#   'six',
#   'smal',
#   'state',
#   'states',
#   'vice',
#   'victories',
#   'vote',
#   'voted',
#   'votes',
#   'washington',
#   'week',
#   'winner'},
#  {'bid',
#   'bill',
#   'came',
#   'challenge',
#   'challenger',
#   'clinched',
#   'day',
#   'drop',
#   'ended',
#   'formally',
#   'former',
#   'gop',
#   'gov',
#   'house',
#   'long',
#   'massachusetts',
#   'move',
#   'nomination',
#   'president',
#   'primary',
#   'race',
#   'remaining',
#   'shot',
#   'sole',
#   'suspends',
#   'trump',
#   'wednesday',
#   'weld',
#   'white'},
#  {'bernie',
#   'bid',
#   'biden',
#   'claiming',
#   'democratic',
#   'dropping',
#   'drubbing',
#   'former',
#   'given',
#   'joe',
#   'losing',
#   'predicted',
#   'president',
#   'primaries',
#   'primary',
#   'race',
#   'sanders',
#   'sen',
#   'socialist',
#   'soon',
#   'taunts',
#   'three',
#   'trump',
#   'tuesday',
#   'vice',
#   'vt'},
#  {'announced',
#   'backing',
#   'biden',
#   'big',
#   'crucial',
#   'days',
#   'democratic',
#   'endorsement',
#   'endorsing',
#   'five',
#   'former',
#   'gov',
#   'governor',
#   'gretchen',
#   'holds',
#   'joe',
#   'landed',
#   'lands',
#   'michigan',
#   'nomination',
#   'p',
#   'presidential',
#   'primary',
#   'race',
#   'state',
#   'thursday',
#   'vice',
#   'whitmer'},
#  {'adding',
#   'back',
#   'biden',
#   'boo',
#   'booker',
#   'campaign',
#   'candidate',
#   'cory',
#   'democratic',
#   'endorsed',
#   'endorses',
#   'former',
#   'j',
#   'joe',
#   'list',
#   'monday',
#   'morning',
#   'n',
#   'nomination',
#   'opponents',
#   'party',
#   'president',
#   'presidential',
#   'primary',
#   'quest',
#   'rival',
#   'sen',
#   'vice'},
#  {'biggest',
#   'cache',
#   'calendar',
#   'califor',
#   'contests',
#   'delegate',
#   'delegates',
#   'democratic',
#   'entire',
#   'florida',
#   'four',
#   'fourth',
#   'grabs',
#   'holding',
#   'largest',
#   'look',
#   'nominating',
#   'past',
#   'pledged',
#   'presidential',
#   'primaries',
#   'primary',
#   'prize',
#   'recent',
#   'state',
#   'states',
#   'tuesday',
#   'winners'},
#  {'actually',
#   'around',
#   'b',
#   'biden',
#   'brought',
#   'campaign',
#   'candidates',
#   'complete',
#   'delegates',
#   'democratic',
#   'earned',
#   'former',
#   'joe',
#   'moderate',
#   'multiple',
#   'party',
#   'president',
#   'presidential',
#   'primary',
#   'results',
#   'revival',
#   'sen',
#   'stand',
#   'state',
#   'states',
#   'super',
#   'together',
#   'tuesday',
#   'vermont',
#   'vice',
#   'wing'},
#  {'biden',
#   'chance',
#   'consecutive',
#   'contenders',
#   'delegates',
#   'democratic',
#   'elections',
#   'first',
#   'former',
#   'head',
#   'joe',
#   'last',
#   'major',
#   'march',
#   'nomination',
#   'party',
#   'polls',
#   'president',
#   'presidential',
#   'primaries',
#   'primary',
#   'remaining',
#   'see',
#   'sen',
#   'set',
#   'stake',
#   'states',
#   'third',
#   'tuesday',
#   'two',
#   'vermont',
#   'vice',
#   'vote',
#   'voters',
#   'voting'},
#  {'american',
#   'announced',
#   'bars',
#   'concerns',
#   'coronavirus',
#   'due',
#   'either',
#   'elections',
#   'even',
#   'events',
#   'including',
#   'life',
#   'multiple',
#   'outbreak',
#   'postponed',
#   'postponing',
#   'presidential',
#   'primaries',
#   'primary',
#   'schools',
#   'shut',
#   'sporting',
#   'spreading',
#   'states'},
#  {'bid',
#   'billion',
#   'bloomberg',
#   'campaign',
#   'city',
#   'contests',
#   'democratic',
#   'ended',
#   'failed',
#   'feder',
#   'federal',
#   'five',
#   'former',
#   'fortune',
#   'lasted',
#   'less',
#   'major',
#   'mayor',
#   'mike',
#   'money',
#   'months',
#   'nearly',
#   'new',
#   'personal',
#   'presidential',
#   'primary',
#   'season',
#   'spent',
#   'winning',
#   'without',
#   'york'},
#  {'amer',
#   'america',
#   'b',
#   'bernie',
#   'came',
#   'carolina',
#   'castro',
#   'claims',
#   'comments',
#   'cuban',
#   'debate',
#   'democratic',
#   'dictator',
#   'ed',
#   'fidel',
#   'following',
#   'front',
#   'henry',
#   'host',
#   'ideas',
#   'late',
#   'lying',
#   'media',
#   'newsroom',
#   'popular',
#   'pressed',
#   'primary',
#   'runner',
#   'said',
#   'sanders',
#   'socialism',
#   'socialist',
#   'south',
#   'support',
#   'surrogate',
#   'wednesday',
#   'winner',
#   'zahr'},
#  {'angle',
#   'biden',
#   'campaign',
#   'candidate',
#   'carolina',
#   'carolinaprimary',
#   'democratic',
#   'f',
#   'fox',
#   'friday',
#   'headed',
#   'host',
#   'important',
#   'ingraham',
#   'joe',
#   'lacking',
#   'lacks',
#   'lagging',
#   'laura',
#   'magic',
#   'money',
#   'news',
#   'night',
#   'noted',
#   'obama',
#   'old',
#   'presidential',
#   'primary',
#   'saturday',
#   'south',
#   'things',
#   'two',
#   'wondered',
#   'year'},
#  {'biden',
#   'bloomberg',
#   'call',
#   'campaign',
#   'carolina',
#   'cited',
#   'democrat',
#   'end',
#   'joe',
#   'joke',
#   'michael',
#   'mike',
#   'mini',
#   'president',
#   'presidential',
#   'primary',
#   'saturday',
#   'says',
#   'sleepy',
#   'south',
#   'trump',
#   'victory',
#   'win'},
#  {'biden',
#   'big',
#   'campaign',
#   'carolina',
#   'complete',
#   'corey',
#   'despite',
#   'former',
#   'hurting',
#   'joe',
#   'lewandowski',
#   'life',
#   'manager',
#   'night',
#   'president',
#   'presidential',
#   'primary',
#   'said',
#   'saturday',
#   'says',
#   'south',
#   'still',
#   'support',
#   'trump',
#   'vice',
#   'victory',
#   'win'},
#  {'accidentally',
#   'attend',
#   'biden',
#   'candidate',
#   'carolina',
#   'critical',
#   'crowd',
#   'days',
#   'dem',
#   'democratic',
#   'former',
#   'gaffe',
#   'hopefuls',
#   'joe',
#   'made',
#   'one',
#   'president',
#   'primary',
#   'senate',
#   'several',
#   'south',
#   'states',
#   'telling',
#   'tells',
#   'unfortunate',
#   'united',
#   'vice',
#   'voters'},
#  {'accept',
#   'acceptance',
#   'anger',
#   'bargaining',
#   'bearer',
#   'bernard',
#   'bernie',
#   'colin',
#   'comes',
#   'contest',
#   'current',
#   'democratic',
#   'democrats',
#   'dems',
#   'denial',
#   'depression',
#   'edge',
#   'elisabeth',
#   'establishment',
#   'five',
#   'front',
#   'grief',
#   'kubler',
#   'learn',
#   'life',
#   'looking',
#   'man',
#   'new',
#   'newfound',
#   'next',
#   'party',
#   'primary',
#   'pushing',
#   'reed',
#   'reminded',
#   'ross',
#   'runner',
#   'sanders',
#   'sen',
#   'stages',
#   'standard',
#   'state',
#   'status',
#   'takeover',
#   'vt',
#   'wears',
#   'wh'},
#  {'absolutely',
#   'ahead',
#   'american',
#   'asked',
#   'bernie',
#   'carolina',
#   'castro',
#   'contributor',
#   'correspondent',
#   'democrats',
#   'election',
#   'felt',
#   'fox',
#   'frontrunner',
#   'grills',
#   'hannity',
#   'inconceivable',
#   'jones',
#   'knowin',
#   'lawrence',
#   'news',
#   'old',
#   'praise',
#   'primary',
#   'sanders',
#   'saturday',
#   'south'},
#  {'appeal',
#   'azz',
#   'back',
#   'billionaire',
#   'carolina',
#   'danced',
#   'dances',
#   'excruciating',
#   'final',
#   'hopeful',
#   'house',
#   'important',
#   'juvenile',
#   'loose',
#   'one',
#   'primary',
#   'rapper',
#   'saturday',
#   'shake',
#   'signature',
#   'south',
#   'stage',
#   'steyer',
#   'tartan',
#   'tie',
#   'tom',
#   'video',
#   'voters',
#   'votes',
#   'way',
#   'wearing',
#   'white'},
#  {'andrew',
#   'candidacy',
#   'dark',
#   'democratic',
#   'dropped',
#   'dropping',
#   'entrepreneur',
#   'getting',
#   'hopes',
#   'horse',
#   'launched',
#   'launches',
#   'many',
#   'mean',
#   'nonprofit',
#   'organization',
#   'politics',
#   'presidential',
#   'primary',
#   'pundits',
#   'race',
#   'surprised',
#   'thursday',
#   'whose',
#   'yang'},
#  {'bernie',
#   'biden',
#   'choices',
#   'confidence',
#   'cranky',
#   'created',
#   'decisions',
#   'democrats',
#   'disaster',
#   'endorsed',
#   'evident',
#   'fleeing',
#   'former',
#   'getting',
#   'go',
#   'gutfeld',
#   'hold',
#   'inspired',
#   'joe',
#   'men',
#   'moments',
#   'old',
#   'one',
#   'president',
#   'presidential',
#   'primary',
#   'quickly',
#   'rolling',
#   'self',
#   'sleeping',
#   'slow',
#   'stuck',
#   'three',
#   'truths',
#   'two',
#   'vice',
#   'vs',
#   'women'},
#  {'ballots',
#   'cast',
#   'cliche',
#   'confusion',
#   'democratic',
#   'democrats',
#   'describes',
#   'designed',
#   'diverse',
#   'facing',
#   'fall',
#   'get',
#   'however',
#   'jessica',
#   'key',
#   'line',
#   'looks',
#   'love',
#   'maybe',
#   'messy',
#   'need',
#   'nominating',
#   'old',
#   'one',
#   'overused',
#   'party',
#   'political',
#   'presidential',
#   'primary',
#   'process',
#   'remember',
#   'republicans',
#   'sho',
#   'sometimes',
#   'tarlov',
#   'thing',
#   'voters',
#   'well',
#   'working'},
#  {'apparently',
#   'back',
#   'bernie',
#   'c',
#   'campaign',
#   'columbia',
#   'current',
#   'cutting',
#   'democracy',
#   'democratic',
#   'digest',
#   'electability',
#   'eve',
#   'front',
#   'heavy',
#   'hi',
#   'light',
#   'nomination',
#   'populist',
#   'president',
#   'presidential',
#   'primary',
#   'race',
#   'revolution',
#   'runner',
#   'sanders',
#   'sc',
#   'sen',
#   'senator',
#   'touted',
#   'touting',
#   'trail',
#   'use',
#   'vermont',
#   'word'},
#  {'bernie',
#   'biden',
#   'campaign',
#   'cannot',
#   'carolina',
#   'congratulated',
#   'congratulates',
#   'eyes',
#   'following',
#   'former',
#   'held',
#   'iowa',
#   'joe',
#   'popular',
#   'president',
#   'primary',
#   'rally',
#   'sanders',
#   'sen',
#   'setting',
#   'sights',
#   'south',
#   'super',
#   'th',
#   'tuesday',
#   'vice',
#   'victory',
#   'virginia',
#   'vote',
#   'vt',
#   'win'},
#  {'act',
#   'bern',
#   'berni',
#   'biden',
#   'campaign',
#   'carolina',
#   'close',
#   'crucial',
#   'democratic',
#   'firewall',
#   'first',
#   'former',
#   'front',
#   'frontrunner',
#   'hoping',
#   'joe',
#   'must',
#   'polls',
#   'president',
#   'presidential',
#   'primary',
#   'race',
#   'runner',
#   'saturday',
#   'seeks',
#   'sen',
#   'soon',
#   'south',
#   'state',
#   'struggling',
#   'surging',
#   'vice',
#   'win'},
#  {'ahead',
#   'analyst',
#   'bl',
#   'brit',
#   'c',
#   'campaigning',
#   'carolina',
#   'charleston',
#   'daily',
#   'delved',
#   'democratic',
#   'dirty',
#   'first',
#   'fox',
#   'grounds',
#   'history',
#   'hume',
#   'infamous',
#   'issued',
#   'main',
#   'mudslinging',
#   'nasty',
#   'nation',
#   'new',
#   'news',
#   'newspaper',
#   'paper',
#   'political',
#   'presidential',
#   'primary',
#   'proving',
#   'reputation',
#   'row',
#   'sc',
#   'season',
#   'second',
#   'see',
#   'senior',
#   'show',
#   'south',
#   'state',
#   'tell',
#   'tricks',
#   'us',
#   'voters',
#   'warning',
#   'warns'},
#  {'accused',
#   'carolina',
#   'charleston',
#   'coronavirus',
#   'critics',
#   'day',
#   'democratic',
#   'democrats',
#   'dems',
#   'eve',
#   'evening',
#   'face',
#   'friday',
#   'h',
#   'head',
#   'holds',
#   'nominee',
#   'north',
#   'politicizing',
#   'polls',
#   'president',
#   'primary',
#   'rally',
#   'south',
#   'stage',
#   'supporters',
#   'took',
#   'trump',
#   'virus',
#   'vote'},
#  {'accused',
#   'barack',
#   'bill',
#   'campaign',
#   'candidate',
#   'carolina',
#   'caused',
#   'clinton',
#   'democratic',
#   'faced',
#   'former',
#   'hillary',
#   'neck',
#   'obama',
#   'president',
#   'presidential',
#   'primary',
#   'problems',
#   'race',
#   'racism',
#   'senator',
#   'serious',
#   'south',
#   'wife'},
#  {'action',
#   'al',
#   'back',
#   'backed',
#   'barack',
#   'bernie',
#   'bid',
#   'campaigns',
#   'challen',
#   'claimed',
#   'claims',
#   'close',
#   'despite',
#   'event',
#   'hosted',
#   'indicating',
#   'mulling',
#   'national',
#   'network',
#   'obama',
#   'president',
#   'presidential',
#   'primary',
#   'proud',
#   'recent',
#   'report',
#   'sanders',
#   'sen',
#   'sharpton',
#   'vt',
#   'wednesday'},
#  {'able',
#   'backing',
#   'bernie',
#   'best',
#   'biden',
#   'big',
#   'candidate',
#   'carolina',
#   'challenge',
#   'defeat',
#   'democratic',
#   'efforts',
#   'former',
#   'gives',
#   'joe',
#   'leslie',
#   'marshall',
#   'position',
#   'president',
#   'presidential',
#   'primary',
#   'sanders',
#   'saturday',
#   'sc',
#   'sen',
#   'socialist',
#   'south',
#   'strengthens',
#   'strong',
#   'vice',
#   'victory',
#   'vt'},
#  {'approach',
#   'c',
#   'carolina',
#   'columbia',
#   'democratic',
#   'democrats',
#   'estimate',
#   'going',
#   'high',
#   'higher',
#   'may',
#   'officials',
#   'original',
#   'party',
#   'presidential',
#   'primary',
#   'probably',
#   'record',
#   'saturday',
#   'say',
#   'set',
#   'south',
#   'substantially',
#   'think',
#   'top',
#   'turnout',
#   'two'},
#  {'absent',
#   'accused',
#   'air',
#   'allegations',
#   'behavior',
#   'carolina',
#   'chris',
#   'contributor',
#   'coverage',
#   'day',
#   'evening',
#   'former',
#   'later',
#   'matthews',
#   'misidentifying',
#   'msnbc',
#   'network',
#   'noticebaly',
#   'one',
#   'politician',
#   'primary',
#   'saturday',
#   'sexism',
#   'sexist',
#   'slip',
#   'south',
#   'ups'},
#  {'aid',
#   'bid',
#   'biden',
#   'c',
#   'carolina',
#   'collapsed',
#   'columbia',
#   'decide',
#   'democratic',
#   'first',
#   'former',
#   'fourth',
#   'got',
#   'house',
#   'joe',
#   'likely',
#   'may',
#   'needed',
#   'night',
#   'poor',
#   'president',
#   'presidential',
#   'primary',
#   'reset',
#   'resurrecting',
#   'saturday',
#   'south',
#   'super',
#   'tuesday',
#   'vice',
#   'white',
#   'win',
#   'would'},
#  {'appeared',
#   'biden',
#   'called',
#   'calls',
#   'carolina',
#   'carry',
#   'comeback',
#   'confident',
#   'democratic',
#   'former',
#   'fox',
#   'joe',
#   'looks',
#   'momentum',
#   'news',
#   'night',
#   'president',
#   'primaries',
#   'primary',
#   'real',
#   'saturday',
#   'sc',
#   'seemed',
#   'sets',
#   'sights',
#   'south',
#   'sunday',
#   'super',
#   'th',
#   'tuesday',
#   'upcoming',
#   'vice',
#   'victory'},
#  {'biden',
#   'big',
#   'briefly',
#   'campaigning',
#   'candidates',
#   'canvassing',
#   'coronavirus',
#   'country',
#   'despite',
#   'facing',
#   'first',
#   'forward',
#   'go',
#   'head',
#   'looks',
#   'modern',
#   'pandemic',
#   'polls',
#   'presidential',
#   'primaries',
#   'primary',
#   'sanders',
#   'shut',
#   'sight',
#   'states',
#   'three',
#   'times',
#   'trepidation',
#   'tuesday',
#   'unpreced',
#   'voters',
#   'welcome'},
#  {'biden',
#   'carolina',
#   'changed',
#   'could',
#   'democratic',
#   'end',
#   'former',
#   'gingrich',
#   'going',
#   'hours',
#   'joe',
#   'long',
#   'newt',
#   'president',
#   'presidential',
#   'primaries',
#   'primary',
#   'question',
#   'race',
#   'ropes',
#   'scal',
#   'south',
#   'studied',
#   'super',
#   'survive',
#   'time',
#   'tuesday',
#   'vice',
#   'whether'},
#  {'bernie',
#   'biden',
#   'candidates',
#   'claims',
#   'clashed',
#   'clashes',
#   'cuts',
#   'debate',
#   'democratic',
#   'faced',
#   'fight',
#   'former',
#   'four',
#   'joe',
#   'major',
#   'night',
#   'nomination',
#   'president',
#   'primary',
#   'race',
#   'record',
#   'reignited',
#   'remaining',
#   'sanders',
#   'security',
#   'sen',
#   'social',
#   'sought',
#   'straight',
#   'sunday',
#   'two',
#   'vice'},
#  {'audience',
#   'b',
#   'candidates',
#   'cheer',
#   'coronavirus',
#   'debate',
#   'democratic',
#   'due',
#   'former',
#   'going',
#   'interrupt',
#   'joe',
#   'live',
#   'moderators',
#   'next',
#   'precautions',
#   'president',
#   'presidential',
#   'primary',
#   'stage',
#   'sunday',
#   'vice',
#   'warning',
#   'worry'},
#  {'according',
#   'arizona',
#   'bernie',
#   'biden',
#   'commanding',
#   'eve',
#   'former',
#   'holds',
#   'joe',
#   'lead',
#   'monday',
#   'monmouth',
#   'new',
#   'percent',
#   'points',
#   'poll',
#   'president',
#   'presidential',
#   'primary',
#   'released',
#   'sanders',
#   'sen',
#   'shows',
#   'state',
#   'support',
#   'survey',
#   'university',
#   'vice'},
#  {'amid',
#   'ballots',
#   'beach',
#   'cast',
#   'caused',
#   'coronavirus',
#   'dealing',
#   'deart',
#   'dearth',
#   'election',
#   'fears',
#   'florida',
#   'held',
#   'home',
#   'many',
#   'officials',
#   'orlando',
#   'outbreak',
#   'palm',
#   'pandemic',
#   'poll',
#   'presidential',
#   'primary',
#   'state',
#   'stay',
#   'sunshine',
#   'tuesday',
#   'voters',
#   'workers'},
#  {'already',
#   'appeared',
#   'biden',
#   'c',
#   'call',
#   'calls',
#   'canceling',
#   'clyburn',
#   'coming',
#   'conversation',
#   'debates',
#   'declare',
#   'dem',
#   'democratic',
#   'endorsed',
#   'former',
#   'house',
#   'jim',
#   'joe',
#   'majority',
#   'night',
#   'npr',
#   'president',
#   'primary',
#   'race',
#   'ready',
#   'results',
#   'shutting',
#   'surge',
#   'tuesday',
#   'vice',
#   'victor',
#   'whip'},
#  {'afternoon',
#   'biggest',
#   'complete',
#   'earliest',
#   'full',
#   'holding',
#   'michigan',
#   'mid',
#   'office',
#   'officials',
#   'primaries',
#   'primary',
#   'prize',
#   'released',
#   'results',
#   'sai',
#   'say',
#   'secretary',
#   'six',
#   'state',
#   'states',
#   'tabulated',
#   'tuesday',
#   'wednesday',
#   'word'},
#  {'ago',
#   'bernie',
#   'biden',
#   'building',
#   'closing',
#   'contests',
#   'cruises',
#   'easily',
#   'former',
#   'fox',
#   'joe',
#   'making',
#   'michigan',
#   'mississippi',
#   'missouri',
#   'momentum',
#   'news',
#   'past',
#   'pivotal',
#   'polls',
#   'president',
#   'primaries',
#   'primary',
#   'projected',
#   'projects',
#   'sanders',
#   'sen',
#   'soon',
#   'states',
#   'super',
#   'tuesday',
#   'vermont',
#   'vice',
#   'week',
#   'wh',
#   'win'},
#  {'accidentally',
#   'airing',
#   'another',
#   'bernie',
#   'biden',
#   'cnn',
#   'coverage',
#   'declaring',
#   'deleg',
#   'displaying',
#   'election',
#   'former',
#   'graphic',
#   'joe',
#   'mississippi',
#   'mocked',
#   'night',
#   'overtaking',
#   'president',
#   'primary',
#   'rough',
#   'sanders',
#   'sen',
#   'start',
#   'strong',
#   'tuesday',
#   'vice',
#   'vt',
#   'winner'},
#  {'allowing',
#   'amid',
#   'arizona',
#   'around',
#   'chairman',
#   'committee',
#   'coronavirus',
#   'criticized',
#   'delay',
#   'democrat',
#   'democratic',
#   'dems',
#   'dnc',
#   'elections',
#   'get',
#   'going',
#   'governments',
#   'illinois',
#   'irresponsible',
#   'killed',
#   'marked',
#   'national',
#   'outbreak',
#   'party',
#   'people',
#   'perez',
#   'primaries',
#   'primary',
#   'progressives',
#   'races',
#   'round',
#   'slam',
#   'state',
#   'tom',
#   'tuesday',
#   'urging',
#   'virus',
#   'widely'},
#  {'cannot',
#   'clear',
#   'concerns',
#   'confusion',
#   'coronavirus',
#   'court',
#   'day',
#   'despite',
#   'dewine',
#   'due',
#   'election',
#   'elections',
#   'gov',
#   'h',
#   'hold',
#   'june',
#   'legislature',
#   'mike',
#   'move',
#   'ohio',
#   'place',
#   'plan',
#   'postponed',
#   'postponement',
#   'primary',
#   'recommendation',
#   'republican',
#   'set',
#   'simply',
#   'spreading',
#   'state',
#   'still',
#   'take'},
#  {'away',
#   'back',
#   'backing',
#   'backs',
#   'biden',
#   'calling',
#   'campaign',
#   'carolina',
#   'denied',
#   'describing',
#   'description',
#   'even',
#   'firewall',
#   'former',
#   'joe',
#   'lock',
#   'pointing',
#   'president',
#   'previously',
#   'primary',
#   'pushed',
#   'south',
#   'state',
#   'sunday',
#   'upcoming',
#   'vice',
#   'virtual'},
#  {'aim',
#   'bernie',
#   'bring',
#   'calling',
#   'calls',
#   'columnist',
#   'counter',
#   'debate',
#   'dem',
#   'democratic',
#   'elders',
#   'former',
#   'friedman',
#   'gathering',
#   'like',
#   'longtime',
#   'maturity',
#   'new',
#   'nyt',
#   'obama',
#   'particular',
#   'party',
#   'president',
#   'primary',
#   'process',
#   'sanders',
#   'sen',
#   'surge',
#   'times',
#   'tom',
#   'took',
#   'tuesday',
#   'vt',
#   'york'},
#  {'ahead',
#   'biden',
#   'c',
#   'campaign',
#   'carolina',
#   'charleston',
#   'contests',
#   'debate',
#   'democratic',
#   'failing',
#   'first',
#   'getting',
#   'insisting',
#   'joe',
#   'night',
#   'notch',
#   'presidential',
#   'primary',
#   'race',
#   'says',
#   'seni',
#   'south',
#   'started',
#   'three',
#   'tuesday',
#   'upcoming',
#   'victory',
#   'vowed',
#   'vows',
#   'win'},
#  {'anne',
#   'answer',
#   'candidates',
#   'carolina',
#   'changed',
#   'debate',
#   'democratic',
#   'fight',
#   'final',
#   'hour',
#   'leading',
#   'losers',
#   'march',
#   'marsh',
#   'mary',
#   'night',
#   'nomination',
#   'presidential',
#   'primary',
#   'race',
#   'resembled',
#   'satur',
#   'saturday',
#   'seven',
#   'something',
#   'south',
#   'street',
#   'super',
#   'tuesday',
#   'turned',
#   'two',
#   'view',
#   'way',
#   'whether',
#   'winners'},
#  {'ahead',
#   'anything',
#   'carolina',
#   'charleston',
#   'connection',
#   'day',
#   'democratic',
#   'described',
#   'first',
#   'friday',
#   'gov',
#   'henry',
#   'like',
#   'love',
#   'mcmaster',
#   'never',
#   'night',
#   'north',
#   'one',
#   'politicians',
#   'president',
#   'primary',
#   'rally',
#   'republican',
#   'seen',
#   'south',
#   'state',
#   'trump',
#   'voters'},
#  {'bernie',
#   'c',
#   'calendar',
#   'carolina',
#   'charleston',
#   'complained',
#   'could',
#   'distorts',
#   'early',
#   'griping',
#   'hold',
#   'looming',
#   'many',
#   'polls',
#   'primaries',
#   'primary',
#   'pro',
#   'reality',
#   'remarks',
#   'resurfaced',
#   'said',
#   'sanders',
#   'south',
#   'southern',
#   'states',
#   'suddenly',
#   'surging'},
#  {'america',
#   'appearing',
#   'bernie',
#   'break',
#   'c',
#   'carolina',
#   'continue',
#   'debate',
#   'democratic',
#   'face',
#   'field',
#   'host',
#   'make',
#   'moment',
#   'newsroom',
#   'predicted',
#   'primary',
#   'r',
#   'rest',
#   'rivals',
#   'sanders',
#   'sandra',
#   'saturday',
#   'scott',
#   'sen',
#   'smith',
#   'south',
#   'streak',
#   'tim',
#   'trouble',
#   'tuesday',
#   'vt',
#   'winning'},
#  {'allow',
#   'backs',
#   'bernie',
#   'campai',
#   'candidate',
#   'continues',
#   'controversial',
#   'democratic',
#   'even',
#   'felons',
#   'front',
#   'incarcerated',
#   'letting',
#   'one',
#   'presidential',
#   'primary',
#   'prison',
#   'proposals',
#   'revisited',
#   'right',
#   'runner',
#   'sanders',
#   'sen',
#   'stand',
#   'violent',
#   'vote',
#   'vt',
#   'would'},
#  {'ahead',
#   'bloomberg',
#   'called',
#   'carolina',
#   'charles',
#   'city',
#   'coverage',
#   'dangerous',
#   'democratic',
#   'editor',
#   'examiner',
#   'former',
#   'fox',
#   'hurt',
#   'mayor',
#   'mike',
#   'new',
#   'news',
#   'opinion',
#   'party',
#   'person',
#   'primary',
#   'problem',
#   'saturday',
#   'south',
#   'special',
#   'super',
#   'think',
#   'tuesday',
#   'washington',
#   'york'},
#  {'adviser',
#   'appeared',
#   'biden',
#   'bush',
#   'candidate',
#   'carolina',
#   'coverage',
#   'democratic',
#   'former',
#   'fox',
#   'george',
#   'house',
#   'joe',
#   'karl',
#   'news',
#   'president',
#   'presidential',
#   'primary',
#   'projected',
#   'reacted',
#   'rove',
#   'saturday',
#   'senior',
#   'south',
#   'special',
#   'tonight',
#   'w',
#   'white',
#   'win'},
#  {'busting',
#   'c',
#   'candidate',
#   'carolina',
#   'close',
#   'columbia',
#   'dance',
#   'deal',
#   'democratic',
#   'first',
#   'floor',
#   'hours',
#   'move',
#   'optimistic',
#   'pledged',
#   'presidential',
#   'primary',
#   'pumped',
#   'ready',
#   'run',
#   'says',
#   'south',
#   'steyer',
#   'suppo',
#   'tape',
#   'told',
#   'tom',
#   'viral',
#   'went'},
#  {'blood',
#   'conference',
#   'coronavirus',
#   'daily',
#   'delivered',
#   'fight',
#   'fights',
#   'get',
#   'gov',
#   'inbox',
#   'latest',
#   'monday',
#   'new',
#   'news',
#   'outbreak',
#   'patients',
#   'plasma',
#   'press',
#   'recovered',
#   'says',
#   'sign',
#   'state',
#   'using',
#   'york'},
#  {'africa',
#   'another',
#   'closure',
#   'congo',
#   'coronavirus',
#   'endangered',
#   'face',
#   'gorillas',
#   'home',
#   'large',
#   'mountain',
#   'national',
#   'park',
#   'prompting',
#   'putting',
#   'risk',
#   'said',
#   'species',
#   'third',
#   'virunga',
#   'vulnerable',
#   'world'},
#  {'australia',
#   'back',
#   'blood',
#   'body',
#   'coronavirus',
#   'country',
#   'covid',
#   'doherty',
#   'experts',
#   'fights',
#   'first',
#   'human',
#   'immune',
#   'immunity',
#   'infection',
#   'institute',
#   'map',
#   'mapped',
#   'novel',
#   'one',
#   'patients',
#   'peter',
#   'recovers',
#   'responses',
#   'sampl',
#   'scientists',
#   'show',
#   'system',
#   'tested'},
#  {'airline',
#   'airlines',
#   'america',
#   'american',
#   'amid',
#   'announced',
#   'ban',
#   'cancellation',
#   'cap',
#   'change',
#   'cnbc',
#   'coronavirus',
#   'countries',
#   'covid',
#   'day',
#   'declaration',
#   'delta',
#   'demand',
#   'europe',
#   'european',
#   'fares',
#   'flight',
#   'following',
#   'fox',
#   'involving',
#   'list',
#   'major',
#   'master',
#   'news',
#   'ongoing',
#   'people',
#   'po',
#   'president',
#   'return',
#   'scramble',
#   'sparks',
#   'stateside',
#   'surge',
#   'three',
#   'travel',
#   'trump',
#   'u',
#   'united',
#   'us'},
#  {'abc',
#   'ability',
#   'abstinence',
#   'announces',
#   'asked',
#   'attempt',
#   'charge',
#   'comedian',
#   'contain',
#   'coronaviru',
#   'coronavirus',
#   'criticized',
#   'fox',
#   'fumble',
#   'government',
#   'handling',
#   'hiv',
#   'jimmy',
#   'joked',
#   'kimmel',
#   'lead',
#   'leads',
#   'mike',
#   'mocks',
#   'news',
#   'outbreak',
#   'pandemic',
#   'pence',
#   'plan',
#   'president',
#   'put',
#   'response',
#   'tackle',
#   'trump',
#   'us',
#   'vice',
#   'vp',
#   'wednesday',
#   'wha',
#   'would'},
#  {'amid',
#   'announced',
#   'business',
#   'congress',
#   'congressional',
#   'coronavirus',
#   'crisis',
#   'cut',
#   'done',
#   'economy',
#   'evening',
#   'fox',
#   'help',
#   'leaders',
#   'leadership',
#   'meet',
#   'meeting',
#   'monday',
#   'news',
#   'outbreak',
#   'payroll',
#   'pitch',
#   'plans',
#   'president',
#   'press',
#   'relief',
#   'said',
#   'senate',
#   'small',
#   'struggles',
#   'tax',
#   'tomorrow',
#   'trump',
#   'tuesday'},
#  {'catastrophe',
#   'causes',
#   'challenges',
#   'dealing',
#   'fox',
#   'frustrating',
#   'global',
#   'help',
#   'hollywood',
#   'home',
#   'made',
#   'many',
#   'middle',
#   'news',
#   'pandemic',
#   'people',
#   'real',
#   'sane',
#   'screenplay',
#   'sinister',
#   'stay',
#   'stop',
#   'tech',
#   'thinking',
#   'thriller',
#   'trying',
#   'virus',
#   'ways'},
#  {'ability',
#   'according',
#   'adults',
#   'british',
#   'clue',
#   'coronavirus',
#   'could',
#   'crucial',
#   'days',
#   'docto',
#   'doctors',
#   'fox',
#   'friday',
#   'individual',
#   'infection',
#   'isolate',
#   'lose',
#   'loss',
#   'lost',
#   'may',
#   'new',
#   'news',
#   'peculiar',
#   'post',
#   'recent',
#   'report',
#   'reported',
#   'self',
#   'sense',
#   'senses',
#   'seven',
#   'sign',
#   'smell',
#   'symptoms',
#   'taste',
#   'telltale',
#   'times',
#   'warned',
#   'york'},
#  {'american',
#   'bolsonaro',
#   'brazil',
#   'brazilian',
#   'claims',
#   'cnbc',
#   'contradicting',
#   'coronavirus',
#   'despite',
#   'earlier',
#   'eduardo',
#   'father',
#   'fox',
#   'indicated',
#   'initially',
#   'jair',
#   'leader',
#   'meeting',
#   'negative',
#   'news',
#   'official',
#   'pence',
#   'photo',
#   'posed',
#   'positiv',
#   'positive',
#   'president',
#   'reports',
#   'say',
#   'son',
#   'south',
#   'tested',
#   'tests',
#   'told',
#   'trump'},
#  {'advise',
#   'americans',
#   'avoid',
#   'becoming',
#   'charts',
#   'coronavirus',
#   'explaining',
#   'fox',
#   'hands',
#   'home',
#   'include',
#   'infected',
#   'locations',
#   'news',
#   'people',
#   'precautions',
#   'president',
#   'safety',
#   'school',
#   'series',
#   'take',
#   'thursday',
#   'tips',
#   'trump',
#   'tweeted',
#   'tweets',
#   'wash',
#   'work'},
#  {'according',
#   'another',
#   'bringing',
#   'confirmed',
#   'confirms',
#   'coronavirus',
#   'coverage',
#   'death',
#   'department',
#   'fatalities',
#   'fox',
#   'full',
#   'google',
#   'health',
#   'kin',
#   'news',
#   'nine',
#   'novel',
#   'number',
#   'officials',
#   'patient',
#   'public',
#   'reported',
#   'state',
#   'total',
#   'view',
#   'washington'},
#  {'confirms',
#   'coronoavirus',
#   'gallagher',
#   'hanks',
#   'positive',
#   'reports',
#   'rita',
#   'test',
#   'tom',
#   'trace',
#   'virus',
#   'wife',
#   'wilson'},
#  {'bomb',
#   'carolina',
#   'chairman',
#   'committee',
#   'coronavirus',
#   'counterattack',
#   'economy',
#   'going',
#   'graham',
#   'judiciary',
#   'kill',
#   'lindsey',
#   'says',
#   'sen',
#   'senate',
#   'senator',
#   'south',
#   'stabilizing',
#   'starve',
#   'us',
#   'virus'},
#  {'america',
#   'americans',
#   'b',
#   'chris',
#   'city',
#   'commentary',
#   'coronavirus',
#   'director',
#   'discusses',
#   'dr',
#   'fight',
#   'growing',
#   'madad',
#   'new',
#   'outbreak',
#   'pathogens',
#   'plus',
#   'prepared',
#   'program',
#   'protect',
#   'ready',
#   'senator',
#   'senior',
#   'special',
#   'spread',
#   'syra',
#   'system',
#   'take',
#   'u',
#   'virus',
#   'wallace',
#   'wide',
#   'york'},
#  {'airing',
#   'biden',
#   'blames',
#   'coronavirus',
#   'coverage',
#   'crisis',
#   'election',
#   'follow',
#   'hatred',
#   'hosting',
#   'howardkurtz',
#   'howie',
#   'impacting',
#   'joe',
#   'kurtz',
#   'maddow',
#   'media',
#   'noticed',
#   'rachel',
#   'saying',
#   'stay',
#   'stop',
#   'tough',
#   'trump',
#   'trying',
#   'twitter',
#   'updates',
#   'virus'},
#  {'american',
#   'barely',
#   'biden',
#   'budge',
#   'china',
#   'click',
#   'coronavirus',
#   'coverage',
#   'defending',
#   'expulsion',
#   'follow',
#   'howardkurtz',
#   'howie',
#   'joe',
#   'journalists',
#   'judging',
#   'kurtz',
#   'media',
#   'mediabuzz',
#   'president',
#   'primaries',
#   'quietly',
#   'response',
#   'states',
#   'sweeps',
#   'trump',
#   'twitter',
#   'virus',
#   'winning'},
#  {'bill',
#   'click',
#   'despite',
#   'economic',
#   'eye',
#   'fighting',
#   'final',
#   'follow',
#   'howardkurtz',
#   'howie',
#   'kurtz',
#   'making',
#   'markets',
#   'mediabuzz',
#   'moves',
#   'offs',
#   'olympics',
#   'others',
#   'pandemic',
#   'positively',
#   'postponed',
#   'reacting',
#   'rescue',
#   'restrictions',
#   'softening',
#   'tokyo',
#   'towards',
#   'trade',
#   'trump',
#   'twitter',
#   'virus',
#   'vote'},
#  {'beat',
#   'believes',
#   'bill',
#   'brian',
#   'congress',
#   'cornyn',
#   'coronavirus',
#   'discuss',
#   'financial',
#   'footing',
#   'funding',
#   'hardships',
#   'help',
#   'house',
#   'john',
#   'joined',
#   'kilmeade',
#   'nation',
#   'need',
#   'otherwise',
#   'passing',
#   'quarantine',
#   'r',
#   'sen',
#   'support',
#   'tx',
#   'unable',
#   'virus',
#   'war',
#   'work'},
#  {'benson',
#   'china',
#   'coronavirus',
#   'department',
#   'earlier',
#   'fire',
#   'fox',
#   'guy',
#   'holding',
#   'listen',
#   'lit',
#   'match',
#   'morgan',
#   'news',
#   'ortagus',
#   'radio',
#   'response',
#   'spoke',
#   'spokesperson',
#   'spox',
#   'state',
#   'today',
#   'us',
#   'virus',
#   'world'},
#  {'across',
#   'america',
#   'briefings',
#   'candidate',
#   'congress',
#   'coronavirus',
#   'disgusted',
#   'dr',
#   'email',
#   'embedon',
#   'failla',
#   'force',
#   'former',
#   'fox',
#   'house',
#   'jackson',
#   'jimmy',
#   'make',
#   'physician',
#   'president',
#   'press',
#   'ronny',
#   'speaks',
#   'task',
#   'th',
#   'treated',
#   'trump',
#   'trying',
#   'white',
#   'xenophobe'},
#  {'anticipation',
#   'around',
#   'bad',
#   'california',
#   'climbed',
#   'communities',
#   'coronavirus',
#   'country',
#   'county',
#   'death',
#   'deaths',
#   'equivalent',
#   'flu',
#   'general',
#   'hoard',
#   'kin',
#   'local',
#   'new',
#   'officials',
#   'one',
#   'placer',
#   'precautions',
#   'season',
#   'spreading',
#   'state',
#   'stop',
#   'surgeon',
#   'take',
#   'think',
#   'toll',
#   'two',
#   'u',
#   'urged',
#   'us',
#   'virus',
#   'washington',
#   'ways',
#   'wednesday'},
#  {'administration',
#   'america',
#   'burgess',
#   'combat',
#   'coronavirus',
#   'donna',
#   'fight',
#   'fl',
#   'growing',
#   'jared',
#   'michael',
#   'plan',
#   'potus',
#   'prepared',
#   'r',
#   'rep',
#   'scotus',
#   'se',
#   'seri',
#   'shalala',
#   'speaks',
#   'spread',
#   'taking',
#   'think',
#   'trump',
#   'tx',
#   'v',
#   'virus',
#   'week'},
#  {'children',
#   'coronavirus',
#   'dickinson',
#   'dr',
#   'family',
#   'friends',
#   'g',
#   'kids',
#   'literally',
#   'members',
#   'mom',
#   'momming',
#   'positive',
#   'psychologist',
#   'quite',
#   'see',
#   'staying',
#   'tell',
#   'today',
#   'war',
#   'wendy',
#   'world'},
#  {'ar',
#   'azazie',
#   'boost',
#   'brides',
#   'business',
#   'chains',
#   'company',
#   'competitors',
#   'consumer',
#   'coronavirus',
#   'direct',
#   'diversified',
#   'dress',
#   'faster',
#   'gets',
#   'getting',
#   'jeopardy',
#   'many',
#   'materials',
#   'means',
#   'momming',
#   'since',
#   'supply',
#   'today',
#   'unusual',
#   'wedding'},
#  {'across',
#   'aggressive',
#   'america',
#   'business',
#   'businesses',
#   'care',
#   'congressmen',
#   'discussed',
#   'failla',
#   'fox',
#   'gottheimer',
#   'jimmy',
#   'josh',
#   'local',
#   'make',
#   'measures',
#   'need',
#   'nj',
#   'owners',
#   'people',
#   'rep',
#   'sides',
#   'spread',
#   'stop',
#   'sure',
#   'take',
#   'taken',
#   'time',
#   'virus'},
#  {'across',
#   'america',
#   'amount',
#   'contributor',
#   'distancing',
#   'dr',
#   'explained',
#   'failla',
#   'fox',
#   'going',
#   'hospital',
#   'janette',
#   'jimmy',
#   'lead',
#   'limit',
#   'lives',
#   'many',
#   'medical',
#   'nation',
#   'nesheiwat',
#   'news',
#   'people',
#   'require',
#   'save',
#   'saved',
#   'social',
#   'tha',
#   'want'},
#  {'announced',
#   'available',
#   'big',
#   'billion',
#   'combatting',
#   'coronavirus',
#   'declaration',
#   'declared',
#   'dollars',
#   'emergency',
#   'fifty',
#   'funds',
#   'global',
#   'health',
#   'house',
#   'made',
#   'national',
#   'organization',
#   'outside',
#   'pandemic',
#   'president',
#   'reacted',
#   'saying',
#   'states',
#   'territori',
#   'trump',
#   'two',
#   'united',
#   'week',
#   'white',
#   'words',
#   'world'},
#  {'amid',
#   'average',
#   'business',
#   'commentary',
#   'coronavirus',
#   'correspondent',
#   'dow',
#   'dr',
#   'fears',
#   'fox',
#   'industrial',
#   'investors',
#   'joins',
#   'jones',
#   'kristina',
#   'madness',
#   'marc',
#   'march',
#   'monday',
#   'new',
#   'oil',
#   'partsinevelos',
#   'plummet',
#   'plunge',
#   'plus',
#   'points',
#   'price',
#   'rundown',
#   'sank',
#   'scrambling',
#   'sent',
#   'siegel',
#   'spread',
#   'stock',
#   'stocks',
#   'war',
#   'york'},
#  {'act',
#   'announced',
#   'announcement',
#   'bill',
#   'combat',
#   'commentary',
#   'coronavirus',
#   'defense',
#   'enemy',
#   'ensures',
#   'following',
#   'free',
#   'giv',
#   'government',
#   'help',
#   'house',
#   'illness',
#   'invisible',
#   'invoking',
#   'leslie',
#   'marshall',
#   'pandemic',
#   'passed',
#   'plus',
#   'president',
#   'production',
#   'response',
#   'senate',
#   'testing',
#   'trump'},
#  {'administrator',
#   'also',
#   'america',
#   'brock',
#   'california',
#   'camp',
#   'chief',
#   'concerns',
#   'coronavirus',
#   'crisis',
#   'deadly',
#   'earlier',
#   'efforts',
#   'extra',
#   'failure',
#   'fema',
#   'fire',
# ...
#   'coronavirus',
#   'done',
#   'dorries',
#   'employees',
#   'entire',
#   'government',
#   'health',
#   'house',
#   'keep',
#   'minister',
#   'ministers',
#   'nadine',
#   'open',
#   'outbreak',
#   'parliament',
#   'parliamentary',
#   'post',
#   'protect',
#   'protections',
#   'represent',
#   'said',
#   'say',
#   'shut',
#   'speaker',
#   'staff',
#   'stay',
#   'trade',
#   'tuesday',
#   'unions',
#   'view',
#   'work',
#   'workers',
#   'would',
#   'written'},
#  {'account',
#   'also',
#   'archived',
#   'austr',
#   'australian',
#   'begging',
#   'buy',
#   'caption',
#   'chinese',
#   'concerned',
#   'deleted',
#   'entire',
#   'export',
#   'facebook',
#   'fake',
#   'government',
#   'group',
#   'hoarding',
#   'leung',
#   'ministers',
#   'name',
#   'news',
#   'one',
#   'page',
#   'pages',
#   'paper',
#   'people',
#   'post',
#   'posted',
#   'posts',
#   'pretending',
#   'programs',
#   'put',
#   'regularly',
#   'right',
#   'screenshot',
#   'sell',
#   'shame',
#   'shared',
#   'stop',
#   'swap',
#   'tagged',
#   'times',
#   'toilet',
#   'tv',
#   'un',
#   'view',
#   'wing',
#   'woman'},
#  {'advice',
#   'boris',
#   'britain',
#   'ca',
#   'cobra',
#   'construction',
#   'coronavirus',
#   'critical',
#   'despite',
#   'different',
#   'emergency',
#   'entire',
#   'faces',
#   'forcefully',
#   'give',
#   'good',
#   'government',
#   'increase',
#   'itv',
#   'johnson',
#   'khan',
#   'lockdown',
#   'london',
#   'made',
#   'mayor',
#   'meeting',
#   'monday',
#   'morning',
#   'ordered',
#   'overcrowded',
#   'packed',
#   'pm',
#   'point',
#   'post',
#   'pressure',
#   'quite',
#   'reason',
#   'sadiq',
#   'safety',
#   'said',
#   'services',
#   'still',
#   'think',
#   'told',
#   'trains',
#   'tube',
#   'tuesday',
#   'view',
#   'workers'},
#  {'airlines',
#   'announced',
#   'contacted',
#   'coronavirus',
#   'could',
#   'country',
#   'covid',
#   'decision',
#   'embassy',
#   'entire',
#   'even',
#   'fear',
#   'flights',
#   'governments',
#   'hundreds',
#   'italian',
#   'italians',
#   'italy',
#   'lo',
#   'lockdown',
#   'major',
#   'monday',
#   'night',
#   'number',
#   'place',
#   'post',
#   'significant',
#   'since',
#   'stranded',
#   'suspending',
#   'thousands',
#   'tourists',
#   'uk',
#   'view',
#   'visiting',
#   'wake'},
#  {'alight',
#   'anxiety',
#   'august',
#   'australian',
#   'camp',
#   'coronavirus',
#   'detained',
#   'detention',
#   'died',
#   'earlier',
#   'eighteen',
#   'end',
#   'entire',
#   'explanation',
#   'friend',
#   'h',
#   'hamed',
#   'health',
#   'immigration',
#   'immolate',
#   'island',
#   'issues',
#   'later',
#   'little',
#   'man',
#   'masoumali',
#   'mental',
#   'months',
#   'nauru',
#   'old',
#   'omid',
#   'outside',
#   'post',
#   'refugee',
#   'refugees',
#   'run',
#   'self',
#   'set',
#   'severe',
#   'sick',
#   'small',
#   'spreads',
#   'told',
#   'view',
#   'watched',
#   'week',
#   'year',
#   'young'},
#  {'across',
#   'back',
#   'children',
#   'closing',
#   'confused',
#   'coronavirus',
#   'could',
#   'despite',
#   'due',
#   'england',
#   'entire',
#   'entitled',
#   'expected',
#   'extensive',
#   'far',
#   'formally',
#   'going',
#   'government',
#   'headteachers',
#   'key',
#   'list',
#   'make',
#   'managers',
#   'new',
#   'next',
#   'nurseries',
#   'nursery',
#   'overwhelmed',
#   'policy',
#   'post',
#   'pupils',
#   'revealed',
#   'school',
#   'schools',
#   'sense',
#   'spaces',
#   'struggling',
#   'unions',
#   'view',
#   'warned',
#   'week',
#   'whose',
#   'worker',
#   'workers'},
#  {'announced',
#   'australia',
#   'australian',
#   'avoid',
#   'ban',
#   'behind',
#   'covid',
#   'efforts',
#   'enforcing',
#   'entire',
#   'essential',
#   'evening',
#   'gatherings',
#   'government',
#   'hoax',
#   'included',
#   'indoor',
#   'latest',
#   'lifted',
#   'lockdown',
#   'malaysian',
#   'mandatory',
#   'message',
#   'minister',
#   'morrison',
#   'non',
#   'online',
#   'people',
#   'post',
#   'press',
#   'prime',
#   'probably',
#   'recommendations',
#   'release',
#   'saw',
#   'scott',
#   'speech',
#   'spread',
#   'stop',
#   'story',
#   'tuesday',
#   'view',
#   'wednesday',
#   'widely'},
#  {'advised',
#   'background',
#   'bailey',
#   'based',
#   'building',
#   'contracts',
#   'cost',
#   'costing',
#   'deal',
#   'despite',
#   'drawing',
#   'entire',
#   'fel',
#   'finance',
#   'firms',
#   'handed',
#   'hopeful',
#   'hospital',
#   'investment',
#   'labour',
#   'leadership',
#   'legal',
#   'liverpool',
#   'long',
#   'luxembourg',
#   'million',
#   'millions',
#   'nhs',
#   'ownership',
#   'pfi',
#   'post',
#   'private',
#   'project',
#   'property',
#   'rebecca',
#   'repeatedly',
#   'responsible',
#   'rip',
#   'spoken',
#   'taxpayers',
#   'team',
#   'view',
#   'worked'},
#  {'able',
#   'army',
#   'around',
#   'best',
#   'brother',
#   'called',
#   'coronavirus',
#   'cousin',
#   'enough',
#   'entire',
#   'friend',
#   'going',
#   'gone',
#   'hilarious',
#   'know',
#   'legit',
#   'lot',
#   'mars',
#   'martians',
#   'mate',
#   'messages',
#   'mine',
#   'monitor',
#   'notes',
#   'one',
#   'people',
#   'post',
#   'said',
#   'see',
#   'sister',
#   'streets',
#   'supermarkets',
#   'view',
#   'viral',
#   'voice',
#   'weird',
#   'whatsapp'},
#  {'also',
#   'compromised',
#   'coronavirus',
#   'create',
#   'current',
#   'disease',
#   'dr',
#   'drugs',
#   'entire',
#   'especially',
#   'first',
#   'generation',
#   'hard',
#   'immune',
#   'immunosuppressed',
#   'isolation',
#   'knows',
#   'like',
#   'many',
#   'map',
#   'martin',
#   'new',
#   'one',
#   'outbreak',
#   'pandemic',
#   'people',
#   'post',
#   'process',
#   'said',
#   'scientist',
#   'self',
#   'slow',
#   'stoermer',
#   'system',
#   'time',
#   'treat',
#   'using',
#   'view',
#   'vulnerable'},
#  {'ago',
#   'almost',
#   'ann',
#   'arthritis',
#   'available',
#   'bridge',
#   'compromise',
#   'coronavirus',
#   'diabetes',
#   'doctor',
#   'drugs',
#   'entire',
#   'hand',
#   'immune',
#   'love',
#   'make',
#   'making',
#   'metabolic',
#   'new',
#   'none',
#   'online',
#   'pandemic',
#   'people',
#   'pickles',
#   'post',
#   'psoriatic',
#   'quadroy',
#   'quarantine',
#   'risk',
#   'sanitiser',
#   'self',
#   'syndrome',
#   'system',
#   'takes',
#   'told',
#   'treat',
#   'two',
#   'type',
#   'using',
#   'view',
#   'vulnerable',
#   'weeks',
#   'would',
#   'yea'},
#  {'affecting',
#   'airline',
#   'around',
#   'asking',
#   'basically',
#   'cancellations',
#   'cancelled',
#   'changes',
#   'coronavirus',
#   'crazy',
#   'entire',
#   'everyone',
#   'furloughs',
#   'getting',
#   'husband',
#   'income',
#   'job',
#   'lives',
#   'means',
#   'musician',
#   'one',
#   'people',
#   'post',
#   'professional',
#   'real',
#   'really',
#   'school',
#   'shows',
#   'something',
#   'take',
#   'time',
#   'tours',
#   'traveling',
#   'view',
#   'werent',
#   'work',
#   'works',
#   'world',
#   'zero'},
#  {'acertar',
#   'consegue',
#   'coronavírus',
#   'criado',
#   'em',
#   'entire',
#   'essas',
#   'fake',
#   'foi',
#   'laboratório',
#   'news',
#   'notícias',
#   'ou',
#   'post',
#   'se',
#   'sobre',
#   'são',
#   'verdadeiras',
#   'view',
#   'você'},
#  {'afirmou',
#   'ano',
#   'anunciou',
#   'boulos',
#   'candidato',
#   'candidatura',
#   'concorrer',
#   'concorreria',
#   'contra',
#   'da',
#   'das',
#   'de',
#   'depois',
#   'derrotado',
#   'desisti',
#   'diz',
#   'dizer',
#   'enfrentar',
#   'entire',
#   'esquerda',
#   'este',
#   'ex',
#   'fake',
#   'feira',
#   'feito',
#   'fernando',
#   'foi',
#   'gente',
#   'guilherme',
#   'haddad',
#   'lança',
#   'lançamento',
#   'mas',
#   'nesta',
#   'news',
#   'não',
#   'paulo',
#   'petista',
#   'por',
#   'post',
#   'prefeito',
#   'prefeitura',
#   'presidência',
#   'pretende',
#   'produzidas',
#   'pré',
#   'prévias',
#   'psol',
#   'que',
#   'república',
#   'segunda',
#   'sp',
#   'são',
#   'ter',
#   'terá',
#   'uma',
#   'view',
#   'à',
#   'é'},
#  {'afirmou',
#   'anúncio',
#   'armadas',
#   'base',
#   'bolsonaro',
#   'com',
#   'contraiu',
#   'coronavírus',
#   'das',
#   'de',
#   'depois',
#   'deram',
#   'disse',
#   'diz',
#   'eduardo',
#   'em',
#   'entire',
#   'era',
#   'exames',
#   'feira',
#   'foi',
#   'forças',
#   'fox',
#   'hospital',
#   'informação',
#   'informou',
#   'jair',
#   'laboratório',
#   'maneira',
#   'manhã',
#   'nas',
#   'negativo',
#   'negou',
#   'nesta',
#   'news',
#   'não',
#   'ocorreu',
#   'os',
#   'para',
#   'particular',
#   'pela',
#   'positivo',
#   'post',
#   'pouco',
#   'presidente',
#   'quanto',
#   'que',
#   'redes',
#   'resultado',
#   'sexta',
#   'sociais',
#   'submetido',
#   'tanto',
#   'transparente',
#   'view'},
#  {'administração',
#   'alvo',
#   'ao',
#   'boate',
#   'bolinha',
#   'buzzfeed',
#   'campo',
#   'casa',
#   'contraiu',
#   'contraído',
#   'coronavírus',
#   'covid',
#   'cristal',
#   'das',
#   'de',
#   'deu',
#   'disse',
#   'diz',
#   'e',
#   'ela',
#   'em',
#   'empresas',
#   'enquanto',
#   'entire',
#   'esperar',
#   'esperava',
#   'estudante',
#   'eu',
#   'exame',
#   'fechou',
#   'festa',
#   'foi',
#   'grande',
#   'internet',
#   'julgamento',
#   'mas',
#   'motivo',
#   'na',
#   'namorado',
#   'news',
#   'não',
#   'pessoas',
#   'pior',
#   'positivo',
#   'post',
#   'quarentena',
#   'que',
#   'raiva',
#   'resultado',
#   'sem',
#   'silva',
#   'sintomas',
#   'sua',
#   'também',
#   'tenho',
#   'ter',
#   'thayany',
#   'uma',
#   'view',
#   'virou',
#   'é'},
#  {'acabou',
#   'agressora',
#   'ainda',
#   'anos',
#   'após',
#   'banheiro',
#   'br',
#   'caso',
#   'com',
#   'de',
#   'direito',
#   'dos',
#   'e',
#   'educação',
#   'em',
#   'entire',
#   'esconder',
#   'estudante',
#   'evitar',
#   'feira',
#   'filmou',
#   'flagrante',
#   'foi',
#   'gritou',
#   'hybner',
#   'luciene',
#   'macaca',
#   'mas',
#   'mim',
#   'minutos',
#   'mulher',
#   'mão',
#   'na',
#   'nathália',
#   'negra',
#   'negro',
#   'noite',
#   'para',
#   'pela',
#   'por',
#   'porque',
#   'post',
#   'presa',
#   'prisão',
#   'que',
#   'quinta',
#   'raiva',
#   'rio',
#   'saída',
#   'se',
#   'seguranças',
#   'sem',
#   'shopping',
#   'tentou',
#   'testemunhado',
#   'tira',
#   'tu',
#   'tá',
#   'um',
#   'uma',
#   'view',
#   'xinga',
#   'xingar',
#   'é'},
#  {'administration',
#   'arent',
#   'asked',
#   'away',
#   'best',
#   'bilingual',
#   'cd',
#   'coronavirus',
#   'doj',
#   'guidance',
#   'handle',
#   'hang',
#   'immigration',
#   'inbox',
#   'judges',
#   'let',
#   'news',
#   'one',
#   'outbreak',
#   'piece',
#   'posters',
#   'reason',
#   'sign',
#   'specifically',
#   'straight',
#   'sure',
#   'took',
#   'trump',
#   'u',
#   'vice',
#   'virus',
#   'want'},
#  {'among',
#   'bangers',
#   'catchy',
#   'caution',
#   'coronavirus',
#   'cumbia',
#   'danced',
#   'del',
#   'earworm',
#   'edition',
#   'even',
#   'everywhere',
#   'focused',
#   'grubbiest',
#   'hopefully',
#   'inform',
#   'insp',
#   'inspired',
#   'john',
#   'last',
#   'memorably',
#   'oliver',
#   'popularizedand',
#   'psa',
#   'recent',
#   'regret',
#   'slap',
#   'songs',
#   'suddenly',
#   'tonight',
#   'toon',
#   'turned',
#   'us',
#   'vietnam',
#   'vietnamese',
#   'virus',
#   'week'},
#  {'around',
#   'become',
#   'best',
#   'continues',
#   'coronavirus',
#   'covid',
#   'escalate',
#   'first',
#   'hit',
#   'inbox',
#   'infected',
#   'korea',
#   'member',
#   'military',
#   'news',
#   'old',
#   'outbreak',
#   'sign',
#   'soldier',
#   'south',
#   'spouse',
#   'starting',
#   'stationed',
#   'straight',
#   'u',
#   'vice',
#   'want',
#   'world',
#   'year'},
#  {'advocates',
#   'arenas',
#   'avoiding',
#   'california',
#   'centers',
#   'city',
#   'closing',
#   'contact',
#   'convention',
#   'converted',
#   'coronavirus',
#   'emptied',
#   'even',
#   'homeless',
#   'hotels',
#   'kentucky',
#   'lining',
#   'might',
#   'officials',
#   'option',
#   'people',
#   'places',
#   'recently',
#   'safer',
#   'sheltering',
#   'shelters',
#   'silver',
#   'small',
#   'state',
#   'taking',
#   'temporary',
#   'theres',
#   'virus',
#   'worry'},
#  {'announced',
#   'another',
#   'b',
#   'bracing',
#   'coming',
#   'coronavirus',
#   'crisis',
#   'days',
#   'death',
#   'epidemic',
#   'europe',
#   'facing',
#   'got',
#   'huge',
#   'impending',
#   'infected',
#   'infections',
#   'italian',
#   'italy',
#   'officials',
#   'others',
#   'real',
#   'reported',
#   'risen',
#   'surge',
#   'threat',
#   'thursday',
#   'toll',
#   'two'},
#  {'anxiety',
#   'buying',
#   'capitalize',
#   'cases',
#   'cdc',
#   'collective',
#   'concern',
#   'coronavirus',
#   'enterprising',
#   'etsy',
#   'face',
#   'growing',
#   'inevitable',
#   'internationally',
#   'jacking',
#   'least',
#   'listing',
#   'locations',
#   'marketing',
#   'masks',
#   'merch',
#   'much',
#   'one',
#   'pandemic',
#   'per',
#   'price',
#   'quickly',
#   'said',
#   'seller',
#   'sellers',
#   'shirts',
#   'shop',
#   'spreading',
#   'started',
#   'would'},
#  {'almost',
#   'announced',
#   'another',
#   'body',
#   'burial',
#   'certainly',
#   'claims',
#   'clerics',
#   'coronavirus',
#   'country',
#   'dead',
#   'death',
#   'evidence',
#   'experts',
#   'fatalities',
#   'figure',
#   'friday',
#   'graves',
#   'growing',
#   'including',
#   'inside',
#   'iran',
#   'leap',
#   'lying',
#   'major',
#   'mass',
#   'mounts',
#   'much',
#   'number',
#   'outbreak',
#   'pits',
#   'real',
#   'rising',
#   'ruling',
#   'say',
#   'says',
#   'see',
#   'seen',
#   'space',
#   'supporting',
#   'toll',
#   'virus',
#   'wider'},
#  {'announced',
#   'buy',
#   'cases',
#   'cause',
#   'cdc',
#   'concern',
#   'considers',
#   'coronavir',
#   'coronavirus',
#   'coughs',
#   'everything',
#   'food',
#   'freaking',
#   'go',
#   'know',
#   'mask',
#   'near',
#   'need',
#   'outside',
#   'people',
#   'personally',
#   'plenty',
#   'situation',
#   'someone',
#   'stockpile',
#   'theres',
#   'tuesday',
#   'u',
#   'unsurprisingly',
#   'widespread',
#   'writing'},
#  {'answers',
#   'aware',
#   'beards',
#   'best',
#   'cdc',
#   'centers',
#   'chops',
#   'chu',
#   'control',
#   'coronavirus',
#   'could',
#   'disease',
#   'effective',
#   'face',
#   'fu',
#   'going',
#   'inbox',
#   'less',
#   'make',
#   'man',
#   'mask',
#   'mutton',
#   'news',
#   'one',
#   'outbreak',
#   'patch',
#   'prevention',
#   'protect',
#   'putting',
#   'risk',
#   'sign',
#   'soul',
#   'straight',
#   'thing',
#   'vice',
#   'want',
#   'wants',
#   'wear',
#   'youre'},
#  {'appeared',
#   'article',
#   'breakthrough',
#   'bringing',
#   'canada',
#   'canadian',
#   'closer',
#   'coronavirus',
#   'covid',
#   'doctors',
#   'institute',
#   'isolated',
#   'means',
#   'medical',
#   'novel',
#   'one',
#   'ontario',
#   'originally',
#   'pandemic',
#   'research',
#   'researchers',
#   'responsible',
#   'step',
#   'sunnybrook',
#   'team',
#   'vaccine',
#   'vice',
#   'world'},
#  {'also',
#   'antarctica',
#   'beyond',
#   'brazil',
#   'cases',
#   'china',
#   'confirmed',
#   'continent',
#   'contracted',
#   'coronavirus',
#   'countries',
#   'day',
#   'deeply',
#   'europe',
#   'every',
#   'except',
#   'field',
#   'flagrantly',
#   'iran',
#   'irresponsible',
#   'korea',
#   'making',
#   'misinformation',
#   'people',
#   'racist',
#   'several',
#   'skits',
#   'south',
#   'spread',
#   'surprise',
#   'te',
#   'terrible',
#   'tiktok',
#   'tiktokers',
#   'tiktoks'},
#  {'alex',
#   'alternative',
#   'anxious',
#   'baseless',
#   'believe',
#   'bioweapon',
#   'claims',
#   'conspiracy',
#   'coronavirus',
#   'crisis',
#   'disinformation',
#   'exa',
#   'fired',
#   'fringe',
#   'groups',
#   'host',
#   'imaginations',
#   'increasingly',
#   'infowars',
#   'jones',
#   'narratives',
#   'novel',
#   'online',
#   'opportunity',
#   'poisoning',
#   'proliferating',
#   'public',
#   'push',
#   'radiation',
#   'theories',
#   'theorists',
#   'using',
#   'wild'},
#  {'became',
#   'best',
#   'casualty',
#   'contracted',
#   'coronavirus',
#   'countrys',
#   'covid',
#   'current',
#   'die',
#   'died',
#   'dying',
#   'fifth',
#   'figure',
#   'figures',
#   'five',
#   'former',
#   'government',
#   'high',
#   'inbox',
#   'iranian',
#   'keep',
#   'latest',
#   'lawmaker',
#   'leading',
#   'making',
#   'man',
#   'monday',
#   'morning',
#   'news',
#   'officials',
#   'outbreak',
#   'political',
#   'profile',
#   'response',
#   'sign',
#   'straight',
#   'th',
#   'vice',
#   'want'},
#  {'according',
#   'appeared',
#   'article',
#   'asia',
#   'cases',
#   'center',
#   'centers',
#   'china',
#   'co',
#   'confirmed',
#   'coronavirus',
#   'covid',
#   'currently',
#   'deaths',
#   'disease',
#   'doctor',
#   'explosion',
#   'highest',
#   'infections',
#   'korea',
#   'march',
#   'monday',
#   'novel',
#   'number',
#   'originally',
#   'outside',
#   'south',
#   'talk',
#   'vice'},
#  {'announce',
#   'asking',
#   'became',
#   'cancel',
#   'cases',
#   'class',
#   'classes',
#   'college',
#   'coronavirus',
#   'deaths',
#   'first',
#   'friday',
#   'get',
#   'graduating',
#   'help',
#   'jeopardy',
#   'maj',
#   'recorded',
#   'related',
#   'remote',
#   'schools',
#   'sick',
#   'spread',
#   'state',
#   'stop',
#   'students',
#   'switching',
#   'u',
#   'university',
#   'virus',
#   'want',
#   'washington',
#   'worried',
#   'would'},
#  {'around',
#   'art',
#   'artists',
#   'coping',
#   'coronavirus',
#   'covid',
#   'creative',
#   'days',
#   'distractions',
#   'edges',
#   'end',
#   'endpoi',
#   'everyone',
#   'fetishists',
#   'find',
#   'fursona',
#   'get',
#   'getting',
#   'horny',
#   'imaginations',
#   'inside',
#   'isolated',
#   'learned',
#   'logical',
#   'minds',
#   'news',
#   'online',
#   'people',
#   'porn',
#   'pretty',
#   'right',
#   'sneeze',
#   'spreads',
#   'stuck',
#   'things',
#   'trying',
#   'waifus',
#   'wandering',
#   'weirder',
#   'wherever',
#   'worse'},
#  ...]

# %%
# create new row in big DF with unique words
MarchNews.insert(11,'uniqueWords', uniqueWords)
print(MarchNews)
# Out:
#                                       source                 author  \
# 0     {'id': 'fox-news', 'name': 'Fox News'}                    NaN
# 1     {'id': 'fox-news', 'name': 'Fox News'}                    NaN
# 2     {'id': 'fox-news', 'name': 'Fox News'}        William Sanchez
# 3     {'id': 'fox-news', 'name': 'Fox News'}    Wyatt DobrovichFago
# 4     {'id': 'fox-news', 'name': 'Fox News'}        William Sanchez
# ...                                      ...                    ...
# 1779  {'id': 'cbs-news', 'name': 'CBS News'}               CBS News
# 1780  {'id': 'cbs-news', 'name': 'CBS News'}  Camilo Montoya-Galvez
# 1781  {'id': 'cbs-news', 'name': 'CBS News'}               CBS News
# 1782  {'id': 'cbs-news', 'name': 'CBS News'}         Stephen Gandel
# 1783  {'id': 'cbs-news', 'name': 'CBS News'}               CBS News
#
#                                                   title  \
# 0     South Carolina primary is do-or-die for Biden ...
# 1     Sanders supporters react to DNC reportedly att...
# 2     Contentious Race Democratic Race Heads to Sout...
# 3     Federalist Editor Mollie Hemingway On Biden’s ...
# 4             Will Biden Get a Bounce on Super Tuesday?
# ...                                                 ...
# 1779  With U.S. in lockdown, hope and calm beat nerv...
# 1780  First immigrant in ICE custody tests positive ...
# 1781  Doctor answers your most pressing coronavirus ...
# 1782  South by Southwest festival canceled due to co...
# 1783  Coronavirus updates: Fear batters the economy ...
#
#                                             description  \
# 0     Reaction from former White House Chief of Staf...
# 1     Fox News contributor Lawrence Jones speaks to ...
# 2     We are days away from the South Carolina prima...
# 3     Former Vice President Joe Biden called his vic...
# 4     Howie Kurtz on Joe Biden winning the South Car...
# ...                                                 ...
# 1779  Some report stress but most stay optimistic as...
# 1780  Former ICE acting director John Sandweg told C...
# 1781  CBS News medical contributor Dr. Tara Narula j...
# 1782  Announcement comes after Apple, Facebook and o...
# 1783  Oil and stock prices have plummeted as Europe ...
#
#                                                     url  \
# 0             http://video.foxnews.com/v/6137137518001/
# 1             http://video.foxnews.com/v/6136724620001/
# 2     https://radio.foxnews.com/2020/02/27/the-fox-n...
# 3     https://radio.foxnews.com/2020/03/02/federalis...
# 4     https://radio.foxnews.com/2020/03/02/will-bide...
# ...                                                 ...
# 1779  https://www.cbsnews.com/news/with-americans-in...
# 1780  https://www.cbsnews.com/news/coronavirus-ice-f...
# 1781  https://www.cbsnews.com/news/coronavirus-press...
# 1782  https://www.cbsnews.com/news/coronavirus-south...
# 1783  https://www.cbsnews.com/live-updates/coronavir...
#
#                                              urlToImage           publishedAt  \
# 0     https://cf-images.us-east-1.prod.boltdns.net/v...  2020-02-29T02:49:49Z
# 1     https://cf-images.us-east-1.prod.boltdns.net/v...  2020-02-28T03:43:40Z
# 2     https://radio.foxnews.com/wp-content/uploads/2...  2020-02-27T10:00:02Z
# 3     https://radio.foxnews.com/wp-content/uploads/2...  2020-03-02T23:32:11Z
# 4     https://radio.foxnews.com/wp-content/uploads/2...  2020-03-02T17:55:01Z
# ...                                                 ...                   ...
# 1779  https://cbsnews3.cbsistatic.com/hub/i/r/2020/0...  2020-03-24T11:00:26Z
# 1780  https://cbsnews1.cbsistatic.com/hub/i/r/2020/0...  2020-03-24T20:19:32Z
# 1781  https://cbsnews2.cbsistatic.com/hub/i/r/2020/0...  2020-03-21T00:58:30Z
# 1782  https://cbsnews1.cbsistatic.com/hub/i/r/2020/0...  2020-03-06T22:31:53Z
# 1783  https://cbsnews3.cbsistatic.com/hub/i/r/2020/0...  2020-03-09T20:47:05Z
#
#                                                 content  \
# 0                                                  None
# 1                                                  None
# 2     We are days away from the South Carolina prima...
# 3     Former Vice President Joe Biden called his vic...
# 4                                                  None
# ...                                                 ...
# 1779  Amid the coronavirus outbreak, the personal ha...
# 1780  Immigration and Customs Enforcement (ICE) on T...
# 1781  The number of reported coronavirus cases in th...
# 1782  pulled out of the eventThe upcoming South by S...
# 1783  As China appeared to be getting over the initi...
#
#                                            TitleCleaned  \
# 0      [south, carolina, primary, die, biden, campaign]
# 1     [sanders, supporters, react, dnc, reportedly, ...
# 2     [contentious, race, democratic, race, heads, s...
# 3     [federalist, editor, mollie, hemingway, biden,...
# 4                  [biden, get, bounce, super, tuesday]
# ...                                                 ...
# 1779  [u, lockdown, hope, calm, beat, nervousness, c...
# 1780  [first, immigrant, ice, custody, tests, positi...
# 1781  [doctor, answers, pressing, coronavirus, quest...
# 1782  [south, southwest, festival, canceled, due, co...
# 1783  [coronavirus, updates, fear, batters, economy,...
#
#                                      DescriptionCleaned  \
# 0     [reaction, former, white, house, chief, staff,...
# 1     [fox, news, contributor, lawrence, jones, spea...
# 2     [days, away, south, carolina, primary, last, p...
# 3     [former, vice, president, joe, biden, called, ...
# 4     [howie, kurtz, joe, biden, winning, south, car...
# ...                                                 ...
# 1779  [report, stress, stay, optimistic, life, changes]
# 1780  [former, ice, acting, director, john, sandweg,...
# 1781  [cbs, news, medical, contributor, dr, tara, na...
# 1782  [announcement, comes, apple, facebook, big, co...
# 1783  [oil, stock, prices, plummeted, europe, u, beg...
#
#                                          ContentCleaned  \
# 0                                                    []
# 1                                                    []
# 2     [days, away, south, carolina, primary, last, p...
# 3     [former, vice, president, joe, biden, called, ...
# 4                                                    []
# ...                                                 ...
# 1779  [amid, coronavirus, outbreak, personal, become...
# 1780  [immigration, customs, enforcement, ice, tuesd...
# 1781  [number, reported, coronavirus, cases, u, cont...
# 1782  [pulled, eventthe, upcoming, south, southwest,...
# 1783  [china, appeared, getting, initial, onslaught,...
#
#                                             uniqueWords
# 0     {reaction, contributor, carolina, die, priebus...
# 1     {subvert, voters, give, supporters, contributo...
# 2     {democratic, carolina, super, bret, baier, pri...
# 3     {democratic, real, carry, mollie, victory, exp...
# 4     {carolina, super, reaching, primary, howardkur...
# ...                                                 ...
# 1779  {coronavirus, family, time, national, changes,...
# 1780  {coronavirus, immigration, could, immigrant, p...
# 1781  {coronavirus, narula, states, ones, cases, med...
# 1782  {coronavirus, texas, popular, technology, anno...
# 1783  {coronavirus, top, stem, economy, getting, chi...
#
# [1784 rows x 12 columns]

# %%
#MarchNews[1:2]
MarchNews['uniqueWords'][0]
# Out:
# {'biden',
#  'bruce',
#  'campaign',
#  'carolina',
#  'chief',
#  'contributor',
#  'die',
#  'former',
#  'fox',
#  'house',
#  'news',
#  'priebus',
#  'primary',
#  'reaction',
#  'reince',
#  'south',
#  'staff',
#  'tammy',
#  'white'}

# %% [markdown]
# # Get word count for unique words

# %%
# Some how need to do this for each row. However, each row will have different words. 

# Previously tried matching to predefined matrix derived from known politically loaded words/terms; 
# however,this doesn't work super well durring election/pandemic. 

# We could to go through articles and create custom global matrix based on current news coverage.
